# %% [markdown]
# ## Preprocessing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import librosa.display
import os

# %%
import tensorflow as tf
from tensorflow import keras

# %%
# to check if tensorflow is using gpu or not
len(tf.config.list_physical_devices('GPU')) > 0
# Out:
# False

# %% [markdown]
# Understanding Provided Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# os.getcwd()
patient_data = pd.read_csv('/content/drive/MyDrive/My Projects/respiratory_disorder_classification/Respiratory_Sound_Database/Respiratory_Sound_Database/patient_diagnosis.csv',names=['pid','disease'])

# %%
# printing patient id and disease info
patient_data.head()
# Out:
#    pid  disease
# 0  101     URTI
# 1  102  Healthy
# 2  103   Asthma
# 3  104     COPD
# 4  105     URTI

# %%
# knowing the audio text files
df = pd.read_csv("/content/drive/MyDrive/My Projects/respiratory_disorder_classification/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/203_1p4_Tc_mc_AKGC417L.txt",sep='\t',names=['start','end','crackles','wheezes'])
df.head()
# Out:
#    start     end  crackles  wheezes
# 0  0.685   2.208         0        0
# 1  2.208   4.577         1        0
# 2  4.577   6.970         1        0
# 3  6.970   9.351         0        0
# 4  9.351  11.851         0        0

# %% [markdown]
# The annotation text files have four columns:
# - Beginning of respiratory cycle(s)
# - End of respiratory cycle(s)
# - Presence/absence of crackles (presence=1, absence=0)
# - Presence/absence of wheezes (presence=1, absence=0)

# %% [markdown]
# We can extract info from the file names also as:
# Each audio file name is divided into 5 elements, separated with underscores (_).
#
# 1. Patient number (101,102,...,226)
# 2. Recording index
# 3. Chest location
#
#       a. Trachea (Tc)
#
#       b. Anterior left (Al)
#
#       c. Anterior right (Ar)
#
#       d. Posterior left (Pl)
#
#       e. Posterior right (Pr)
#
#       f. Lateral left (Ll)
#
#       g. Lateral right (Lr)
#
# 4. Acquisition mode
#
#      a. sequential/single channel (sc),
#
#      b. simultaneous/multichannel (mc)
#
# 5. Recording equipment
#
#      a. AKG C417L Microphone (AKGC417L),
#
#      b. 3M Littmann Classic II SE Stethoscope (LittC2SE),
#
#      c. 3M Litmmann 3200 Electronic Stethoscope (Litt3200),
#
#      d.  WelchAllyn Meditron Master Elite Electronic Stethoscope (Meditron)

# %%
# taking the file names
import os
path='/content/drive/MyDrive/My Projects/respiratory_disorder_classification/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/'
files=[s.split('.')[0] for s in os.listdir(path) if '.txt' in s]
files[:5]
# Out:
# ['160_1b3_Pl_mc_AKGC417L',
#  '160_1b3_Pr_mc_AKGC417L',
#  '160_1b3_Ar_mc_AKGC417L',
#  '160_2b4_Tc_mc_AKGC417L',
#  '162_1b2_Al_mc_AKGC417L']

# %%
def getFilenameInfo(file):
    return file.split('_')

# %%
getFilenameInfo('101_1b1_Al_sc_Meditron')
# Out:
# ['101', '1b1', 'Al', 'sc', 'Meditron']

# %%
files_data=[]
for file in files:
    data=pd.read_csv(path + file + '.txt',sep='\t',names=['start','end','crackles','wheezes'])
    name_data=getFilenameInfo(file)
    data['pid']=name_data[0]
    data['mode']=name_data[-2]
    data['filename']=file
    files_data.append(data)
files_df=pd.concat(files_data)
files_df.reset_index()
files_df.head()
# Out:
#     start     end  crackles  wheezes  pid mode                filename
# 0   1.862   5.718         0        1  160   mc  160_1b3_Pl_mc_AKGC417L
# 1   5.718   9.725         1        1  160   mc  160_1b3_Pl_mc_AKGC417L
# 2   9.725  13.614         1        1  160   mc  160_1b3_Pl_mc_AKGC417L
# 3  13.614  17.671         0        1  160   mc  160_1b3_Pl_mc_AKGC417L
# 4  17.671  19.541         0        0  160   mc  160_1b3_Pl_mc_AKGC417L

# %% [markdown]
# Join Patient Data with our Files DataFrame

# %%
patient_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126 entries, 0 to 125
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   pid      126 non-null    int64
#  1   disease  126 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.1+ KB

# %%
files_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6931 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   start     6931 non-null   float64
#  1   end       6931 non-null   float64
#  2   crackles  6931 non-null   int64
#  3   wheezes   6931 non-null   int64
#  4   pid       6931 non-null   object
#  5   mode      6931 non-null   object
#  6   filename  6931 non-null   object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 433.2+ KB

# %% [markdown]
# Jo join based on pid, we need to make the datatype of pid in both the files same.

# %%
patient_data.pid=patient_data.pid.astype('int32')
files_df.pid=files_df.pid.astype('int32')

# %% [markdown]
# Finally, we can merge to create our data

# %%
data=pd.merge(files_df,patient_data,on='pid')
data.head()
# Out:
#     start     end  crackles  wheezes  pid mode                filename disease
# 0   1.862   5.718         0        1  160   mc  160_1b3_Pl_mc_AKGC417L    COPD
# 1   5.718   9.725         1        1  160   mc  160_1b3_Pl_mc_AKGC417L    COPD
# 2   9.725  13.614         1        1  160   mc  160_1b3_Pl_mc_AKGC417L    COPD
# 3  13.614  17.671         0        1  160   mc  160_1b3_Pl_mc_AKGC417L    COPD
# 4  17.671  19.541         0        0  160   mc  160_1b3_Pl_mc_AKGC417L    COPD

# %% [markdown]
# Saving our output in csv format

# %%
isCsvDataExist = os.path.exists('/content/drive/MyDrive/My Projects/respiratory_disorder_classification/csv_data')
if(not isCsvDataExist):
    os.makedirs('/content/drive/MyDrive/My Projects/respiratory_disorder_classification/csv_data')
    data.to_csv('/content/drive/MyDrive/My Projects/respiratory_disorder_classification/csv_data/data.csv',index=False)
isCsvDataExist
# Out:
# True

# %% [markdown]
# We only want that parts from whole audio file which contains Respiratory Cycles.
#
# We will utilize the start and end time specified for these cycles in our data dataframe

# %%
'''
    Takes a numpy array and spilts its using start and end args
    raw_data=numpy array of audio sample
    start=time
    end=time
    sr=sampling_rate
    mode=mono/stereo
    by default librosa gives sr=22050
'''
def getPureSample(raw_data,start,end,sr):
    max_ind = len(raw_data)
    start_ind = min(int(start * sr), max_ind)
    end_ind = min(int(end * sr), max_ind)
    return raw_data[start_ind: end_ind]

# %% [markdown]
# We multiplied start/end with sampling rate cause start is time and raw_data is array sampled according to sampling rate
# Now we also want our input images to our cnn to be of same size for that audio files must be of same length i.e (start - end) must be same
#
# We will find the best length we can have

# %%
sns.scatterplot(x=(data.end-data.start), y=data.pid)
# Out:
# <Axes: xlabel='None', ylabel='pid'>

# %%
sns.boxplot(y=(data.end-data.start))
# Out:
# <Axes: ylabel='None'>

# %% [markdown]
# A boxplot is a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile [Q1], median, third quartile [Q3] and “maximum”).
#
# From these plots we can conclude that best length is ~6
# Also if difference is <6 we must Zero Pad it to get it to required length.
#
# Zero-padding refers to the process of symmetrically adding zeroes to the input matrix. It's a commonly used modification that allows the size of the input to be adjusted to our requirement.
#
# Here zero padding would mean silence.

# %% [markdown]
# A single sample of audio file can have Many Respiratory Cycles so we might have same multiple files for a single audio file
#
# We will be using Librosa module for loading audio files and Soundfile module for writing to output path
#
# Librosa - A python package for music and audio analysis. Librosa also normalizes the audio array.
#
# Soundfile - The soundfile module is an audio library based on libsndfile, CFFI and NumPy. It can read and write sound files.

# %%
# how single data looks in our dataframe
import librosa as lb
for index,row in data.iterrows():
    print("Index:",index)
    print("DataRow:\n",row)
    audio_file_loc=path + row['filename'] + '.wav'
    audioArr,sampleRate=lb.load(audio_file_loc)
    print("sr:",sampleRate)
    break
# Out:
# Index: 0
# DataRow:
#  start                        1.862
# end                          5.718
# crackles                         0
# wheezes                          1
# pid                            160
# mode                            mc
# filename    160_1b3_Pl_mc_AKGC417L
# disease                       COPD
# Name: 0, dtype: object
# sr: 22050

# %%
# directory to store our processed audio files
isProcessedAudioFilesExist = os.path.exists('/content/drive/MyDrive/My Projects/respiratory_disorder_classification/processed_audio_files')
isProcessedAudioFilesExistFlag = False

if not isProcessedAudioFilesExist:
    os.makedirs('/content/drive/MyDrive/My Projects/respiratory_disorder_classification/processed_audio_files')
    isProcessedAudioFilesExistFlag = True
    print("Processed audio files directory created successfully.")
else:
    isProcessedAudioFilesExistFlag = True
    print("Processed audio files directory already exists.")

# Your processing code here (with isProcessedAudioFilesExistFlag properly set)
import soundfile as sf
import librosa as lb

if isProcessedAudioFilesExistFlag:
    i, cnt = 0, 0
    for index, row in data.iterrows():
        try:
            maxLen = 6
            start = row['start']
            end = row['end']
            filename = row['filename']

            # If len > maxLen, change len to maxLen
            if end - start > maxLen:
                end = start + maxLen  # end - start = maxLen

            audio_file_loc = path + filename + '.wav'

            if index > 0:
                # Check if more cycles exist for the same patient, if so, then add i to change filename
                if data.iloc[index - 1]['filename'] == filename:
                    i += 1
                else:
                    i = 0
            filename = filename + '_' + str(i) + '.wav'

            save_path = '/content/drive/MyDrive/My Projects/respiratory_disorder_classification/processed_audio_files/' + filename
            cnt += 1

            # librosa also normalizes the audio array
            audioArr, sampleRate = lb.load(audio_file_loc)
            pureSample = getPureSample(audioArr, start, end, sampleRate)

            # Pad audio if pureSample len < max_len

            # reqLen = 6 * sampleRate
            # padded_data = lb.util.pad_center(pureSample, reqLen)

            reqLen = 6 * sampleRate
            if len(pureSample) < reqLen:
              pad_len = reqLen - len(pureSample)
              padded_data = np.pad(pureSample, (0, pad_len), 'constant')
            else:
              padded_data = pureSample[:reqLen]

            sf.write(file=save_path, data=padded_data, samplerate=sampleRate)

            print(f"Processed file {filename} successfully.")
        except FileNotFoundError as e:
            print(f"File not found: {audio_file_loc}. Skipping...")
        except Exception as e:
            print(f"Error processing file {filename}: {e}")

    print('Total Files Processed: ', cnt)
else:
    print("isProcessedAudioFilesExistFlag is False. Skipping processing.")
# Out:
# Processed audio files directory already exists.
# Processed file 160_1b3_Pl_mc_AKGC417L_0.wav successfully.
# Processed file 160_1b3_Pl_mc_AKGC417L_1.wav successfully.
# Processed file 160_1b3_Pl_mc_AKGC417L_2.wav successfully.
# Processed file 160_1b3_Pl_mc_AKGC417L_3.wav successfully.
# Processed file 160_1b3_Pl_mc_AKGC417L_4.wav successfully.
# Processed file 160_1b3_Pr_mc_AKGC417L_0.wav successfully.
# Processed file 160_1b3_Pr_mc_AKGC417L_1.wav successfully.
# Processed file 160_1b3_Pr_mc_AKGC417L_2.wav successfully.
# Processed file 160_1b3_Pr_mc_AKGC417L_3.wav successfully.
# Processed file 160_1b3_Pr_mc_AKGC417L_4.wav successfully.
# Processed file 160_1b3_Ar_mc_AKGC417L_0.wav successfully.
# Processed file 160_1b3_Ar_mc_AKGC417L_1.wav successfully.
# Processed file 160_1b3_Ar_mc_AKGC417L_2.wav successfully.
# Processed file 160_1b3_Ar_mc_AKGC417L_3.wav successfully.
# Processed file 160_1b3_Ar_mc_AKGC417L_4.wav successfully.
# Processed file 160_2b4_Tc_mc_AKGC417L_0.wav successfully.
# Processed file 160_2b4_Tc_mc_AKGC417L_1.wav successfully.
# Processed file 160_2b4_Tc_mc_AKGC417L_2.wav successfully.
# Processed file 160_2b4_Tc_mc_AKGC417L_3.wav successfully.
# Processed file 160_2b4_Tc_mc_AKGC417L_4.wav successfully.
# Processed file 160_2b4_Tc_mc_AKGC417L_5.wav successfully.
# Processed file 160_2b4_Tc_mc_AKGC417L_6.wav successfully.
# Processed file 160_2b4_Pl_mc_AKGC417L_0.wav successfully.
# Processed file 160_2b4_Pl_mc_AKGC417L_1.wav successfully.
# Processed file 160_2b4_Pl_mc_AKGC417L_2.wav successfully.
# Processed file 160_2b4_Pl_mc_AKGC417L_3.wav successfully.
# Processed file 160_2b4_Pl_mc_AKGC417L_4.wav successfully.
# Processed file 160_2b4_Pl_mc_AKGC417L_5.wav successfully.
# Processed file 160_2b4_Pl_mc_AKGC417L_6.wav successfully.
# Processed file 160_1b4_Tc_mc_AKGC417L_0.wav successfully.
# Processed file 160_1b4_Tc_mc_AKGC417L_1.wav successfully.
# Processed file 160_1b4_Tc_mc_AKGC417L_2.wav successfully.
# Processed file 160_1b4_Tc_mc_AKGC417L_3.wav successfully.
# Processed file 160_2b4_Pr_mc_AKGC417L_0.wav successfully.
# Processed file 160_2b4_Pr_mc_AKGC417L_1.wav successfully.
# Processed file 160_2b4_Pr_mc_AKGC417L_2.wav successfully.
# Processed file 160_2b4_Pr_mc_AKGC417L_3.wav successfully.
# Processed file 160_2b4_Pr_mc_AKGC417L_4.wav successfully.
# Processed file 160_2b4_Pr_mc_AKGC417L_5.wav successfully.
# Processed file 160_2b4_Pr_mc_AKGC417L_6.wav successfully.
# Processed file 160_2b3_Lr_mc_AKGC417L_0.wav successfully.
# Processed file 160_2b3_Lr_mc_AKGC417L_1.wav successfully.
# Processed file 160_2b3_Lr_mc_AKGC417L_2.wav successfully.
# Processed file 160_2b3_Lr_mc_AKGC417L_3.wav successfully.
# Processed file 160_2b3_Lr_mc_AKGC417L_4.wav successfully.
# Processed file 160_2b3_Lr_mc_AKGC417L_5.wav successfully.
# Processed file 160_2b3_Lr_mc_AKGC417L_6.wav successfully.
# Processed file 160_2b4_Ar_mc_AKGC417L_0.wav successfully.
# Processed file 160_2b4_Ar_mc_AKGC417L_1.wav successfully.
# Processed file 160_2b4_Ar_mc_AKGC417L_2.wav successfully.
# Processed file 160_2b4_Ar_mc_AKGC417L_3.wav successfully.
# Processed file 160_2b4_Ar_mc_AKGC417L_4.wav successfully.
# Processed file 160_2b4_Ar_mc_AKGC417L_5.wav successfully.
# Processed file 160_2b4_Ar_mc_AKGC417L_6.wav successfully.
# Processed file 160_1b4_Pr_mc_AKGC417L_0.wav successfully.
# Processed file 160_1b4_Pr_mc_AKGC417L_1.wav successfully.
# Processed file 160_1b4_Pr_mc_AKGC417L_2.wav successfully.
# Processed file 160_1b4_Pr_mc_AKGC417L_3.wav successfully.
# Processed file 160_1b2_Pl_mc_AKGC417L_0.wav successfully.
# Processed file 160_1b2_Pl_mc_AKGC417L_1.wav successfully.
# Processed file 160_1b2_Ar_mc_AKGC417L_0.wav successfully.
# Processed file 160_1b2_Ar_mc_AKGC417L_1.wav successfully.
# Processed file 160_1b2_Pr_mc_AKGC417L_0.wav successfully.
# Processed file 160_1b2_Pr_mc_AKGC417L_1.wav successfully.
# Processed file 160_1b2_Al_mc_AKGC417L_0.wav successfully.
# Processed file 160_1b2_Al_mc_AKGC417L_1.wav successfully.
# Processed file 160_1b2_Lr_mc_AKGC417L_0.wav successfully.
# Processed file 160_1b2_Lr_mc_AKGC417L_1.wav successfully.
# Processed file 160_1b3_Tc_mc_AKGC417L_0.wav successfully.
# Processed file 160_1b3_Tc_mc_AKGC417L_1.wav successfully.
# Processed file 160_1b3_Tc_mc_AKGC417L_2.wav successfully.
# Processed file 160_1b3_Tc_mc_AKGC417L_3.wav successfully.
# Processed file 160_1b3_Tc_mc_AKGC417L_4.wav successfully.
# Processed file 160_1b4_Lr_mc_AKGC417L_0.wav successfully.
# Processed file 160_1b4_Lr_mc_AKGC417L_1.wav successfully.
# Processed file 160_1b4_Lr_mc_AKGC417L_2.wav successfully.
# Processed file 160_1b4_Lr_mc_AKGC417L_3.wav successfully.
# Processed file 160_1b2_Tc_mc_AKGC417L_0.wav successfully.
# Processed file 160_1b2_Tc_mc_AKGC417L_1.wav successfully.
# Processed file 160_1b4_Pl_mc_AKGC417L_0.wav successfully.
# Processed file 160_1b4_Pl_mc_AKGC417L_1.wav successfully.
# Processed file 160_1b4_Pl_mc_AKGC417L_2.wav successfully.
# Processed file 160_1b4_Pl_mc_AKGC417L_3.wav successfully.
# Processed file 160_1b4_Al_mc_AKGC417L_0.wav successfully.
# Processed file 160_1b4_Al_mc_AKGC417L_1.wav successfully.
# Processed file 160_1b4_Al_mc_AKGC417L_2.wav successfully.
# Processed file 160_1b4_Al_mc_AKGC417L_3.wav successfully.
# Processed file 160_1b3_Lr_mc_AKGC417L_0.wav successfully.
# Processed file 160_1b3_Lr_mc_AKGC417L_1.wav successfully.
# Processed file 160_1b3_Lr_mc_AKGC417L_2.wav successfully.
# Processed file 160_1b3_Lr_mc_AKGC417L_3.wav successfully.
# Processed file 160_1b3_Lr_mc_AKGC417L_4.wav successfully.
# Processed file 160_1b4_Ar_mc_AKGC417L_0.wav successfully.
# Processed file 160_1b4_Ar_mc_AKGC417L_1.wav successfully.
# Processed file 160_1b4_Ar_mc_AKGC417L_2.wav successfully.
# Processed file 160_1b4_Ar_mc_AKGC417L_3.wav successfully.
# Processed file 160_1b3_Al_mc_AKGC417L_0.wav successfully.
# Processed file 160_1b3_Al_mc_AKGC417L_1.wav successfully.
# Processed file 160_1b3_Al_mc_AKGC417L_2.wav successfully.
# Processed file 160_1b3_Al_mc_AKGC417L_3.wav successfully.
# Processed file 160_1b3_Al_mc_AKGC417L_4.wav successfully.
# Processed file 162_1b2_Al_mc_AKGC417L_0.wav successfully.
# Processed file 162_1b2_Al_mc_AKGC417L_1.wav successfully.
# Processed file 162_1b2_Al_mc_AKGC417L_2.wav successfully.
# Processed file 162_1b2_Tc_mc_AKGC417L_0.wav successfully.
# Processed file 162_1b2_Tc_mc_AKGC417L_1.wav successfully.
# Processed file 162_1b2_Tc_mc_AKGC417L_2.wav successfully.
# Processed file 162_2b2_Pr_mc_AKGC417L_0.wav successfully.
# Processed file 162_2b2_Pr_mc_AKGC417L_1.wav successfully.
# Processed file 162_2b2_Pr_mc_AKGC417L_2.wav successfully.
# Processed file 162_2b2_Pr_mc_AKGC417L_3.wav successfully.
# Processed file 162_1b2_Lr_mc_AKGC417L_0.wav successfully.
# Processed file 162_1b2_Lr_mc_AKGC417L_1.wav successfully.
# Processed file 162_1b2_Lr_mc_AKGC417L_2.wav successfully.
# Processed file 162_1b2_Pr_mc_AKGC417L_0.wav successfully.
# Processed file 162_1b2_Pr_mc_AKGC417L_1.wav successfully.
# Processed file 162_1b2_Pr_mc_AKGC417L_2.wav successfully.
# Processed file 162_2b2_Tc_mc_AKGC417L_0.wav successfully.
# Processed file 162_2b2_Tc_mc_AKGC417L_1.wav successfully.
# Processed file 162_2b2_Tc_mc_AKGC417L_2.wav successfully.
# Processed file 162_2b2_Tc_mc_AKGC417L_3.wav successfully.
# Processed file 162_2b2_Al_mc_AKGC417L_0.wav successfully.
# Processed file 162_2b2_Al_mc_AKGC417L_1.wav successfully.
# Processed file 162_2b2_Al_mc_AKGC417L_2.wav successfully.
# Processed file 162_2b2_Al_mc_AKGC417L_3.wav successfully.
# Processed file 162_2b2_Pl_mc_AKGC417L_0.wav successfully.
# Processed file 162_2b2_Pl_mc_AKGC417L_1.wav successfully.
# Processed file 162_2b2_Pl_mc_AKGC417L_2.wav successfully.
# Processed file 162_2b2_Pl_mc_AKGC417L_3.wav successfully.
# Processed file 162_1b2_Ll_mc_AKGC417L_0.wav successfully.
# Processed file 162_1b2_Ll_mc_AKGC417L_1.wav successfully.
# Processed file 162_1b2_Ll_mc_AKGC417L_2.wav successfully.
# Processed file 162_1b2_Pl_mc_AKGC417L_0.wav successfully.
# Processed file 162_1b2_Pl_mc_AKGC417L_1.wav successfully.
# Processed file 162_1b2_Pl_mc_AKGC417L_2.wav successfully.
# Processed file 162_1b2_Ar_mc_AKGC417L_0.wav successfully.
# Processed file 162_1b2_Ar_mc_AKGC417L_1.wav successfully.
# Processed file 162_1b2_Ar_mc_AKGC417L_2.wav successfully.
# Processed file 162_2b2_Ar_mc_AKGC417L_0.wav successfully.
# Processed file 162_2b2_Ar_mc_AKGC417L_1.wav successfully.
# Processed file 162_2b2_Ar_mc_AKGC417L_2.wav successfully.
# Processed file 162_2b2_Ar_mc_AKGC417L_3.wav successfully.
# Processed file 162_2b3_Lr_mc_AKGC417L_0.wav successfully.
# Processed file 162_2b3_Lr_mc_AKGC417L_1.wav successfully.
# Processed file 162_2b3_Lr_mc_AKGC417L_2.wav successfully.
# Processed file 162_2b3_Lr_mc_AKGC417L_3.wav successfully.
# Processed file 162_2b3_Tc_mc_AKGC417L_0.wav successfully.
# Processed file 162_2b3_Tc_mc_AKGC417L_1.wav successfully.
# Processed file 162_2b3_Tc_mc_AKGC417L_2.wav successfully.
# Processed file 162_2b3_Tc_mc_AKGC417L_3.wav successfully.
# Processed file 162_2b4_Pl_mc_AKGC417L_0.wav successfully.
# Processed file 162_2b4_Pl_mc_AKGC417L_1.wav successfully.
# Processed file 162_2b4_Pl_mc_AKGC417L_2.wav successfully.
# Processed file 162_2b4_Pl_mc_AKGC417L_3.wav successfully.
# Processed file 162_2b4_Al_mc_AKGC417L_0.wav successfully.
# Processed file 162_2b4_Al_mc_AKGC417L_1.wav successfully.
# Processed file 162_2b4_Al_mc_AKGC417L_2.wav successfully.
# Processed file 162_2b4_Al_mc_AKGC417L_3.wav successfully.
# Processed file 162_2b3_Pr_mc_AKGC417L_0.wav successfully.
# Processed file 162_2b3_Pr_mc_AKGC417L_1.wav successfully.
# Processed file 162_2b3_Pr_mc_AKGC417L_2.wav successfully.
# Processed file 162_2b3_Pr_mc_AKGC417L_3.wav successfully.
# Processed file 162_2b4_Lr_mc_AKGC417L_0.wav successfully.
# Processed file 162_2b4_Lr_mc_AKGC417L_1.wav successfully.
# Processed file 162_2b4_Lr_mc_AKGC417L_2.wav successfully.
# Processed file 162_2b4_Lr_mc_AKGC417L_3.wav successfully.
# Processed file 162_2b4_Ar_mc_AKGC417L_0.wav successfully.
# Processed file 162_2b4_Ar_mc_AKGC417L_1.wav successfully.
# Processed file 162_2b4_Ar_mc_AKGC417L_2.wav successfully.
# Processed file 162_2b4_Ar_mc_AKGC417L_3.wav successfully.
# Processed file 162_2b3_Pl_mc_AKGC417L_0.wav successfully.
# Processed file 162_2b3_Pl_mc_AKGC417L_1.wav successfully.
# Processed file 162_2b3_Pl_mc_AKGC417L_2.wav successfully.
# Processed file 162_2b3_Pl_mc_AKGC417L_3.wav successfully.
# Processed file 162_2b3_Ar_mc_AKGC417L_0.wav successfully.
# Processed file 162_2b3_Ar_mc_AKGC417L_1.wav successfully.
# Processed file 162_2b3_Ar_mc_AKGC417L_2.wav successfully.
# Processed file 162_2b3_Ar_mc_AKGC417L_3.wav successfully.
# Processed file 162_2b3_Al_mc_AKGC417L_0.wav successfully.
# Processed file 162_2b3_Al_mc_AKGC417L_1.wav successfully.
# Processed file 162_2b3_Al_mc_AKGC417L_2.wav successfully.
# Processed file 162_2b3_Al_mc_AKGC417L_3.wav successfully.
# Processed file 162_2b4_Tc_mc_AKGC417L_0.wav successfully.
# Processed file 162_2b4_Tc_mc_AKGC417L_1.wav successfully.
# Processed file 162_2b4_Tc_mc_AKGC417L_2.wav successfully.
# Processed file 162_2b4_Tc_mc_AKGC417L_3.wav successfully.
# Processed file 162_2b4_Pr_mc_AKGC417L_0.wav successfully.
# Processed file 162_2b4_Pr_mc_AKGC417L_1.wav successfully.
# Processed file 162_2b4_Pr_mc_AKGC417L_2.wav successfully.
# Processed file 162_2b4_Pr_mc_AKGC417L_3.wav successfully.
# Processed file 161_1b1_Al_sc_Meditron_0.wav successfully.
# Processed file 161_1b1_Al_sc_Meditron_1.wav successfully.
# Processed file 161_1b1_Al_sc_Meditron_2.wav successfully.
# Processed file 161_1b1_Al_sc_Meditron_3.wav successfully.
# Processed file 161_1b1_Al_sc_Meditron_4.wav successfully.
# Processed file 161_1b1_Al_sc_Meditron_5.wav successfully.
# Processed file 161_1b1_Al_sc_Meditron_6.wav successfully.
# Processed file 161_1b1_Al_sc_Meditron_7.wav successfully.
# Processed file 161_1b1_Al_sc_Meditron_8.wav successfully.
# Processed file 161_1b1_Pl_sc_Meditron_0.wav successfully.
# Processed file 161_1b1_Pl_sc_Meditron_1.wav successfully.
# Processed file 161_1b1_Pl_sc_Meditron_2.wav successfully.
# Processed file 161_1b1_Pl_sc_Meditron_3.wav successfully.
# Processed file 161_1b1_Pl_sc_Meditron_4.wav successfully.
# Processed file 161_1b1_Pl_sc_Meditron_5.wav successfully.
# Processed file 161_1b1_Pl_sc_Meditron_6.wav successfully.
# Processed file 161_1b1_Pl_sc_Meditron_7.wav successfully.
# Processed file 161_1b1_Pl_sc_Meditron_8.wav successfully.
# Processed file 161_1b1_Pl_sc_Meditron_9.wav successfully.
# Processed file 163_2b2_Ll_mc_AKGC417L_0.wav successfully.
# Processed file 163_2b2_Ll_mc_AKGC417L_1.wav successfully.
# Processed file 163_2b2_Ll_mc_AKGC417L_2.wav successfully.
# Processed file 163_2b2_Ll_mc_AKGC417L_3.wav successfully.
# Processed file 163_2b2_Ll_mc_AKGC417L_4.wav successfully.
# Processed file 163_2b2_Al_mc_AKGC417L_0.wav successfully.
# Processed file 163_2b2_Al_mc_AKGC417L_1.wav successfully.
# Processed file 163_2b2_Al_mc_AKGC417L_2.wav successfully.
# Processed file 163_2b2_Al_mc_AKGC417L_3.wav successfully.
# Processed file 163_2b2_Al_mc_AKGC417L_4.wav successfully.
# Processed file 163_2b2_Tc_mc_AKGC417L_0.wav successfully.
# Processed file 163_2b2_Tc_mc_AKGC417L_1.wav successfully.
# Processed file 163_2b2_Tc_mc_AKGC417L_2.wav successfully.
# Processed file 163_2b2_Tc_mc_AKGC417L_3.wav successfully.
# Processed file 163_2b2_Tc_mc_AKGC417L_4.wav successfully.
# Processed file 163_2b2_Ar_mc_AKGC417L_0.wav successfully.
# Processed file 163_2b2_Ar_mc_AKGC417L_1.wav successfully.
# Processed file 163_2b2_Ar_mc_AKGC417L_2.wav successfully.
# Processed file 163_2b2_Ar_mc_AKGC417L_3.wav successfully.
# Processed file 163_2b2_Ar_mc_AKGC417L_4.wav successfully.
# Processed file 163_2b2_Pr_mc_AKGC417L_0.wav successfully.
# Processed file 163_2b2_Pr_mc_AKGC417L_1.wav successfully.
# Processed file 163_2b2_Pr_mc_AKGC417L_2.wav successfully.
# Processed file 163_2b2_Pr_mc_AKGC417L_3.wav successfully.
# Processed file 163_2b2_Pr_mc_AKGC417L_4.wav successfully.
# Processed file 163_2b2_Lr_mc_AKGC417L_0.wav successfully.
# Processed file 163_2b2_Lr_mc_AKGC417L_1.wav successfully.
# Processed file 163_2b2_Lr_mc_AKGC417L_2.wav successfully.
# Processed file 163_2b2_Lr_mc_AKGC417L_3.wav successfully.
# Processed file 163_2b2_Lr_mc_AKGC417L_4.wav successfully.
# Processed file 163_8b3_Al_mc_AKGC417L_0.wav successfully.
# Processed file 163_8b3_Al_mc_AKGC417L_1.wav successfully.
# Processed file 163_8b3_Al_mc_AKGC417L_2.wav successfully.
# Processed file 163_8b3_Al_mc_AKGC417L_3.wav successfully.
# Processed file 163_8b3_Al_mc_AKGC417L_4.wav successfully.
# Processed file 163_8b3_Al_mc_AKGC417L_5.wav successfully.
# Processed file 163_2b2_Pl_mc_AKGC417L_0.wav successfully.
# Processed file 163_2b2_Pl_mc_AKGC417L_1.wav successfully.
# Processed file 163_2b2_Pl_mc_AKGC417L_2.wav successfully.
# Processed file 163_2b2_Pl_mc_AKGC417L_3.wav successfully.
# Processed file 163_2b2_Pl_mc_AKGC417L_4.wav successfully.
# Processed file 163_8b3_Ar_mc_AKGC417L_0.wav successfully.
# Processed file 163_8b3_Ar_mc_AKGC417L_1.wav successfully.
# Processed file 163_8b3_Ar_mc_AKGC417L_2.wav successfully.
# Processed file 163_8b3_Ar_mc_AKGC417L_3.wav successfully.
# Processed file 163_8b3_Ar_mc_AKGC417L_4.wav successfully.
# Processed file 163_8b3_Ar_mc_AKGC417L_5.wav successfully.
# Processed file 163_8b3_Ll_mc_AKGC417L_0.wav successfully.
# Processed file 163_8b3_Ll_mc_AKGC417L_1.wav successfully.
# Processed file 163_8b3_Ll_mc_AKGC417L_2.wav successfully.
# Processed file 163_8b3_Ll_mc_AKGC417L_3.wav successfully.
# Processed file 163_8b3_Ll_mc_AKGC417L_4.wav successfully.
# Processed file 163_8b3_Ll_mc_AKGC417L_5.wav successfully.
# Processed file 163_8b3_Pl_mc_AKGC417L_0.wav successfully.
# Processed file 163_8b3_Pl_mc_AKGC417L_1.wav successfully.
# Processed file 163_8b3_Pl_mc_AKGC417L_2.wav successfully.
# Processed file 163_8b3_Pl_mc_AKGC417L_3.wav successfully.
# Processed file 163_8b3_Pl_mc_AKGC417L_4.wav successfully.
# Processed file 163_8b3_Pl_mc_AKGC417L_5.wav successfully.
# Processed file 163_8b3_Pr_mc_AKGC417L_0.wav successfully.
# Processed file 163_8b3_Pr_mc_AKGC417L_1.wav successfully.
# Processed file 163_8b3_Pr_mc_AKGC417L_2.wav successfully.
# Processed file 163_8b3_Pr_mc_AKGC417L_3.wav successfully.
# Processed file 163_8b3_Pr_mc_AKGC417L_4.wav successfully.
# Processed file 163_8b3_Pr_mc_AKGC417L_5.wav successfully.
# Processed file 163_8b3_Lr_mc_AKGC417L_0.wav successfully.
# Processed file 163_8b3_Lr_mc_AKGC417L_1.wav successfully.
# Processed file 163_8b3_Lr_mc_AKGC417L_2.wav successfully.
# Processed file 163_8b3_Lr_mc_AKGC417L_3.wav successfully.
# Processed file 163_8b3_Lr_mc_AKGC417L_4.wav successfully.
# Processed file 163_8b3_Lr_mc_AKGC417L_5.wav successfully.
# Processed file 165_1b1_Pr_sc_Meditron_0.wav successfully.
# Processed file 165_1b1_Pr_sc_Meditron_1.wav successfully.
# Processed file 165_1b1_Pr_sc_Meditron_2.wav successfully.
# Processed file 165_1b1_Pr_sc_Meditron_3.wav successfully.
# Processed file 165_1b1_Pr_sc_Meditron_4.wav successfully.
# Processed file 165_1b1_Pr_sc_Meditron_5.wav successfully.
# Processed file 165_1b1_Pr_sc_Meditron_6.wav successfully.
# Processed file 165_1b1_Pr_sc_Meditron_7.wav successfully.
# Processed file 165_1b1_Ar_sc_Meditron_0.wav successfully.
# Processed file 165_1b1_Ar_sc_Meditron_1.wav successfully.
# Processed file 165_1b1_Ar_sc_Meditron_2.wav successfully.
# Processed file 165_1b1_Ar_sc_Meditron_3.wav successfully.
# Processed file 165_1b1_Ar_sc_Meditron_4.wav successfully.
# Processed file 165_1b1_Ar_sc_Meditron_5.wav successfully.
# Processed file 165_1b1_Ar_sc_Meditron_6.wav successfully.
# Processed file 165_1b1_Pl_sc_Meditron_0.wav successfully.
# Processed file 165_1b1_Pl_sc_Meditron_1.wav successfully.
# Processed file 165_1b1_Pl_sc_Meditron_2.wav successfully.
# Processed file 165_1b1_Pl_sc_Meditron_3.wav successfully.
# Processed file 165_1b1_Pl_sc_Meditron_4.wav successfully.
# Processed file 165_1b1_Pl_sc_Meditron_5.wav successfully.
# Processed file 165_1b1_Pl_sc_Meditron_6.wav successfully.
# Processed file 165_1b1_Pl_sc_Meditron_7.wav successfully.
# Processed file 166_1p1_Al_sc_Meditron_0.wav successfully.
# Processed file 166_1p1_Al_sc_Meditron_1.wav successfully.
# Processed file 166_1p1_Al_sc_Meditron_2.wav successfully.
# Processed file 166_1p1_Al_sc_Meditron_3.wav successfully.
# Processed file 166_1p1_Al_sc_Meditron_4.wav successfully.
# Processed file 166_1p1_Al_sc_Meditron_5.wav successfully.
# Processed file 166_1p1_Al_sc_Meditron_6.wav successfully.
# Processed file 166_1p1_Al_sc_Meditron_7.wav successfully.
# Processed file 166_1p1_Al_sc_Meditron_8.wav successfully.
# Processed file 166_1p1_Al_sc_Meditron_9.wav successfully.
# Processed file 166_1p1_Al_sc_Meditron_10.wav successfully.
# Processed file 166_1p1_Al_sc_Meditron_11.wav successfully.
# Processed file 166_1p1_Al_sc_Meditron_12.wav successfully.
# Processed file 166_1p1_Al_sc_Meditron_13.wav successfully.
# Processed file 166_1p1_Al_sc_Meditron_14.wav successfully.
# Processed file 166_1p1_Al_sc_Meditron_15.wav successfully.
# Processed file 166_1p1_Al_sc_Meditron_16.wav successfully.
# Processed file 166_1p1_Ar_sc_Meditron_0.wav successfully.
# Processed file 166_1p1_Ar_sc_Meditron_1.wav successfully.
# Processed file 166_1p1_Ar_sc_Meditron_2.wav successfully.
# Processed file 166_1p1_Ar_sc_Meditron_3.wav successfully.
# Processed file 166_1p1_Ar_sc_Meditron_4.wav successfully.
# Processed file 166_1p1_Ar_sc_Meditron_5.wav successfully.
# Processed file 166_1p1_Ar_sc_Meditron_6.wav successfully.
# Processed file 166_1p1_Ar_sc_Meditron_7.wav successfully.
# Processed file 166_1p1_Ar_sc_Meditron_8.wav successfully.
# Processed file 166_1p1_Ar_sc_Meditron_9.wav successfully.
# Processed file 166_1p1_Ar_sc_Meditron_10.wav successfully.
# Processed file 166_1p1_Ar_sc_Meditron_11.wav successfully.
# Processed file 166_1p1_Ar_sc_Meditron_12.wav successfully.
# Processed file 166_1p1_Ar_sc_Meditron_13.wav successfully.
# Processed file 166_1p1_Ar_sc_Meditron_14.wav successfully.
# Processed file 166_1p1_Ar_sc_Meditron_15.wav successfully.
# Processed file 166_1p1_Ar_sc_Meditron_16.wav successfully.
# Processed file 166_1p1_Ar_sc_Meditron_17.wav successfully.
# Processed file 166_1p1_Ar_sc_Meditron_18.wav successfully.
# Processed file 166_1p1_Ar_sc_Meditron_19.wav successfully.
# Processed file 166_1p1_Ar_sc_Meditron_20.wav successfully.
# Processed file 166_1p1_Ar_sc_Meditron_21.wav successfully.
# Processed file 166_1p1_Ar_sc_Meditron_22.wav successfully.
# Processed file 166_1p1_Ar_sc_Meditron_23.wav successfully.
# Processed file 166_1p1_Ar_sc_Meditron_24.wav successfully.
# Processed file 166_1p1_Pr_sc_Meditron_0.wav successfully.
# Processed file 166_1p1_Pr_sc_Meditron_1.wav successfully.
# Processed file 166_1p1_Pr_sc_Meditron_2.wav successfully.
# Processed file 166_1p1_Pr_sc_Meditron_3.wav successfully.
# Processed file 166_1p1_Pr_sc_Meditron_4.wav successfully.
# Processed file 166_1p1_Pr_sc_Meditron_5.wav successfully.
# Processed file 166_1p1_Pr_sc_Meditron_6.wav successfully.
# Processed file 166_1p1_Pr_sc_Meditron_7.wav successfully.
# Processed file 166_1p1_Pr_sc_Meditron_8.wav successfully.
# Processed file 166_1p1_Pr_sc_Meditron_9.wav successfully.
# Processed file 166_1p1_Pr_sc_Meditron_10.wav successfully.
# Processed file 166_1p1_Pr_sc_Meditron_11.wav successfully.
# Processed file 166_1p1_Pr_sc_Meditron_12.wav successfully.
# Processed file 166_1p1_Pr_sc_Meditron_13.wav successfully.
# Processed file 166_1p1_Pr_sc_Meditron_14.wav successfully.
# Processed file 166_1p1_Pr_sc_Meditron_15.wav successfully.
# Processed file 166_1p1_Pr_sc_Meditron_16.wav successfully.
# Processed file 166_1p1_Pr_sc_Meditron_17.wav successfully.
# Processed file 166_1p1_Pr_sc_Meditron_18.wav successfully.
# Processed file 166_1p1_Pr_sc_Meditron_19.wav successfully.
# Processed file 166_1p1_Pr_sc_Meditron_20.wav successfully.
# Processed file 166_1p1_Pr_sc_Meditron_21.wav successfully.
# Processed file 166_1p1_Pr_sc_Meditron_22.wav successfully.
# Processed file 166_1p1_Pr_sc_Meditron_23.wav successfully.
# Processed file 166_1p1_Pl_sc_Meditron_0.wav successfully.
# Processed file 166_1p1_Pl_sc_Meditron_1.wav successfully.
# Processed file 166_1p1_Pl_sc_Meditron_2.wav successfully.
# Processed file 166_1p1_Pl_sc_Meditron_3.wav successfully.
# Processed file 166_1p1_Pl_sc_Meditron_4.wav successfully.
# Processed file 166_1p1_Pl_sc_Meditron_5.wav successfully.
# Processed file 166_1p1_Pl_sc_Meditron_6.wav successfully.
# Processed file 166_1p1_Pl_sc_Meditron_7.wav successfully.
# Processed file 166_1p1_Pl_sc_Meditron_8.wav successfully.
# Processed file 166_1p1_Pl_sc_Meditron_9.wav successfully.
# Processed file 166_1p1_Pl_sc_Meditron_10.wav successfully.
# Processed file 166_1p1_Pl_sc_Meditron_11.wav successfully.
# Processed file 166_1p1_Pl_sc_Meditron_12.wav successfully.
# Processed file 166_1p1_Pl_sc_Meditron_13.wav successfully.
# Processed file 166_1p1_Pl_sc_Meditron_14.wav successfully.
# Processed file 166_1p1_Pl_sc_Meditron_15.wav successfully.
# Processed file 166_1p1_Pl_sc_Meditron_16.wav successfully.
# Processed file 166_1p1_Pl_sc_Meditron_17.wav successfully.
# Processed file 166_1p1_Pl_sc_Meditron_18.wav successfully.
# Processed file 166_1p1_Pl_sc_Meditron_19.wav successfully.
# Processed file 166_1p1_Pl_sc_Meditron_20.wav successfully.
# Processed file 166_1p1_Pl_sc_Meditron_21.wav successfully.
# Processed file 166_1p1_Pl_sc_Meditron_22.wav successfully.
# Processed file 166_1p1_Pl_sc_Meditron_23.wav successfully.
# Processed file 166_1p1_Ll_sc_Meditron_0.wav successfully.
# Processed file 166_1p1_Ll_sc_Meditron_1.wav successfully.
# Processed file 166_1p1_Ll_sc_Meditron_2.wav successfully.
# Processed file 166_1p1_Ll_sc_Meditron_3.wav successfully.
# Processed file 166_1p1_Ll_sc_Meditron_4.wav successfully.
# Processed file 166_1p1_Ll_sc_Meditron_5.wav successfully.
# Processed file 166_1p1_Ll_sc_Meditron_6.wav successfully.
# Processed file 166_1p1_Ll_sc_Meditron_7.wav successfully.
# Processed file 166_1p1_Ll_sc_Meditron_8.wav successfully.
# Processed file 166_1p1_Ll_sc_Meditron_9.wav successfully.
# Processed file 166_1p1_Ll_sc_Meditron_10.wav successfully.
# Processed file 166_1p1_Ll_sc_Meditron_11.wav successfully.
# Processed file 166_1p1_Ll_sc_Meditron_12.wav successfully.
# Processed file 166_1p1_Ll_sc_Meditron_13.wav successfully.
# Processed file 166_1p1_Ll_sc_Meditron_14.wav successfully.
# Processed file 166_1p1_Ll_sc_Meditron_15.wav successfully.
# Processed file 166_1p1_Ll_sc_Meditron_16.wav successfully.
# Processed file 166_1p1_Ll_sc_Meditron_17.wav successfully.
# Processed file 166_1p1_Ll_sc_Meditron_18.wav successfully.
# Processed file 166_1p1_Ll_sc_Meditron_19.wav successfully.
# Processed file 166_1p1_Ll_sc_Meditron_20.wav successfully.
# Processed file 166_1p1_Ll_sc_Meditron_21.wav successfully.
# Processed file 166_1p1_Ll_sc_Meditron_22.wav successfully.
# Processed file 166_1p1_Ll_sc_Meditron_23.wav successfully.
# Processed file 166_1p1_Ll_sc_Meditron_24.wav successfully.
# Processed file 164_1b1_Ll_sc_Meditron_0.wav successfully.
# Processed file 164_1b1_Ll_sc_Meditron_1.wav successfully.
# Processed file 164_1b1_Ll_sc_Meditron_2.wav successfully.
# Processed file 164_1b1_Ll_sc_Meditron_3.wav successfully.
# Processed file 164_1b1_Ll_sc_Meditron_4.wav successfully.
# Processed file 164_1b1_Ll_sc_Meditron_5.wav successfully.
# Processed file 164_1b1_Ll_sc_Meditron_6.wav successfully.
# Processed file 164_1b1_Ll_sc_Meditron_7.wav successfully.
# Processed file 164_1b1_Ll_sc_Meditron_8.wav successfully.
# Processed file 164_1b1_Ll_sc_Meditron_9.wav successfully.
# Processed file 167_1b1_Pr_sc_Meditron_0.wav successfully.
# Processed file 167_1b1_Pr_sc_Meditron_1.wav successfully.
# Processed file 167_1b1_Pr_sc_Meditron_2.wav successfully.
# Processed file 167_1b1_Pr_sc_Meditron_3.wav successfully.
# Processed file 167_1b1_Pr_sc_Meditron_4.wav successfully.
# Processed file 167_1b1_Pr_sc_Meditron_5.wav successfully.
# Processed file 167_1b1_Pr_sc_Meditron_6.wav successfully.
# Processed file 167_1b1_Pr_sc_Meditron_7.wav successfully.
# Processed file 167_1b1_Pr_sc_Meditron_8.wav successfully.
# Processed file 167_1b1_Pr_sc_Meditron_9.wav successfully.
# Processed file 167_1b1_Pr_sc_Meditron_10.wav successfully.
# Processed file 167_1b1_Pr_sc_Meditron_11.wav successfully.
# Processed file 167_1b1_Pr_sc_Meditron_12.wav successfully.
# Processed file 167_1b1_Pr_sc_Meditron_13.wav successfully.
# Processed file 167_1b1_Pr_sc_Meditron_14.wav successfully.
# Processed file 167_1b1_Al_sc_Meditron_0.wav successfully.
# Processed file 167_1b1_Al_sc_Meditron_1.wav successfully.
# Processed file 167_1b1_Al_sc_Meditron_2.wav successfully.
# Processed file 167_1b1_Al_sc_Meditron_3.wav successfully.
# Processed file 167_1b1_Al_sc_Meditron_4.wav successfully.
# Processed file 167_1b1_Al_sc_Meditron_5.wav successfully.
# Processed file 167_1b1_Al_sc_Meditron_6.wav successfully.
# Processed file 167_1b1_Al_sc_Meditron_7.wav successfully.
# Processed file 167_1b1_Al_sc_Meditron_8.wav successfully.
# Processed file 167_1b1_Al_sc_Meditron_9.wav successfully.
# Processed file 167_1b1_Al_sc_Meditron_10.wav successfully.
# Processed file 167_1b1_Al_sc_Meditron_11.wav successfully.
# Processed file 167_1b1_Al_sc_Meditron_12.wav successfully.
# Processed file 169_1b2_Ll_sc_Meditron_0.wav successfully.
# Processed file 169_1b2_Ll_sc_Meditron_1.wav successfully.
# Processed file 169_1b2_Ll_sc_Meditron_2.wav successfully.
# Processed file 169_1b2_Ll_sc_Meditron_3.wav successfully.
# Processed file 169_1b2_Ll_sc_Meditron_4.wav successfully.
# Processed file 169_1b2_Ll_sc_Meditron_5.wav successfully.
# Processed file 169_1b2_Ll_sc_Meditron_6.wav successfully.
# Processed file 169_1b1_Lr_sc_Meditron_0.wav successfully.
# Processed file 169_1b1_Lr_sc_Meditron_1.wav successfully.
# Processed file 169_1b1_Lr_sc_Meditron_2.wav successfully.
# Processed file 169_1b1_Lr_sc_Meditron_3.wav successfully.
# Processed file 169_1b1_Lr_sc_Meditron_4.wav successfully.
# Processed file 169_1b1_Lr_sc_Meditron_5.wav successfully.
# Processed file 169_1b1_Lr_sc_Meditron_6.wav successfully.
# Processed file 170_1b2_Pl_mc_AKGC417L_0.wav successfully.
# Processed file 170_1b2_Pl_mc_AKGC417L_1.wav successfully.
# Processed file 170_1b2_Pl_mc_AKGC417L_2.wav successfully.
# Processed file 170_1b2_Pl_mc_AKGC417L_3.wav successfully.
# Processed file 170_1b2_Pl_mc_AKGC417L_4.wav successfully.
# Processed file 170_1b2_Al_mc_AKGC417L_0.wav successfully.
# Processed file 170_1b2_Al_mc_AKGC417L_1.wav successfully.
# Processed file 170_1b2_Al_mc_AKGC417L_2.wav successfully.
# Processed file 170_1b2_Al_mc_AKGC417L_3.wav successfully.
# Processed file 170_1b2_Al_mc_AKGC417L_4.wav successfully.
# Processed file 170_1b2_Ar_mc_AKGC417L_0.wav successfully.
# Processed file 170_1b2_Ar_mc_AKGC417L_1.wav successfully.
# Processed file 170_1b2_Ar_mc_AKGC417L_2.wav successfully.
# Processed file 170_1b2_Ar_mc_AKGC417L_3.wav successfully.
# Processed file 170_1b2_Ar_mc_AKGC417L_4.wav successfully.
# Processed file 170_1b2_Lr_mc_AKGC417L_0.wav successfully.
# Processed file 170_1b2_Lr_mc_AKGC417L_1.wav successfully.
# Processed file 170_1b2_Lr_mc_AKGC417L_2.wav successfully.
# Processed file 170_1b2_Lr_mc_AKGC417L_3.wav successfully.
# Processed file 170_1b2_Lr_mc_AKGC417L_4.wav successfully.
# Processed file 170_1b3_Lr_mc_AKGC417L_0.wav successfully.
# Processed file 170_1b3_Lr_mc_AKGC417L_1.wav successfully.
# Processed file 170_1b3_Lr_mc_AKGC417L_2.wav successfully.
# Processed file 170_1b3_Lr_mc_AKGC417L_3.wav successfully.
# Processed file 170_1b3_Lr_mc_AKGC417L_4.wav successfully.
# Processed file 170_1b3_Lr_mc_AKGC417L_5.wav successfully.
# Processed file 170_1b2_Pr_mc_AKGC417L_0.wav successfully.
# Processed file 170_1b2_Pr_mc_AKGC417L_1.wav successfully.
# Processed file 170_1b2_Pr_mc_AKGC417L_2.wav successfully.
# Processed file 170_1b2_Pr_mc_AKGC417L_3.wav successfully.
# Processed file 170_1b2_Pr_mc_AKGC417L_4.wav successfully.
# Processed file 170_1b2_Tc_mc_AKGC417L_0.wav successfully.
# Processed file 170_1b2_Tc_mc_AKGC417L_1.wav successfully.
# Processed file 170_1b2_Tc_mc_AKGC417L_2.wav successfully.
# Processed file 170_1b2_Tc_mc_AKGC417L_3.wav successfully.
# Processed file 170_1b2_Tc_mc_AKGC417L_4.wav successfully.
# Processed file 170_1b3_Ar_mc_AKGC417L_0.wav successfully.
# Processed file 170_1b3_Ar_mc_AKGC417L_1.wav successfully.
# Processed file 170_1b3_Ar_mc_AKGC417L_2.wav successfully.
# Processed file 170_1b3_Ar_mc_AKGC417L_3.wav successfully.
# Processed file 170_1b3_Ar_mc_AKGC417L_4.wav successfully.
# Processed file 170_1b3_Ar_mc_AKGC417L_5.wav successfully.
# Processed file 170_1b3_Al_mc_AKGC417L_0.wav successfully.
# Processed file 170_1b3_Al_mc_AKGC417L_1.wav successfully.
# Processed file 170_1b3_Al_mc_AKGC417L_2.wav successfully.
# Processed file 170_1b3_Al_mc_AKGC417L_3.wav successfully.
# Processed file 170_1b3_Al_mc_AKGC417L_4.wav successfully.
# Processed file 170_1b3_Al_mc_AKGC417L_5.wav successfully.
# Processed file 170_1b4_Al_mc_AKGC417L_0.wav successfully.
# Processed file 170_1b4_Al_mc_AKGC417L_1.wav successfully.
# Processed file 170_1b4_Al_mc_AKGC417L_2.wav successfully.
# Processed file 170_1b4_Al_mc_AKGC417L_3.wav successfully.
# Processed file 170_1b4_Al_mc_AKGC417L_4.wav successfully.
# Processed file 170_1b4_Al_mc_AKGC417L_5.wav successfully.
# Processed file 170_1b3_Pr_mc_AKGC417L_0.wav successfully.
# Processed file 170_1b3_Pr_mc_AKGC417L_1.wav successfully.
# Processed file 170_1b3_Pr_mc_AKGC417L_2.wav successfully.
# Processed file 170_1b3_Pr_mc_AKGC417L_3.wav successfully.
# Processed file 170_1b3_Pr_mc_AKGC417L_4.wav successfully.
# Processed file 170_1b3_Pr_mc_AKGC417L_5.wav successfully.
# Processed file 170_1b3_Ll_mc_AKGC417L_0.wav successfully.
# Processed file 170_1b3_Ll_mc_AKGC417L_1.wav successfully.
# Processed file 170_1b3_Ll_mc_AKGC417L_2.wav successfully.
# Processed file 170_1b3_Ll_mc_AKGC417L_3.wav successfully.
# Processed file 170_1b3_Ll_mc_AKGC417L_4.wav successfully.
# Processed file 170_1b3_Ll_mc_AKGC417L_5.wav successfully.
# Processed file 170_1b3_Pl_mc_AKGC417L_0.wav successfully.
# Processed file 170_1b3_Pl_mc_AKGC417L_1.wav successfully.
# Processed file 170_1b3_Pl_mc_AKGC417L_2.wav successfully.
# Processed file 170_1b3_Pl_mc_AKGC417L_3.wav successfully.
# Processed file 170_1b3_Pl_mc_AKGC417L_4.wav successfully.
# Processed file 170_1b3_Pl_mc_AKGC417L_5.wav successfully.
# Processed file 170_1b3_Tc_mc_AKGC417L_0.wav successfully.
# Processed file 170_1b3_Tc_mc_AKGC417L_1.wav successfully.
# Processed file 170_1b3_Tc_mc_AKGC417L_2.wav successfully.
# Processed file 170_1b3_Tc_mc_AKGC417L_3.wav successfully.
# Processed file 170_1b3_Tc_mc_AKGC417L_4.wav successfully.
# Processed file 170_1b3_Tc_mc_AKGC417L_5.wav successfully.
# Processed file 170_1b4_Pr_mc_AKGC417L_0.wav successfully.
# Processed file 170_1b4_Pr_mc_AKGC417L_1.wav successfully.
# Processed file 170_1b4_Pr_mc_AKGC417L_2.wav successfully.
# Processed file 170_1b4_Pr_mc_AKGC417L_3.wav successfully.
# Processed file 170_1b4_Pr_mc_AKGC417L_4.wav successfully.
# Processed file 170_1b4_Pr_mc_AKGC417L_5.wav successfully.
# Processed file 170_2b2_Pr_mc_AKGC417L_0.wav successfully.
# Processed file 170_2b2_Pr_mc_AKGC417L_1.wav successfully.
# Processed file 170_2b2_Pr_mc_AKGC417L_2.wav successfully.
# Processed file 170_2b2_Pr_mc_AKGC417L_3.wav successfully.
# Processed file 170_2b2_Pr_mc_AKGC417L_4.wav successfully.
# Processed file 170_2b2_Pr_mc_AKGC417L_5.wav successfully.
# Processed file 170_2b2_Pr_mc_AKGC417L_6.wav successfully.
# Processed file 170_1b4_Lr_mc_AKGC417L_0.wav successfully.
# Processed file 170_1b4_Lr_mc_AKGC417L_1.wav successfully.
# Processed file 170_1b4_Lr_mc_AKGC417L_2.wav successfully.
# Processed file 170_1b4_Lr_mc_AKGC417L_3.wav successfully.
# Processed file 170_1b4_Lr_mc_AKGC417L_4.wav successfully.
# Processed file 170_1b4_Lr_mc_AKGC417L_5.wav successfully.
# Processed file 170_2b2_Ar_mc_AKGC417L_0.wav successfully.
# Processed file 170_2b2_Ar_mc_AKGC417L_1.wav successfully.
# Processed file 170_2b2_Ar_mc_AKGC417L_2.wav successfully.
# Processed file 170_2b2_Ar_mc_AKGC417L_3.wav successfully.
# Processed file 170_2b2_Ar_mc_AKGC417L_4.wav successfully.
# Processed file 170_2b2_Ar_mc_AKGC417L_5.wav successfully.
# Processed file 170_2b2_Ar_mc_AKGC417L_6.wav successfully.
# Processed file 170_1b4_Pl_mc_AKGC417L_0.wav successfully.
# Processed file 170_1b4_Pl_mc_AKGC417L_1.wav successfully.
# Processed file 170_1b4_Pl_mc_AKGC417L_2.wav successfully.
# Processed file 170_1b4_Pl_mc_AKGC417L_3.wav successfully.
# Processed file 170_1b4_Pl_mc_AKGC417L_4.wav successfully.
# Processed file 170_1b4_Pl_mc_AKGC417L_5.wav successfully.
# Processed file 170_2b2_Pl_mc_AKGC417L_0.wav successfully.
# Processed file 170_2b2_Pl_mc_AKGC417L_1.wav successfully.
# Processed file 170_2b2_Pl_mc_AKGC417L_2.wav successfully.
# Processed file 170_2b2_Pl_mc_AKGC417L_3.wav successfully.
# Processed file 170_2b2_Pl_mc_AKGC417L_4.wav successfully.
# Processed file 170_2b2_Pl_mc_AKGC417L_5.wav successfully.
# Processed file 170_2b2_Pl_mc_AKGC417L_6.wav successfully.
# Processed file 170_2b2_Lr_mc_AKGC417L_0.wav successfully.
# Processed file 170_2b2_Lr_mc_AKGC417L_1.wav successfully.
# Processed file 170_2b2_Lr_mc_AKGC417L_2.wav successfully.
# Processed file 170_2b2_Lr_mc_AKGC417L_3.wav successfully.
# Processed file 170_2b2_Lr_mc_AKGC417L_4.wav successfully.
# Processed file 170_2b2_Lr_mc_AKGC417L_5.wav successfully.
# Processed file 170_2b2_Lr_mc_AKGC417L_6.wav successfully.
# Processed file 170_2b2_Tc_mc_AKGC417L_0.wav successfully.
# Processed file 170_2b2_Tc_mc_AKGC417L_1.wav successfully.
# Processed file 170_2b2_Tc_mc_AKGC417L_2.wav successfully.
# Processed file 170_2b2_Tc_mc_AKGC417L_3.wav successfully.
# Processed file 170_2b2_Tc_mc_AKGC417L_4.wav successfully.
# Processed file 170_2b2_Tc_mc_AKGC417L_5.wav successfully.
# Processed file 170_2b2_Tc_mc_AKGC417L_6.wav successfully.
# Processed file 170_1b4_Ar_mc_AKGC417L_0.wav successfully.
# Processed file 170_1b4_Ar_mc_AKGC417L_1.wav successfully.
# Processed file 170_1b4_Ar_mc_AKGC417L_2.wav successfully.
# Processed file 170_1b4_Ar_mc_AKGC417L_3.wav successfully.
# Processed file 170_1b4_Ar_mc_AKGC417L_4.wav successfully.
# Processed file 170_1b4_Ar_mc_AKGC417L_5.wav successfully.
# Processed file 170_1b4_Tc_mc_AKGC417L_0.wav successfully.
# Processed file 170_1b4_Tc_mc_AKGC417L_1.wav successfully.
# Processed file 170_1b4_Tc_mc_AKGC417L_2.wav successfully.
# Processed file 170_1b4_Tc_mc_AKGC417L_3.wav successfully.
# Processed file 170_1b4_Tc_mc_AKGC417L_4.wav successfully.
# Processed file 170_1b4_Tc_mc_AKGC417L_5.wav successfully.
# Processed file 170_2b2_Al_mc_AKGC417L_0.wav successfully.
# Processed file 170_2b2_Al_mc_AKGC417L_1.wav successfully.
# Processed file 170_2b2_Al_mc_AKGC417L_2.wav successfully.
# Processed file 170_2b2_Al_mc_AKGC417L_3.wav successfully.
# Processed file 170_2b2_Al_mc_AKGC417L_4.wav successfully.
# Processed file 170_2b2_Al_mc_AKGC417L_5.wav successfully.
# Processed file 170_2b2_Al_mc_AKGC417L_6.wav successfully.
# Processed file 168_1b1_Al_sc_Meditron_0.wav successfully.
# Processed file 168_1b1_Al_sc_Meditron_1.wav successfully.
# Processed file 168_1b1_Al_sc_Meditron_2.wav successfully.
# Processed file 168_1b1_Al_sc_Meditron_3.wav successfully.
# Processed file 168_1b1_Al_sc_Meditron_4.wav successfully.
# Processed file 168_1b1_Al_sc_Meditron_5.wav successfully.
# Processed file 168_1b1_Al_sc_Meditron_6.wav successfully.
# Processed file 172_1b3_Ll_mc_AKGC417L_0.wav successfully.
# Processed file 172_1b3_Ll_mc_AKGC417L_1.wav successfully.
# Processed file 172_1b3_Ll_mc_AKGC417L_2.wav successfully.
# Processed file 172_1b3_Ll_mc_AKGC417L_3.wav successfully.
# Processed file 172_1b3_Ll_mc_AKGC417L_4.wav successfully.
# Processed file 172_1b3_Ll_mc_AKGC417L_5.wav successfully.
# Processed file 172_1b3_Ll_mc_AKGC417L_6.wav successfully.
# Processed file 172_1b3_Al_mc_AKGC417L_0.wav successfully.
# Processed file 172_1b3_Al_mc_AKGC417L_1.wav successfully.
# Processed file 172_1b3_Al_mc_AKGC417L_2.wav successfully.
# Processed file 172_1b3_Al_mc_AKGC417L_3.wav successfully.
# Processed file 172_1b3_Al_mc_AKGC417L_4.wav successfully.
# Processed file 172_1b3_Al_mc_AKGC417L_5.wav successfully.
# Processed file 172_1b3_Al_mc_AKGC417L_6.wav successfully.
# Processed file 172_1b4_Ar_mc_AKGC417L_0.wav successfully.
# Processed file 172_1b4_Ar_mc_AKGC417L_1.wav successfully.
# Processed file 172_1b4_Ar_mc_AKGC417L_2.wav successfully.
# Processed file 172_1b4_Ar_mc_AKGC417L_3.wav successfully.
# Processed file 172_1b4_Ar_mc_AKGC417L_4.wav successfully.
# Processed file 172_1b4_Ar_mc_AKGC417L_5.wav successfully.
# Processed file 172_1b3_Pl_mc_AKGC417L_0.wav successfully.
# Processed file 172_1b3_Pl_mc_AKGC417L_1.wav successfully.
# Processed file 172_1b3_Pl_mc_AKGC417L_2.wav successfully.
# Processed file 172_1b3_Pl_mc_AKGC417L_3.wav successfully.
# Processed file 172_1b3_Pl_mc_AKGC417L_4.wav successfully.
# Processed file 172_1b3_Pl_mc_AKGC417L_5.wav successfully.
# Processed file 172_1b3_Pl_mc_AKGC417L_6.wav successfully.
# Processed file 172_1b4_Al_mc_AKGC417L_0.wav successfully.
# Processed file 172_1b4_Al_mc_AKGC417L_1.wav successfully.
# Processed file 172_1b4_Al_mc_AKGC417L_2.wav successfully.
# Processed file 172_1b4_Al_mc_AKGC417L_3.wav successfully.
# Processed file 172_1b4_Al_mc_AKGC417L_4.wav successfully.
# Processed file 172_1b4_Al_mc_AKGC417L_5.wav successfully.
# Processed file 172_1b3_Tc_mc_AKGC417L_0.wav successfully.
# Processed file 172_1b3_Tc_mc_AKGC417L_1.wav successfully.
# Processed file 172_1b3_Tc_mc_AKGC417L_2.wav successfully.
# Processed file 172_1b3_Tc_mc_AKGC417L_3.wav successfully.
# Processed file 172_1b3_Tc_mc_AKGC417L_4.wav successfully.
# Processed file 172_1b3_Tc_mc_AKGC417L_5.wav successfully.
# Processed file 172_1b3_Tc_mc_AKGC417L_6.wav successfully.
# Processed file 172_1b3_Pr_mc_AKGC417L_0.wav successfully.
# Processed file 172_1b3_Pr_mc_AKGC417L_1.wav successfully.
# Processed file 172_1b3_Pr_mc_AKGC417L_2.wav successfully.
# Processed file 172_1b3_Pr_mc_AKGC417L_3.wav successfully.
# Processed file 172_1b3_Pr_mc_AKGC417L_4.wav successfully.
# Processed file 172_1b3_Pr_mc_AKGC417L_5.wav successfully.
# Processed file 172_1b3_Pr_mc_AKGC417L_6.wav successfully.
# Processed file 172_1b3_Lr_mc_AKGC417L_0.wav successfully.
# Processed file 172_1b3_Lr_mc_AKGC417L_1.wav successfully.
# Processed file 172_1b3_Lr_mc_AKGC417L_2.wav successfully.
# Processed file 172_1b3_Lr_mc_AKGC417L_3.wav successfully.
# Processed file 172_1b3_Lr_mc_AKGC417L_4.wav successfully.
# Processed file 172_1b3_Lr_mc_AKGC417L_5.wav successfully.
# Processed file 172_1b3_Lr_mc_AKGC417L_6.wav successfully.
# Processed file 172_1b3_Ar_mc_AKGC417L_0.wav successfully.
# Processed file 172_1b3_Ar_mc_AKGC417L_1.wav successfully.
# Processed file 172_1b3_Ar_mc_AKGC417L_2.wav successfully.
# Processed file 172_1b3_Ar_mc_AKGC417L_3.wav successfully.
# Processed file 172_1b3_Ar_mc_AKGC417L_4.wav successfully.
# Processed file 172_1b3_Ar_mc_AKGC417L_5.wav successfully.
# Processed file 172_1b3_Ar_mc_AKGC417L_6.wav successfully.
# Processed file 172_1b4_Pl_mc_AKGC417L_0.wav successfully.
# Processed file 172_1b4_Pl_mc_AKGC417L_1.wav successfully.
# Processed file 172_1b4_Pl_mc_AKGC417L_2.wav successfully.
# Processed file 172_1b4_Pl_mc_AKGC417L_3.wav successfully.
# Processed file 172_1b4_Pl_mc_AKGC417L_4.wav successfully.
# Processed file 172_1b4_Pl_mc_AKGC417L_5.wav successfully.
# Processed file 172_1b4_Lr_mc_AKGC417L_0.wav successfully.
# Processed file 172_1b4_Lr_mc_AKGC417L_1.wav successfully.
# Processed file 172_1b4_Lr_mc_AKGC417L_2.wav successfully.
# Processed file 172_1b4_Lr_mc_AKGC417L_3.wav successfully.
# Processed file 172_1b4_Lr_mc_AKGC417L_4.wav successfully.
# Processed file 172_1b4_Lr_mc_AKGC417L_5.wav successfully.
# Processed file 172_1b5_Ll_mc_AKGC417L_0.wav successfully.
# Processed file 172_1b5_Ll_mc_AKGC417L_1.wav successfully.
# Processed file 172_1b5_Ll_mc_AKGC417L_2.wav successfully.
# Processed file 172_1b5_Ll_mc_AKGC417L_3.wav successfully.
# Processed file 172_1b5_Ll_mc_AKGC417L_4.wav successfully.
# Processed file 172_1b5_Ll_mc_AKGC417L_5.wav successfully.
# Processed file 172_1b5_Ll_mc_AKGC417L_6.wav successfully.
# Processed file 172_1b5_Ar_mc_AKGC417L_0.wav successfully.
# Processed file 172_1b5_Ar_mc_AKGC417L_1.wav successfully.
# Processed file 172_1b5_Ar_mc_AKGC417L_2.wav successfully.
# Processed file 172_1b5_Ar_mc_AKGC417L_3.wav successfully.
# Processed file 172_1b5_Ar_mc_AKGC417L_4.wav successfully.
# Processed file 172_1b5_Ar_mc_AKGC417L_5.wav successfully.
# Processed file 172_1b5_Ar_mc_AKGC417L_6.wav successfully.
# Processed file 172_1b5_Al_mc_AKGC417L_0.wav successfully.
# Processed file 172_1b5_Al_mc_AKGC417L_1.wav successfully.
# Processed file 172_1b5_Al_mc_AKGC417L_2.wav successfully.
# Processed file 172_1b5_Al_mc_AKGC417L_3.wav successfully.
# Processed file 172_1b5_Al_mc_AKGC417L_4.wav successfully.
# Processed file 172_1b5_Al_mc_AKGC417L_5.wav successfully.
# Processed file 172_1b5_Al_mc_AKGC417L_6.wav successfully.
# Processed file 172_1b4_Tc_mc_AKGC417L_0.wav successfully.
# Processed file 172_1b4_Tc_mc_AKGC417L_1.wav successfully.
# Processed file 172_1b4_Tc_mc_AKGC417L_2.wav successfully.
# Processed file 172_1b4_Tc_mc_AKGC417L_3.wav successfully.
# Processed file 172_1b4_Tc_mc_AKGC417L_4.wav successfully.
# Processed file 172_1b4_Tc_mc_AKGC417L_5.wav successfully.
# Processed file 172_1b4_Pr_mc_AKGC417L_0.wav successfully.
# Processed file 172_1b4_Pr_mc_AKGC417L_1.wav successfully.
# Processed file 172_1b4_Pr_mc_AKGC417L_2.wav successfully.
# Processed file 172_1b4_Pr_mc_AKGC417L_3.wav successfully.
# Processed file 172_1b4_Pr_mc_AKGC417L_4.wav successfully.
# Processed file 172_1b4_Pr_mc_AKGC417L_5.wav successfully.
# Processed file 172_1b4_Ll_mc_AKGC417L_0.wav successfully.
# Processed file 172_1b4_Ll_mc_AKGC417L_1.wav successfully.
# Processed file 172_1b4_Ll_mc_AKGC417L_2.wav successfully.
# Processed file 172_1b4_Ll_mc_AKGC417L_3.wav successfully.
# Processed file 172_1b4_Ll_mc_AKGC417L_4.wav successfully.
# Processed file 172_1b4_Ll_mc_AKGC417L_5.wav successfully.
# Processed file 172_1b5_Lr_mc_AKGC417L_0.wav successfully.
# Processed file 172_1b5_Lr_mc_AKGC417L_1.wav successfully.
# Processed file 172_1b5_Lr_mc_AKGC417L_2.wav successfully.
# Processed file 172_1b5_Lr_mc_AKGC417L_3.wav successfully.
# Processed file 172_1b5_Lr_mc_AKGC417L_4.wav successfully.
# Processed file 172_1b5_Lr_mc_AKGC417L_5.wav successfully.
# Processed file 172_1b5_Lr_mc_AKGC417L_6.wav successfully.
# Processed file 172_1b5_Pl_mc_AKGC417L_0.wav successfully.
# Processed file 172_1b5_Pl_mc_AKGC417L_1.wav successfully.
# Processed file 172_1b5_Pl_mc_AKGC417L_2.wav successfully.
# Processed file 172_1b5_Pl_mc_AKGC417L_3.wav successfully.
# Processed file 172_1b5_Pl_mc_AKGC417L_4.wav successfully.
# Processed file 172_1b5_Pl_mc_AKGC417L_5.wav successfully.
# Processed file 172_1b5_Pl_mc_AKGC417L_6.wav successfully.
# Processed file 172_2b5_Al_mc_AKGC417L_0.wav successfully.
# Processed file 172_2b5_Al_mc_AKGC417L_1.wav successfully.
# Processed file 172_2b5_Al_mc_AKGC417L_2.wav successfully.
# Processed file 172_2b5_Al_mc_AKGC417L_3.wav successfully.
# Processed file 172_2b5_Al_mc_AKGC417L_4.wav successfully.
# Processed file 172_2b5_Al_mc_AKGC417L_5.wav successfully.
# Processed file 172_2b5_Pr_mc_AKGC417L_0.wav successfully.
# Processed file 172_2b5_Pr_mc_AKGC417L_1.wav successfully.
# Processed file 172_2b5_Pr_mc_AKGC417L_2.wav successfully.
# Processed file 172_2b5_Pr_mc_AKGC417L_3.wav successfully.
# Processed file 172_2b5_Pr_mc_AKGC417L_4.wav successfully.
# Processed file 172_2b5_Pr_mc_AKGC417L_5.wav successfully.
# Processed file 172_2b5_Ar_mc_AKGC417L_0.wav successfully.
# Processed file 172_2b5_Ar_mc_AKGC417L_1.wav successfully.
# Processed file 172_2b5_Ar_mc_AKGC417L_2.wav successfully.
# Processed file 172_2b5_Ar_mc_AKGC417L_3.wav successfully.
# Processed file 172_2b5_Ar_mc_AKGC417L_4.wav successfully.
# Processed file 172_2b5_Ar_mc_AKGC417L_5.wav successfully.
# Processed file 172_1b5_Pr_mc_AKGC417L_0.wav successfully.
# Processed file 172_1b5_Pr_mc_AKGC417L_1.wav successfully.
# Processed file 172_1b5_Pr_mc_AKGC417L_2.wav successfully.
# Processed file 172_1b5_Pr_mc_AKGC417L_3.wav successfully.
# Processed file 172_1b5_Pr_mc_AKGC417L_4.wav successfully.
# Processed file 172_1b5_Pr_mc_AKGC417L_5.wav successfully.
# Processed file 172_1b5_Pr_mc_AKGC417L_6.wav successfully.
# Processed file 172_2b5_Pl_mc_AKGC417L_0.wav successfully.
# Processed file 172_2b5_Pl_mc_AKGC417L_1.wav successfully.
# Processed file 172_2b5_Pl_mc_AKGC417L_2.wav successfully.
# Processed file 172_2b5_Pl_mc_AKGC417L_3.wav successfully.
# Processed file 172_2b5_Pl_mc_AKGC417L_4.wav successfully.
# Processed file 172_2b5_Pl_mc_AKGC417L_5.wav successfully.
# Processed file 172_1b5_Tc_mc_AKGC417L_0.wav successfully.
# Processed file 172_1b5_Tc_mc_AKGC417L_1.wav successfully.
# Processed file 172_1b5_Tc_mc_AKGC417L_2.wav successfully.
# Processed file 172_1b5_Tc_mc_AKGC417L_3.wav successfully.
# Processed file 172_1b5_Tc_mc_AKGC417L_4.wav successfully.
# Processed file 172_1b5_Tc_mc_AKGC417L_5.wav successfully.
# Processed file 172_1b5_Tc_mc_AKGC417L_6.wav successfully.
# Processed file 172_2b5_Tc_mc_AKGC417L_0.wav successfully.
# Processed file 172_2b5_Tc_mc_AKGC417L_1.wav successfully.
# Processed file 172_2b5_Tc_mc_AKGC417L_2.wav successfully.
# Processed file 172_2b5_Tc_mc_AKGC417L_3.wav successfully.
# Processed file 172_2b5_Tc_mc_AKGC417L_4.wav successfully.
# Processed file 172_2b5_Tc_mc_AKGC417L_5.wav successfully.
# Processed file 172_2b5_Lr_mc_AKGC417L_0.wav successfully.
# Processed file 172_2b5_Lr_mc_AKGC417L_1.wav successfully.
# Processed file 172_2b5_Lr_mc_AKGC417L_2.wav successfully.
# Processed file 172_2b5_Lr_mc_AKGC417L_3.wav successfully.
# Processed file 172_2b5_Lr_mc_AKGC417L_4.wav successfully.
# Processed file 172_2b5_Lr_mc_AKGC417L_5.wav successfully.
# Processed file 171_1b1_Al_sc_Meditron_0.wav successfully.
# Processed file 171_1b1_Al_sc_Meditron_1.wav successfully.
# Processed file 171_1b1_Al_sc_Meditron_2.wav successfully.
# Processed file 171_1b1_Al_sc_Meditron_3.wav successfully.
# Processed file 171_1b1_Al_sc_Meditron_4.wav successfully.
# Processed file 171_1b1_Al_sc_Meditron_5.wav successfully.
# Processed file 171_1b1_Al_sc_Meditron_6.wav successfully.
# Processed file 171_1b1_Al_sc_Meditron_7.wav successfully.
# Processed file 171_1b1_Al_sc_Meditron_8.wav successfully.
# Processed file 173_1b1_Al_sc_Meditron_0.wav successfully.
# Processed file 173_1b1_Al_sc_Meditron_1.wav successfully.
# Processed file 173_1b1_Al_sc_Meditron_2.wav successfully.
# Processed file 173_1b1_Al_sc_Meditron_3.wav successfully.
# Processed file 173_1b1_Al_sc_Meditron_4.wav successfully.
# Processed file 173_1b1_Al_sc_Meditron_5.wav successfully.
# Processed file 173_1b1_Al_sc_Meditron_6.wav successfully.
# Processed file 173_1b1_Al_sc_Meditron_7.wav successfully.
# Processed file 173_1b1_Al_sc_Meditron_8.wav successfully.
# Processed file 173_1b1_Al_sc_Meditron_9.wav successfully.
# Processed file 173_1b1_Al_sc_Meditron_10.wav successfully.
# Processed file 173_1b1_Al_sc_Meditron_11.wav successfully.
# Processed file 173_1b1_Al_sc_Meditron_12.wav successfully.
# ...
# Processed file 157_1b1_Ar_sc_Meditron_11.wav successfully.
# Processed file 157_1b1_Pr_sc_Meditron_0.wav successfully.
# Processed file 157_1b1_Pr_sc_Meditron_1.wav successfully.
# Processed file 157_1b1_Pr_sc_Meditron_2.wav successfully.
# Processed file 157_1b1_Pr_sc_Meditron_3.wav successfully.
# Processed file 157_1b1_Pr_sc_Meditron_4.wav successfully.
# Processed file 157_1b1_Pr_sc_Meditron_5.wav successfully.
# Processed file 157_1b1_Pr_sc_Meditron_6.wav successfully.
# Processed file 157_1b1_Pr_sc_Meditron_7.wav successfully.
# Processed file 157_1b1_Pr_sc_Meditron_8.wav successfully.
# Processed file 157_1b1_Pr_sc_Meditron_9.wav successfully.
# Processed file 157_1b1_Pr_sc_Meditron_10.wav successfully.
# Processed file 157_1b1_Pr_sc_Meditron_11.wav successfully.
# Processed file 157_1b1_Pr_sc_Meditron_12.wav successfully.
# Processed file 157_1b1_Pr_sc_Meditron_13.wav successfully.
# Processed file 157_1b1_Pr_sc_Meditron_14.wav successfully.
# Processed file 158_1p2_Ar_mc_AKGC417L_0.wav successfully.
# Processed file 158_1p2_Ar_mc_AKGC417L_1.wav successfully.
# Processed file 158_1p2_Ar_mc_AKGC417L_2.wav successfully.
# Processed file 158_1p2_Ar_mc_AKGC417L_3.wav successfully.
# Processed file 158_1p2_Ar_mc_AKGC417L_4.wav successfully.
# Processed file 158_1p2_Ar_mc_AKGC417L_5.wav successfully.
# Processed file 158_1p2_Ar_mc_AKGC417L_6.wav successfully.
# Processed file 158_1p2_Ar_mc_AKGC417L_7.wav successfully.
# Processed file 158_1p2_Ll_mc_AKGC417L_0.wav successfully.
# Processed file 158_1p2_Ll_mc_AKGC417L_1.wav successfully.
# Processed file 158_1p2_Ll_mc_AKGC417L_2.wav successfully.
# Processed file 158_1p2_Ll_mc_AKGC417L_3.wav successfully.
# Processed file 158_1p2_Ll_mc_AKGC417L_4.wav successfully.
# Processed file 158_1p2_Ll_mc_AKGC417L_5.wav successfully.
# Processed file 158_1p2_Ll_mc_AKGC417L_6.wav successfully.
# Processed file 158_1p2_Ll_mc_AKGC417L_7.wav successfully.
# Processed file 158_1p3_Ar_mc_AKGC417L_0.wav successfully.
# Processed file 158_1p3_Ar_mc_AKGC417L_1.wav successfully.
# Processed file 158_1p3_Ar_mc_AKGC417L_2.wav successfully.
# Processed file 158_1p3_Ar_mc_AKGC417L_3.wav successfully.
# Processed file 158_1p3_Ar_mc_AKGC417L_4.wav successfully.
# Processed file 158_1p3_Ar_mc_AKGC417L_5.wav successfully.
# Processed file 158_1p3_Ar_mc_AKGC417L_6.wav successfully.
# Processed file 158_1p3_Ar_mc_AKGC417L_7.wav successfully.
# Processed file 158_1p3_Ar_mc_AKGC417L_8.wav successfully.
# Processed file 158_1p3_Ll_mc_AKGC417L_0.wav successfully.
# Processed file 158_1p3_Ll_mc_AKGC417L_1.wav successfully.
# Processed file 158_1p3_Ll_mc_AKGC417L_2.wav successfully.
# Processed file 158_1p3_Ll_mc_AKGC417L_3.wav successfully.
# Processed file 158_1p3_Ll_mc_AKGC417L_4.wav successfully.
# Processed file 158_1p3_Ll_mc_AKGC417L_5.wav successfully.
# Processed file 158_1p3_Ll_mc_AKGC417L_6.wav successfully.
# Processed file 158_1p3_Ll_mc_AKGC417L_7.wav successfully.
# Processed file 158_1p3_Ll_mc_AKGC417L_8.wav successfully.
# Processed file 158_1p2_Pl_mc_AKGC417L_0.wav successfully.
# Processed file 158_1p2_Pl_mc_AKGC417L_1.wav successfully.
# Processed file 158_1p2_Pl_mc_AKGC417L_2.wav successfully.
# Processed file 158_1p2_Pl_mc_AKGC417L_3.wav successfully.
# Processed file 158_1p2_Pl_mc_AKGC417L_4.wav successfully.
# Processed file 158_1p2_Pl_mc_AKGC417L_5.wav successfully.
# Processed file 158_1p2_Pl_mc_AKGC417L_6.wav successfully.
# Processed file 158_1p2_Pl_mc_AKGC417L_7.wav successfully.
# Processed file 158_1p2_Al_mc_AKGC417L_0.wav successfully.
# Processed file 158_1p2_Al_mc_AKGC417L_1.wav successfully.
# Processed file 158_1p2_Al_mc_AKGC417L_2.wav successfully.
# Processed file 158_1p2_Al_mc_AKGC417L_3.wav successfully.
# Processed file 158_1p2_Al_mc_AKGC417L_4.wav successfully.
# Processed file 158_1p2_Al_mc_AKGC417L_5.wav successfully.
# Processed file 158_1p2_Al_mc_AKGC417L_6.wav successfully.
# Processed file 158_1p2_Al_mc_AKGC417L_7.wav successfully.
# Processed file 158_1p3_Al_mc_AKGC417L_0.wav successfully.
# Processed file 158_1p3_Al_mc_AKGC417L_1.wav successfully.
# Processed file 158_1p3_Al_mc_AKGC417L_2.wav successfully.
# Processed file 158_1p3_Al_mc_AKGC417L_3.wav successfully.
# Processed file 158_1p3_Al_mc_AKGC417L_4.wav successfully.
# Processed file 158_1p3_Al_mc_AKGC417L_5.wav successfully.
# Processed file 158_1p3_Al_mc_AKGC417L_6.wav successfully.
# Processed file 158_1p3_Al_mc_AKGC417L_7.wav successfully.
# Processed file 158_1p3_Al_mc_AKGC417L_8.wav successfully.
# Processed file 158_1p2_Pr_mc_AKGC417L_0.wav successfully.
# Processed file 158_1p2_Pr_mc_AKGC417L_1.wav successfully.
# Processed file 158_1p2_Pr_mc_AKGC417L_2.wav successfully.
# Processed file 158_1p2_Pr_mc_AKGC417L_3.wav successfully.
# Processed file 158_1p2_Pr_mc_AKGC417L_4.wav successfully.
# Processed file 158_1p2_Pr_mc_AKGC417L_5.wav successfully.
# Processed file 158_1p2_Pr_mc_AKGC417L_6.wav successfully.
# Processed file 158_1p2_Pr_mc_AKGC417L_7.wav successfully.
# Processed file 158_1p2_Lr_mc_AKGC417L_0.wav successfully.
# Processed file 158_1p2_Lr_mc_AKGC417L_1.wav successfully.
# Processed file 158_1p2_Lr_mc_AKGC417L_2.wav successfully.
# Processed file 158_1p2_Lr_mc_AKGC417L_3.wav successfully.
# Processed file 158_1p2_Lr_mc_AKGC417L_4.wav successfully.
# Processed file 158_1p2_Lr_mc_AKGC417L_5.wav successfully.
# Processed file 158_1p2_Lr_mc_AKGC417L_6.wav successfully.
# Processed file 158_1p2_Lr_mc_AKGC417L_7.wav successfully.
# Processed file 158_1b3_Ar_mc_LittC2SE_0.wav successfully.
# Processed file 158_1b3_Ar_mc_LittC2SE_1.wav successfully.
# Processed file 158_1b3_Ar_mc_LittC2SE_2.wav successfully.
# Processed file 158_1b3_Ar_mc_LittC2SE_3.wav successfully.
# Processed file 158_1b3_Ar_mc_LittC2SE_4.wav successfully.
# Processed file 158_1b3_Ar_mc_LittC2SE_5.wav successfully.
# Processed file 158_1b3_Ar_mc_LittC2SE_6.wav successfully.
# Processed file 158_1b3_Ar_mc_LittC2SE_7.wav successfully.
# Processed file 158_1b3_Ar_mc_LittC2SE_8.wav successfully.
# Processed file 158_1b3_Ar_mc_LittC2SE_9.wav successfully.
# Processed file 158_1b3_Ar_mc_LittC2SE_10.wav successfully.
# Processed file 158_1p2_Tc_mc_AKGC417L_0.wav successfully.
# Processed file 158_1p2_Tc_mc_AKGC417L_1.wav successfully.
# Processed file 158_1p2_Tc_mc_AKGC417L_2.wav successfully.
# Processed file 158_1p2_Tc_mc_AKGC417L_3.wav successfully.
# Processed file 158_1p2_Tc_mc_AKGC417L_4.wav successfully.
# Processed file 158_1p2_Tc_mc_AKGC417L_5.wav successfully.
# Processed file 158_1p2_Tc_mc_AKGC417L_6.wav successfully.
# Processed file 158_1p2_Tc_mc_AKGC417L_7.wav successfully.
# Processed file 158_1p3_Pr_mc_AKGC417L_0.wav successfully.
# Processed file 158_1p3_Pr_mc_AKGC417L_1.wav successfully.
# Processed file 158_1p3_Pr_mc_AKGC417L_2.wav successfully.
# Processed file 158_1p3_Pr_mc_AKGC417L_3.wav successfully.
# Processed file 158_1p3_Pr_mc_AKGC417L_4.wav successfully.
# Processed file 158_1p3_Pr_mc_AKGC417L_5.wav successfully.
# Processed file 158_1p3_Pr_mc_AKGC417L_6.wav successfully.
# Processed file 158_1p3_Pr_mc_AKGC417L_7.wav successfully.
# Processed file 158_1p3_Pr_mc_AKGC417L_8.wav successfully.
# Processed file 158_1p4_Pl_mc_AKGC417L_0.wav successfully.
# Processed file 158_1p4_Pl_mc_AKGC417L_1.wav successfully.
# Processed file 158_1p4_Pl_mc_AKGC417L_2.wav successfully.
# Processed file 158_1p4_Pl_mc_AKGC417L_3.wav successfully.
# Processed file 158_1p4_Pl_mc_AKGC417L_4.wav successfully.
# Processed file 158_1p4_Pl_mc_AKGC417L_5.wav successfully.
# Processed file 158_1p4_Pl_mc_AKGC417L_6.wav successfully.
# Processed file 158_1p4_Pl_mc_AKGC417L_7.wav successfully.
# Processed file 158_1p4_Pl_mc_AKGC417L_8.wav successfully.
# Processed file 158_1p4_Lr_mc_AKGC417L_0.wav successfully.
# Processed file 158_1p4_Lr_mc_AKGC417L_1.wav successfully.
# Processed file 158_1p4_Lr_mc_AKGC417L_2.wav successfully.
# Processed file 158_1p4_Lr_mc_AKGC417L_3.wav successfully.
# Processed file 158_1p4_Lr_mc_AKGC417L_4.wav successfully.
# Processed file 158_1p4_Lr_mc_AKGC417L_5.wav successfully.
# Processed file 158_1p4_Lr_mc_AKGC417L_6.wav successfully.
# Processed file 158_1p4_Lr_mc_AKGC417L_7.wav successfully.
# Processed file 158_1p4_Lr_mc_AKGC417L_8.wav successfully.
# Processed file 158_1p4_Al_mc_AKGC417L_0.wav successfully.
# Processed file 158_1p4_Al_mc_AKGC417L_1.wav successfully.
# Processed file 158_1p4_Al_mc_AKGC417L_2.wav successfully.
# Processed file 158_1p4_Al_mc_AKGC417L_3.wav successfully.
# Processed file 158_1p4_Al_mc_AKGC417L_4.wav successfully.
# Processed file 158_1p4_Al_mc_AKGC417L_5.wav successfully.
# Processed file 158_1p4_Al_mc_AKGC417L_6.wav successfully.
# Processed file 158_1p4_Al_mc_AKGC417L_7.wav successfully.
# Processed file 158_1p4_Al_mc_AKGC417L_8.wav successfully.
# Processed file 158_1p3_Tc_mc_AKGC417L_0.wav successfully.
# Processed file 158_1p3_Tc_mc_AKGC417L_1.wav successfully.
# Processed file 158_1p3_Tc_mc_AKGC417L_2.wav successfully.
# Processed file 158_1p3_Tc_mc_AKGC417L_3.wav successfully.
# Processed file 158_1p3_Tc_mc_AKGC417L_4.wav successfully.
# Processed file 158_1p3_Tc_mc_AKGC417L_5.wav successfully.
# Processed file 158_1p3_Tc_mc_AKGC417L_6.wav successfully.
# Processed file 158_1p3_Tc_mc_AKGC417L_7.wav successfully.
# Processed file 158_1p3_Tc_mc_AKGC417L_8.wav successfully.
# Processed file 158_1p3_Lr_mc_AKGC417L_0.wav successfully.
# Processed file 158_1p3_Lr_mc_AKGC417L_1.wav successfully.
# Processed file 158_1p3_Lr_mc_AKGC417L_2.wav successfully.
# Processed file 158_1p3_Lr_mc_AKGC417L_3.wav successfully.
# Processed file 158_1p3_Lr_mc_AKGC417L_4.wav successfully.
# Processed file 158_1p3_Lr_mc_AKGC417L_5.wav successfully.
# Processed file 158_1p3_Lr_mc_AKGC417L_6.wav successfully.
# Processed file 158_1p3_Lr_mc_AKGC417L_7.wav successfully.
# Processed file 158_1p3_Lr_mc_AKGC417L_8.wav successfully.
# Processed file 158_2p3_Lr_mc_AKGC417L_0.wav successfully.
# Processed file 158_2p3_Lr_mc_AKGC417L_1.wav successfully.
# Processed file 158_2p3_Lr_mc_AKGC417L_2.wav successfully.
# Processed file 158_2p3_Lr_mc_AKGC417L_3.wav successfully.
# Processed file 158_2p3_Lr_mc_AKGC417L_4.wav successfully.
# Processed file 158_2p3_Lr_mc_AKGC417L_5.wav successfully.
# Processed file 158_2p3_Lr_mc_AKGC417L_6.wav successfully.
# Processed file 158_2p3_Lr_mc_AKGC417L_7.wav successfully.
# Processed file 158_2p3_Lr_mc_AKGC417L_8.wav successfully.
# Processed file 158_2p3_Lr_mc_AKGC417L_9.wav successfully.
# Processed file 158_2p3_Lr_mc_AKGC417L_10.wav successfully.
# Processed file 158_2p3_Lr_mc_AKGC417L_11.wav successfully.
# Processed file 158_1p4_Pr_mc_AKGC417L_0.wav successfully.
# Processed file 158_1p4_Pr_mc_AKGC417L_1.wav successfully.
# Processed file 158_1p4_Pr_mc_AKGC417L_2.wav successfully.
# Processed file 158_1p4_Pr_mc_AKGC417L_3.wav successfully.
# Processed file 158_1p4_Pr_mc_AKGC417L_4.wav successfully.
# Processed file 158_1p4_Pr_mc_AKGC417L_5.wav successfully.
# Processed file 158_1p4_Pr_mc_AKGC417L_6.wav successfully.
# Processed file 158_1p4_Pr_mc_AKGC417L_7.wav successfully.
# Processed file 158_1p4_Pr_mc_AKGC417L_8.wav successfully.
# Processed file 158_1p3_Pl_mc_AKGC417L_0.wav successfully.
# Processed file 158_1p3_Pl_mc_AKGC417L_1.wav successfully.
# Processed file 158_1p3_Pl_mc_AKGC417L_2.wav successfully.
# Processed file 158_1p3_Pl_mc_AKGC417L_3.wav successfully.
# Processed file 158_1p3_Pl_mc_AKGC417L_4.wav successfully.
# Processed file 158_1p3_Pl_mc_AKGC417L_5.wav successfully.
# Processed file 158_1p3_Pl_mc_AKGC417L_6.wav successfully.
# Processed file 158_1p3_Pl_mc_AKGC417L_7.wav successfully.
# Processed file 158_1p3_Pl_mc_AKGC417L_8.wav successfully.
# Processed file 158_2p2_Ar_mc_AKGC417L_0.wav successfully.
# Processed file 158_2p2_Ar_mc_AKGC417L_1.wav successfully.
# Processed file 158_2p2_Ar_mc_AKGC417L_2.wav successfully.
# Processed file 158_2p2_Ar_mc_AKGC417L_3.wav successfully.
# Processed file 158_2p2_Ar_mc_AKGC417L_4.wav successfully.
# Processed file 158_2p2_Ar_mc_AKGC417L_5.wav successfully.
# Processed file 158_2p2_Ar_mc_AKGC417L_6.wav successfully.
# Processed file 158_2p2_Ar_mc_AKGC417L_7.wav successfully.
# Processed file 158_2p2_Ar_mc_AKGC417L_8.wav successfully.
# Processed file 158_1p4_Tc_mc_AKGC417L_0.wav successfully.
# Processed file 158_1p4_Tc_mc_AKGC417L_1.wav successfully.
# Processed file 158_1p4_Tc_mc_AKGC417L_2.wav successfully.
# Processed file 158_1p4_Tc_mc_AKGC417L_3.wav successfully.
# Processed file 158_1p4_Tc_mc_AKGC417L_4.wav successfully.
# Processed file 158_1p4_Tc_mc_AKGC417L_5.wav successfully.
# Processed file 158_1p4_Tc_mc_AKGC417L_6.wav successfully.
# Processed file 158_1p4_Tc_mc_AKGC417L_7.wav successfully.
# Processed file 158_1p4_Tc_mc_AKGC417L_8.wav successfully.
# Processed file 158_1p4_Ar_mc_AKGC417L_0.wav successfully.
# Processed file 158_1p4_Ar_mc_AKGC417L_1.wav successfully.
# Processed file 158_1p4_Ar_mc_AKGC417L_2.wav successfully.
# Processed file 158_1p4_Ar_mc_AKGC417L_3.wav successfully.
# Processed file 158_1p4_Ar_mc_AKGC417L_4.wav successfully.
# Processed file 158_1p4_Ar_mc_AKGC417L_5.wav successfully.
# Processed file 158_1p4_Ar_mc_AKGC417L_6.wav successfully.
# Processed file 158_1p4_Ar_mc_AKGC417L_7.wav successfully.
# Processed file 158_1p4_Ar_mc_AKGC417L_8.wav successfully.
# Processed file 158_2p3_Tc_mc_AKGC417L_0.wav successfully.
# Processed file 158_2p3_Tc_mc_AKGC417L_1.wav successfully.
# Processed file 158_2p3_Tc_mc_AKGC417L_2.wav successfully.
# Processed file 158_2p3_Tc_mc_AKGC417L_3.wav successfully.
# Processed file 158_2p3_Tc_mc_AKGC417L_4.wav successfully.
# Processed file 158_2p3_Tc_mc_AKGC417L_5.wav successfully.
# Processed file 158_2p3_Tc_mc_AKGC417L_6.wav successfully.
# Processed file 158_2p3_Tc_mc_AKGC417L_7.wav successfully.
# Processed file 158_2p3_Tc_mc_AKGC417L_8.wav successfully.
# Processed file 158_2p3_Tc_mc_AKGC417L_9.wav successfully.
# Processed file 158_2p3_Tc_mc_AKGC417L_10.wav successfully.
# Processed file 158_2p3_Tc_mc_AKGC417L_11.wav successfully.
# Processed file 159_1b1_Al_sc_Meditron_0.wav successfully.
# Processed file 159_1b1_Al_sc_Meditron_1.wav successfully.
# Processed file 159_1b1_Al_sc_Meditron_2.wav successfully.
# Processed file 159_1b1_Al_sc_Meditron_3.wav successfully.
# Processed file 159_1b1_Al_sc_Meditron_4.wav successfully.
# Processed file 159_1b1_Al_sc_Meditron_5.wav successfully.
# Processed file 159_1b1_Al_sc_Meditron_6.wav successfully.
# Processed file 159_1b1_Al_sc_Meditron_7.wav successfully.
# Processed file 159_1b1_Al_sc_Meditron_8.wav successfully.
# Processed file 159_1b1_Al_sc_Meditron_9.wav successfully.
# Processed file 159_1b1_Al_sc_Meditron_10.wav successfully.
# Processed file 159_1b1_Al_sc_Meditron_11.wav successfully.
# Processed file 159_1b1_Ar_sc_Meditron_0.wav successfully.
# Processed file 159_1b1_Ar_sc_Meditron_1.wav successfully.
# Processed file 159_1b1_Ar_sc_Meditron_2.wav successfully.
# Processed file 159_1b1_Ar_sc_Meditron_3.wav successfully.
# Processed file 159_1b1_Ar_sc_Meditron_4.wav successfully.
# Processed file 159_1b1_Ar_sc_Meditron_5.wav successfully.
# Processed file 159_1b1_Ar_sc_Meditron_6.wav successfully.
# Processed file 159_1b1_Ar_sc_Meditron_7.wav successfully.
# Processed file 159_1b1_Ar_sc_Meditron_8.wav successfully.
# Processed file 159_1b1_Ll_sc_Meditron_0.wav successfully.
# Processed file 159_1b1_Ll_sc_Meditron_1.wav successfully.
# Processed file 159_1b1_Ll_sc_Meditron_2.wav successfully.
# Processed file 159_1b1_Ll_sc_Meditron_3.wav successfully.
# Processed file 159_1b1_Ll_sc_Meditron_4.wav successfully.
# Processed file 159_1b1_Ll_sc_Meditron_5.wav successfully.
# Processed file 159_1b1_Ll_sc_Meditron_6.wav successfully.
# Processed file 159_1b1_Ll_sc_Meditron_7.wav successfully.
# Processed file 159_1b1_Ll_sc_Meditron_8.wav successfully.
# Processed file 159_1b1_Ll_sc_Meditron_9.wav successfully.
# Processed file 159_1b1_Ll_sc_Meditron_10.wav successfully.
# Processed file 159_1b1_Ll_sc_Meditron_11.wav successfully.
# Processed file 159_1b1_Pr_sc_Meditron_0.wav successfully.
# Processed file 159_1b1_Pr_sc_Meditron_1.wav successfully.
# Processed file 159_1b1_Pr_sc_Meditron_2.wav successfully.
# Processed file 159_1b1_Pr_sc_Meditron_3.wav successfully.
# Processed file 159_1b1_Pr_sc_Meditron_4.wav successfully.
# Processed file 159_1b1_Pr_sc_Meditron_5.wav successfully.
# Processed file 159_1b1_Pr_sc_Meditron_6.wav successfully.
# Processed file 159_1b1_Pr_sc_Meditron_7.wav successfully.
# Processed file 159_1b1_Pr_sc_Meditron_8.wav successfully.
# Total Files Processed:  6931

# %% [markdown]
# ## EDA, Handling Imbalance & Creating Spectrogram

# %%
patient_info = pd.read_csv("/content/drive/MyDrive/My Projects/respiratory_disorder_classification/demographic_info.txt", names=['Patient', 'Age', 'Sex', 'BMI', 'Weight', 'Height'], delim_whitespace=True)

# %%
patient_info.head()
# Out:
#    Patient    Age Sex    BMI  Weight  Height
# 0      101   3.00   F    NaN    19.0    99.0
# 1      102   0.75   F    NaN     9.8    73.0
# 2      103  70.00   F  33.00     NaN     NaN
# 3      104  70.00   F  28.47     NaN     NaN
# 4      105   7.00   F    NaN    32.0   135.0

# %%
patient_info['Sex'].value_counts()
# Out:
# M    79
# F    46
# Name: Sex, dtype: int64

# %%
plt.pie(patient_info['Sex'].value_counts(), labels = ['M','F'], autopct='%1.1f%%')
plt.title("Gender Distribution", fontsize=22, pad=50.0)
plt.legend(fontsize=12, loc='best', bbox_to_anchor=(1, 1));
plt.show()

# %%
import IPython.display as ipd

# %%
'''
Loading And Playing Audio Files
'''
filePath = '/content/drive/MyDrive/My Projects/respiratory_disorder_classification/processed_audio_files/226_1b1_Pl_sc_LittC2SE_7.wav'
ipd.Audio(filePath)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# librosa can convert stereo to mono audio
audio1,sample_rate1 = librosa.load(filePath,  mono=True)

# %%
'''
The sampling rate is the number of samples per second. Hz or Hertz is the unit of the sampling rate.
20 kHz is the audible range for human beings.
'''

librosa.display.waveshow(audio1,sr=sample_rate1, max_points=50000, x_axis='time', offset=0)
# Out:
# <ipython-input-29-b3251167e771>:6: FutureWarning: waveshow() keyword argument 'x_axis' has been renamed to 'axis' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   librosa.display.waveshow(audio1,sr=sample_rate1, max_points=50000, x_axis='time', offset=0)

# %%
import seaborn as sns
# patient_data = pd.read_csv('Respiratory_Sound_Database\Respiratory_Sound_Database\patient_diagnosis.csv',names=['pid','disease'])
patient_data.head()
# Out:
#    pid  disease
# 0  101     URTI
# 1  102  Healthy
# 2  103   Asthma
# 3  104     COPD
# 4  105     URTI

# %%
sns.countplot(x = 'disease', data = patient_data, palette = "bright")
plt.xticks(rotation=90)
# Out:
# <ipython-input-31-2fee0f544d75>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'disease', data = patient_data, palette = "bright")
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'URTI'),
#   Text(1, 0, 'Healthy'),
#   Text(2, 0, 'Asthma'),
#   Text(3, 0, 'COPD'),
#   Text(4, 0, 'LRTI'),
#   Text(5, 0, 'Bronchiectasis'),
#   Text(6, 0, 'Pneumonia'),
#   Text(7, 0, 'Bronchiolitis')])

# %%
# show count of each category in a column
patient_data['disease'].value_counts()
# Out:
# COPD              64
# Healthy           26
# URTI              14
# Bronchiectasis     7
# Pneumonia          6
# Bronchiolitis      6
# LRTI               2
# Asthma             1
# Name: disease, dtype: int64

# %% [markdown]
# We can see that classes are imbalanced so we must split them into train and validation set via stratify.
#
# We will try to extract Id of each processed audio file and then merge them with their respective class label so we can split files in to train and validation folder in stratified manner.

# %%
def extractId(filename):
    return filename.split('_')[0]

# %%
path='/content/drive/MyDrive/My Projects/respiratory_disorder_classification/processed_audio_files'
length=len(os.listdir(path))
index=range(length)
i=0
files_df=pd.DataFrame(index=index,columns=['pid','filename'])
for f in os.listdir(path):
    files_df.iloc[i]['pid']=extractId(f)
    files_df.iloc[i]['filename']=f
    i+=1
files_df.head()
# Out:
#    pid                       filename
# 0  147   147_1b2_Tc_mc_AKGC417L_7.wav
# 1  147   147_1b2_Tc_mc_AKGC417L_8.wav
# 2  147  147_1b2_Tc_mc_AKGC417L_11.wav
# 3  147  147_1b2_Tc_mc_AKGC417L_10.wav
# 4  147   147_2b3_Ar_mc_AKGC417L_0.wav

# %%
files_df.pid=files_df.pid.astype('int64') # both pid's must be of same dtype for them to merge

# %%
data=pd.merge(files_df,patient_data,on='pid')
data.head()
# Out:
#    pid                       filename disease
# 0  147   147_1b2_Tc_mc_AKGC417L_7.wav    COPD
# 1  147   147_1b2_Tc_mc_AKGC417L_8.wav    COPD
# 2  147  147_1b2_Tc_mc_AKGC417L_11.wav    COPD
# 3  147  147_1b2_Tc_mc_AKGC417L_10.wav    COPD
# 4  147   147_2b3_Ar_mc_AKGC417L_0.wav    COPD

# %%
sns.countplot(x = 'disease', data = patient_data)
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'URTI'),
#   Text(1, 0, 'Healthy'),
#   Text(2, 0, 'Asthma'),
#   Text(3, 0, 'COPD'),
#   Text(4, 0, 'LRTI'),
#   Text(5, 0, 'Bronchiectasis'),
#   Text(6, 0, 'Pneumonia'),
#   Text(7, 0, 'Bronchiolitis')])

# %% [markdown]
# We can see that classes are very skewed

# %%
from sklearn.model_selection import train_test_split
Xtrain,Xval,ytrain,yval=train_test_split(data,data.disease,stratify=data.disease,random_state=42,test_size=0.25)

# %% [markdown]
# stratify data based on class labels and split accordingly

# %%
Xtrain.disease.value_counts()/Xtrain.shape[0]
# Out:
# COPD              0.832979
# Healthy           0.046588
# Pneumonia         0.041369
# URTI              0.035183
# Bronchiolitis     0.023197
# Bronchiectasis    0.015078
# LRTI              0.004639
# Asthma            0.000967
# Name: disease, dtype: float64

# %%
Xval.disease.value_counts()/Xval.shape[0]
# Out:
# COPD              0.833043
# Healthy           0.046957
# Pneumonia         0.041159
# URTI              0.035362
# Bronchiolitis     0.023188
# Bronchiectasis    0.015072
# LRTI              0.004638
# Asthma            0.000580
# Name: disease, dtype: float64

# %% [markdown]
# % of class labels is same in both train and val data set

# %% [markdown]
# This will help our model to learn and validate classes , it will not be like we are training only on COPD disease and there is no COPD in our validation

# %% [markdown]
# Visualizing Mel-Frequency Cepstral Coefficients (MFCCS)

# %%
# Using one file for demo
sound,sample_rate=lb.load(filePath)
mfccs = lb.feature.mfcc(y=sound, sr=sample_rate, n_mfcc=40)
fig, ax = plt.subplots()
img = librosa.display.specshow(mfccs, x_axis='time', ax=ax)
fig.colorbar(img, ax=ax)
ax.set(title='MFCC')
# Out:
# [Text(0.5, 1.0, 'MFCC')]

# %% [markdown]
# x-axis = time, y-axis = decibels

# %%
mfccs.shape
# Out:
# (40, 259)

# %% [markdown]
# The first dimension (40) is the number of MFCC coefficients, and the second dimensions (1876) is the number of time frames. The number of MFCC is specified by n_mfcc, and the number of time frames is given by the length of the audio (in samples) divided by the hop_length

# %%
Xtrain.head()
# Out:
#       pid                      filename  disease
# 1580  132  132_2b1_Lr_mc_LittC2SE_5.wav     COPD
# 2271  143  143_1b1_Al_sc_Meditron_7.wav  Healthy
# 552   154  154_4b4_Pr_mc_AKGC417L_4.wav     COPD
# 3627  225  225_1b1_Pl_sc_Meditron_6.wav  Healthy
# 1349  130  130_2b2_Pl_mc_AKGC417L_6.wav     COPD

# %%
ytrain.head()
# Out:
# 1580       COPD
# 2271    Healthy
# 552        COPD
# 3627    Healthy
# 1349       COPD
# Name: disease, dtype: object

# %%
Xval.head()
# Out:
#       pid                      filename disease
# 3612  222  222_1b1_Ar_sc_Meditron_1.wav    COPD
# 3341  218  218_1b1_Pl_sc_Meditron_4.wav    COPD
# 920   158  158_1p3_Lr_mc_AKGC417L_7.wav    COPD
# 651   156  156_2b3_Pl_mc_AKGC417L_1.wav    COPD
# 5161  174  174_1p2_Ll_mc_AKGC417L_2.wav    COPD

# %%
yval.head
# Out:
# <bound method NDFrame.head of 3612    COPD
# 3341    COPD
# 920     COPD
# 651     COPD
# 5161    COPD
#         ...
# 1720    COPD
# 4990    COPD
# 5309    COPD
# 2794    COPD
# 1749    COPD
# Name: disease, Length: 1725, dtype: object>

# %%
import os

TrainingFileExist = os.path.exists('/content/drive/MyDrive/My Projects/respiratory_disorder_classification/training')
ValidationFileExist = os.path.exists('/content/drive/MyDrive/My Projects/respiratory_disorder_classification/validation')

if not TrainingFileExist:
    os.makedirs('/content/drive/MyDrive/My Projects/respiratory_disorder_classification/training')
    Xtrain.to_csv('/content/drive/MyDrive/My Projects/respiratory_disorder_classification/training/train.csv')

if not ValidationFileExist:
    os.makedirs('/content/drive/MyDrive/My Projects/respiratory_disorder_classification/validation')
    Xval.to_csv('/content/drive/MyDrive/My Projects/respiratory_disorder_classification/validation/val.csv')

# %% [markdown]
# Further Steps:
# - Feature Extraction using MFCC, Chroma STFT, Mel Spectrogram
# - Building Our Neural Network Model
# - Testing the model
# - comparing our model
# - Developing flask app for our model deployment

# %%
train=pd.read_csv('/content/drive/MyDrive/My Projects/respiratory_disorder_classification/training/train.csv')
val=pd.read_csv('/content/drive/MyDrive/My Projects/respiratory_disorder_classification/validation/val.csv')
train.head()
# Out:
#    Unnamed: 0  pid                      filename  disease
# 0        1567  186  186_2b3_Tc_mc_AKGC417L_1.wav     COPD
# 1        3129  217  217_1b1_Tc_sc_Meditron_6.wav  Healthy
# 2         567  170  170_2b2_Ar_mc_AKGC417L_0.wav     COPD
# 3        4513  125  125_1b1_Tc_sc_Meditron_0.wav  Healthy
# 4        1335  178  178_1b6_Ll_mc_AKGC417L_1.wav     COPD

# %%
ytrain=train.disease
yval=val.disease
yval
# Out:
# 0       COPD
# 1       COPD
# 2       COPD
# 3       COPD
# 4       COPD
#         ...
# 1720    COPD
# 1721    COPD
# 1722    COPD
# 1723    COPD
# 1724    COPD
# Name: disease, Length: 1725, dtype: object

# %%
yval.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1725 entries, 0 to 1724
# Series name: disease
# Non-Null Count  Dtype
# --------------  -----
# 1725 non-null   object
# dtypes: object(1)
# memory usage: 13.6+ KB

# %% [markdown]
# class labels are of dtype: object we must first convert them to encoded values or intergers

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
ytrain=le.fit_transform(ytrain)
yval=le.transform(yval)

# %%
yval
# Out:
# array([3, 3, 3, ..., 3, 3, 3])

# %% [markdown]
# ## Feature Extraction

# %%
def getFeatures(path):
    soundArr,sample_rate=lb.load(path)
    mfcc=lb.feature.mfcc(y=soundArr,sr=sample_rate)
    cstft=lb.feature.chroma_stft(y=soundArr,sr=sample_rate)
    mSpec=lb.feature.melspectrogram(y=soundArr,sr=sample_rate)
    return mfcc,cstft,mSpec

# %% [markdown]
# In These functions we are iterating over train and val dataset, and using filenames to extract features and then converting them to numpy arrays

# %%
root='/content/drive/MyDrive/My Projects/respiratory_disorder_classification/processed_audio_files/'
mfcc,cstft,mSpec = [],[],[]

for idx,row in train.iterrows():
    path=root + row['filename']
    a,b,c=getFeatures(path)
    mfcc.append(a)
    cstft.append(b)
    mSpec.append(c)

mfcc_train=np.array(mfcc)
cstft_train=np.array(cstft)
mSpec_train=np.array(mSpec)
# Out:
# /usr/local/lib/python3.10/dist-packages/librosa/core/pitch.py:101: UserWarning: Trying to estimate tuning from empty frequency set.
#   return pitch_tuning(

# %%
mfcc_train
# Out:
# array([[[-3.63721466e+02, -3.84499359e+02, -4.00248596e+02, ...,
#          -4.91153015e+02, -4.91153015e+02, -4.91153015e+02],
#         [ 1.12430931e+02,  1.08334152e+02,  1.01900085e+02, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 3.29160118e+01,  4.33921127e+01,  5.23206177e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         ...,
#         [ 7.26463795e+00,  1.12937250e+01,  9.72031784e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 4.11883450e+00,  7.43141747e+00,  7.47712326e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 5.22984505e+00,  5.24107695e+00,  3.25792217e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[-4.73410583e+02, -5.15877258e+02, -5.49301880e+02, ...,
#          -6.84740906e+02, -6.84740906e+02, -6.84740906e+02],
#         [ 1.04842514e+02,  9.46024704e+01,  9.03846130e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 2.78377514e+01,  3.80125275e+01,  4.31751671e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         ...,
#         [ 6.79416943e+00,  1.03055420e+01,  7.15180826e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 3.62815571e+00,  4.33410788e+00,  2.09957838e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 6.31051493e+00,  7.82261181e+00,  3.21465445e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[-2.46311951e+02, -2.95958252e+02, -3.52120239e+02, ...,
#          -5.08606262e+02, -5.08606262e+02, -5.08606262e+02],
#         [ 1.07275932e+02,  1.05540573e+02,  9.36361465e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 2.28717728e+01,  2.76066113e+01,  2.71950874e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         ...,
#         [ 3.70883703e+00,  5.54833746e+00,  6.07305479e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 4.17888069e+00,  6.27184486e+00,  1.05717821e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 4.32378387e+00,  6.04220581e+00,  9.07763100e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        ...,
#
#        [[-3.36110291e+02, -3.10545288e+02, -2.99062775e+02, ...,
#          -4.67424591e+02, -4.67424591e+02, -4.67424591e+02],
#         [ 1.24829643e+02,  1.34168549e+02,  1.41018127e+02, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 5.48213806e+01,  5.36365662e+01,  4.81060638e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         ...,
#         [ 1.03293514e+01,  1.14510250e+01,  1.01063080e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 6.67661047e+00,  6.71947098e+00,  2.16426301e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 5.26530361e+00,  4.48703384e+00, -7.32155204e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[-2.30242065e+02, -2.89925201e+02, -4.02307404e+02, ...,
#          -5.36847595e+02, -5.36847595e+02, -5.36847595e+02],
#         [ 1.10299393e+02,  1.16042542e+02,  1.18044502e+02, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 2.48362122e+01,  3.13674469e+01,  4.92503777e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         ...,
#         [ 3.93399286e+00,  7.45942020e+00,  1.09027786e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 3.85122514e+00,  7.40920734e+00,  9.84410477e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 4.01954460e+00,  7.66304255e+00,  1.23792839e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[-3.54270111e+02, -3.57715485e+02, -3.64312469e+02, ...,
#          -5.52639587e+02, -5.52639587e+02, -5.52639587e+02],
#         [ 1.09529854e+02,  1.07932716e+02,  1.07503426e+02, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 1.83073502e+01,  1.19437065e+01,  1.34955120e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         ...,
#         [ 1.25011749e+01,  9.31584263e+00,  7.24291229e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 4.25459671e+00, -5.93649037e-02, -3.06393003e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 4.43194675e+00,  5.53220797e+00,  2.39626145e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]]],
#       dtype=float32)

# %%
# saving variables so we do not have to extract them again
# convert 3d arr to 2d to save it
# while loading need to reshape back to 3d

mfcc_reshaped = mfcc_train.reshape(mfcc_train.shape[0], -1)
cstft_reshaped = cstft_train.reshape(cstft_train.shape[0], -1)
mSpec_reshaped = mSpec_train.reshape(mSpec_train.shape[0], -1)
print(mfcc_reshaped)
np.savetxt('mfcc_variable_train.txt', mfcc_reshaped)
np.savetxt('cstft_variable_train.txt', cstft_reshaped)
np.savetxt('mSpec_variable_train.txt', mSpec_reshaped)
# Out:
# [[-363.72147 -384.49936 -400.2486  ...    0.         0.         0.     ]
#  [-473.41058 -515.87726 -549.3019  ...    0.         0.         0.     ]
#  [-246.31195 -295.95825 -352.12024 ...    0.         0.         0.     ]
#  ...
#  [-336.1103  -310.5453  -299.06277 ...    0.         0.         0.     ]
#  [-230.24207 -289.9252  -402.3074  ...    0.         0.         0.     ]
#  [-354.2701  -357.71548 -364.31247 ...    0.         0.         0.     ]]

# %%
# loading variable files
mfcc_train = np.loadtxt('mfcc_variable_train.txt')
cstft_train = np.loadtxt('cstft_variable_train.txt')
mSpec_train = np.loadtxt('mSpec_variable_train.txt')

# %%
mfcc_train
# Out:
# array([[-363.72146606, -384.49935913, -400.24859619, ...,    0.        ,
#            0.        ,    0.        ],
#        [-473.4105835 , -515.8772583 , -549.30187988, ...,    0.        ,
#            0.        ,    0.        ],
#        [-246.31195068, -295.95825195, -352.12023926, ...,    0.        ,
#            0.        ,    0.        ],
#        ...,
#        [-336.11029053, -310.54528809, -299.06277466, ...,    0.        ,
#            0.        ,    0.        ],
#        [-230.24206543, -289.92520142, -402.30740356, ...,    0.        ,
#            0.        ,    0.        ],
#        [-354.27011108, -357.71548462, -364.31246948, ...,    0.        ,
#            0.        ,    0.        ]])

# %%
# back to original variable
mfcc_train = mfcc_train.reshape(
    mfcc_train.shape[0], mfcc_train.shape[1] // 259 , 259)

mfcc_train   # original mfcc array mfcc.shape[2] = 259 (back to 3d array)
# Out:
# array([[[-3.63721466e+02, -3.84499359e+02, -4.00248596e+02, ...,
#          -4.91153015e+02, -4.91153015e+02, -4.91153015e+02],
#         [ 1.12430931e+02,  1.08334152e+02,  1.01900085e+02, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 3.29160118e+01,  4.33921127e+01,  5.23206177e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         ...,
#         [ 7.26463795e+00,  1.12937250e+01,  9.72031784e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 4.11883450e+00,  7.43141747e+00,  7.47712326e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 5.22984505e+00,  5.24107695e+00,  3.25792217e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[-4.73410583e+02, -5.15877258e+02, -5.49301880e+02, ...,
#          -6.84740906e+02, -6.84740906e+02, -6.84740906e+02],
#         [ 1.04842514e+02,  9.46024704e+01,  9.03846130e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 2.78377514e+01,  3.80125275e+01,  4.31751671e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         ...,
#         [ 6.79416943e+00,  1.03055420e+01,  7.15180826e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 3.62815571e+00,  4.33410788e+00,  2.09957838e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 6.31051493e+00,  7.82261181e+00,  3.21465445e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[-2.46311951e+02, -2.95958252e+02, -3.52120239e+02, ...,
#          -5.08606262e+02, -5.08606262e+02, -5.08606262e+02],
#         [ 1.07275932e+02,  1.05540573e+02,  9.36361465e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 2.28717728e+01,  2.76066113e+01,  2.71950874e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         ...,
#         [ 3.70883703e+00,  5.54833746e+00,  6.07305479e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 4.17888069e+00,  6.27184486e+00,  1.05717821e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 4.32378387e+00,  6.04220581e+00,  9.07763100e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        ...,
#
#        [[-3.36110291e+02, -3.10545288e+02, -2.99062775e+02, ...,
#          -4.67424591e+02, -4.67424591e+02, -4.67424591e+02],
#         [ 1.24829643e+02,  1.34168549e+02,  1.41018127e+02, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 5.48213806e+01,  5.36365662e+01,  4.81060638e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         ...,
#         [ 1.03293514e+01,  1.14510250e+01,  1.01063080e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 6.67661047e+00,  6.71947098e+00,  2.16426301e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 5.26530361e+00,  4.48703384e+00, -7.32155204e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[-2.30242065e+02, -2.89925201e+02, -4.02307404e+02, ...,
#          -5.36847595e+02, -5.36847595e+02, -5.36847595e+02],
#         [ 1.10299393e+02,  1.16042542e+02,  1.18044502e+02, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 2.48362122e+01,  3.13674469e+01,  4.92503777e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         ...,
#         [ 3.93399286e+00,  7.45942020e+00,  1.09027786e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 3.85122514e+00,  7.40920734e+00,  9.84410477e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 4.01954460e+00,  7.66304255e+00,  1.23792839e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[-3.54270111e+02, -3.57715485e+02, -3.64312469e+02, ...,
#          -5.52639587e+02, -5.52639587e+02, -5.52639587e+02],
#         [ 1.09529854e+02,  1.07932716e+02,  1.07503426e+02, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 1.83073502e+01,  1.19437065e+01,  1.34955120e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         ...,
#         [ 1.25011749e+01,  9.31584263e+00,  7.24291229e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 4.25459671e+00, -5.93649037e-02, -3.06393003e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 4.43194675e+00,  5.53220797e+00,  2.39626145e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]]])

# %%
# back to original variable
cstft_train = cstft_train.reshape(
    cstft_train.shape[0], cstft_train.shape[1] // 259 , 259)

cstft_train   # original mfcc array cstft_train.shape[2] = 259
# Out:
# array([[[0.58030152, 0.73625714, 0.40997586, ..., 0.        ,
#          0.        , 0.        ],
#         [0.69759738, 0.79876506, 0.50841349, ..., 0.        ,
#          0.        , 0.        ],
#         [0.86479753, 0.95690101, 0.72613972, ..., 0.        ,
#          0.        , 0.        ],
#         ...,
#         [0.35181263, 0.56081951, 0.72135532, ..., 0.        ,
#          0.        , 0.        ],
#         [0.40180987, 0.60477197, 0.570858  , ..., 0.        ,
#          0.        , 0.        ],
#         [0.48839679, 0.68754745, 0.44460732, ..., 0.        ,
#          0.        , 0.        ]],
#
#        [[0.83066666, 0.56748253, 0.53704953, ..., 0.        ,
#          0.        , 0.        ],
#         [0.89885938, 0.68189263, 0.63354897, ..., 0.        ,
#          0.        , 0.        ],
#         [0.94405365, 0.8085826 , 0.75054199, ..., 0.        ,
#          0.        , 0.        ],
#         ...,
#         [0.72422576, 0.60147786, 0.696289  , ..., 0.        ,
#          0.        , 0.        ],
#         [0.69589674, 0.48634818, 0.54825234, ..., 0.        ,
#          0.        , 0.        ],
#         [0.71710277, 0.44585538, 0.45586398, ..., 0.        ,
#          0.        , 0.        ]],
#
#        [[0.88545817, 0.77187377, 0.92087191, ..., 0.        ,
#          0.        , 0.        ],
#         [0.93911928, 0.84086215, 0.90013331, ..., 0.        ,
#          0.        , 0.        ],
#         [0.97115374, 0.94178402, 0.90798771, ..., 0.        ,
#          0.        , 0.        ],
#         ...,
#         [0.71923751, 0.65194851, 1.        , ..., 0.        ,
#          0.        , 0.        ],
#         [0.75238597, 0.65677375, 0.92415798, ..., 0.        ,
#          0.        , 0.        ],
#         [0.79542232, 0.68305421, 0.86466146, ..., 0.        ,
#          0.        , 0.        ]],
#
#        ...,
#
#        [[0.81674886, 0.80074197, 1.        , ..., 0.        ,
#          0.        , 0.        ],
#         [0.91862154, 0.91894799, 0.81240726, ..., 0.        ,
#          0.        , 0.        ],
#         [0.95316803, 0.92436761, 0.75279289, ..., 0.        ,
#          0.        , 0.        ],
#         ...,
#         [0.7858488 , 0.87799609, 0.8906368 , ..., 0.        ,
#          0.        , 0.        ],
#         [0.75390357, 0.73502952, 0.79796469, ..., 0.        ,
#          0.        , 0.        ],
#         [0.7224797 , 0.66930586, 0.787848  , ..., 0.        ,
#          0.        , 0.        ]],
#
#        [[1.        , 1.        , 0.87201995, ..., 0.        ,
#          0.        , 0.        ],
#         [0.95246822, 0.96590263, 0.93709135, ..., 0.        ,
#          0.        , 0.        ],
#         [0.95935923, 0.9230305 , 0.96927565, ..., 0.        ,
#          0.        , 0.        ],
#         ...,
#         [0.91734439, 0.90370744, 0.78122002, ..., 0.        ,
#          0.        , 0.        ],
#         [0.89049488, 0.8953402 , 0.73766422, ..., 0.        ,
#          0.        , 0.        ],
#         [0.96153176, 0.93551713, 0.74170703, ..., 0.        ,
#          0.        , 0.        ]],
#
#        [[1.        , 1.        , 0.95386016, ..., 0.        ,
#          0.        , 0.        ],
#         [0.93004453, 0.98073828, 0.89441782, ..., 0.        ,
#          0.        , 0.        ],
#         [0.82580715, 0.89541608, 0.87324291, ..., 0.        ,
#          0.        , 0.        ],
#         ...,
#         [0.8881864 , 0.83423549, 0.90039444, ..., 0.        ,
#          0.        , 0.        ],
#         [0.9446243 , 0.87400436, 0.94932771, ..., 0.        ,
#          0.        , 0.        ],
#         [0.97408569, 0.91364175, 1.        , ..., 0.        ,
#          0.        , 0.        ]]])

# %%
# back to original variable
mSpec_train = mSpec_train.reshape(
    mSpec_train.shape[0], mSpec_train.shape[1] // 259 , 259)

mSpec_train   # original mfcc array mSpec_train.shape[2] = 259
# Out:
# array([[[2.52902374e+01, 4.34115410e+01, 4.79558640e+01, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [5.66892529e+00, 5.57895355e+01, 7.71177826e+01, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [4.23162746e+00, 2.84769611e+01, 2.05762691e+01, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [2.64845785e-05, 1.20000577e-05, 1.02360236e-05, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [2.66182851e-05, 9.78345179e-06, 4.69574024e-06, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [2.28262579e-05, 6.05126115e-06, 5.21315428e-07, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        [[4.37246990e+00, 1.21453714e+01, 1.06971569e+01, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [3.11700463e-01, 1.98628619e-01, 4.84634161e-01, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [3.28996815e-02, 2.78259609e-02, 4.60390002e-02, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [6.20824312e-06, 5.11363078e-06, 4.01709212e-06, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [3.93608207e-06, 2.89483387e-06, 2.21256414e-06, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [4.07716198e-06, 1.29095554e-06, 3.55868821e-07, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        [[9.87371750e+01, 1.05271690e+02, 6.94739685e+01, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [2.54310341e+01, 3.19584293e+01, 1.50775051e+01, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [3.50139427e+00, 9.84496498e+00, 6.60637712e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [4.02649050e-04, 1.46758975e-04, 6.72211318e-05, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [3.35442804e-04, 1.09146291e-04, 3.77177930e-05, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [3.48531175e-04, 8.87295901e-05, 2.68778513e-06, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        ...,
#
#        [[5.09610779e+02, 7.01421570e+02, 1.21948967e+02, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [4.22538300e+01, 3.55562515e+01, 8.86458969e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [1.99406767e+00, 9.83366132e-01, 1.21361542e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [4.70993982e-05, 7.90505874e-05, 7.89407422e-05, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [4.10344110e-05, 4.51200431e-05, 5.35019644e-05, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [1.96275250e-05, 6.36627283e-06, 1.66454868e-06, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        [[6.32158813e+01, 7.18640259e+02, 1.56582275e+03, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [5.84607010e+01, 1.70294189e+02, 9.39807281e+01, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [4.98357086e+01, 4.62340469e+01, 8.18911171e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [5.30442456e-04, 1.45487124e-04, 1.41459441e-05, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [4.97187313e-04, 1.31212480e-04, 6.71511270e-06, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [4.91315033e-04, 1.23446822e-04, 9.62069521e-07, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        [[7.11523914e+00, 1.80209827e+01, 1.45521936e+01, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [5.25201797e+00, 4.66017914e+00, 1.03080416e+01, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [1.15931106e+00, 1.42441106e+00, 2.31032610e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [2.92855202e-05, 1.77411694e-05, 3.00428383e-05, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [2.35616390e-05, 1.09208013e-05, 1.04052724e-05, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [2.32691400e-05, 6.29197530e-06, 5.17839112e-07, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]])

# %% [markdown]
# Chroma STFT The Chroma value of an audio basically represent the intensity of the twelve distinctive pitch classes that are used to study music. They can be employed in the differentiation of the pitch class profiles between audio signals. Chroma STFT in used short-term Fourier transformation to compute Chroma features. STFT represents information about the classification of pitch and signal structure. It depicts the spike with high values (as evident from the color bar net to the graph) in low values (dark regions).
#
# Need to plot graph

# %%
mfcc,cstft,mSpec = [],[],[]

for idx,row in val.iterrows():
    path=root + row['filename']
    a,b,c=getFeatures(path)
    mfcc.append(a)
    cstft.append(b)
    mSpec.append(c)

mfcc_val=np.array(mfcc)
cstft_val=np.array(cstft)
mSpec_val=np.array(mSpec)

# %%
mfcc_val
# Out:
# array([[[-2.61581726e+02, -3.21932983e+02, -4.00954346e+02, ...,
#          -3.83439392e+02, -2.41710449e+02, -1.01510231e+02],
#         [ 1.07941971e+02,  1.16920837e+02,  9.64519119e+01, ...,
#           1.19636185e+02,  1.13705048e+02,  1.08091766e+02],
#         [ 2.11560955e+01,  2.57366600e+01,  4.36615944e+01, ...,
#           6.17030716e+01,  2.68198967e+01,  2.26682816e+01],
#         ...,
#         [ 1.16055274e+00,  6.28351784e+00,  1.78989105e+01, ...,
#           1.20311317e+01,  7.00717020e+00,  3.86244631e+00],
#         [ 3.77085805e-03,  4.96559429e+00,  1.98193665e+01, ...,
#           1.31560564e+01,  7.01825285e+00,  3.99151373e+00],
#         [-8.95883679e-01,  2.57453871e+00,  1.24938545e+01, ...,
#           9.52023125e+00,  6.62363863e+00,  4.10206270e+00]],
#
#        [[-2.38587616e+02, -3.02529968e+02, -3.75574005e+02, ...,
#          -4.57602783e+02, -4.57602783e+02, -4.57602783e+02],
#         [ 1.07068253e+02,  1.12754837e+02,  9.91386566e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 2.11647415e+01,  2.60046082e+01,  6.31365967e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         ...,
#         [ 2.63481188e+00,  4.31874561e+00,  2.37960243e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 2.71482182e+00,  4.34648371e+00,  2.79087949e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 2.64068699e+00,  4.07870245e+00,  3.72588515e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[-2.52650620e+02, -3.15803223e+02, -4.38577698e+02, ...,
#          -5.36816406e+02, -5.36816406e+02, -5.36816406e+02],
#         [ 1.07113068e+02,  1.09988449e+02,  1.04950073e+02, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 2.16275387e+01,  2.57364922e+01,  5.34068909e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         ...,
#         [ 1.52613986e+00,  3.47286415e+00,  1.15710011e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 1.34997725e+00,  2.97425056e+00,  9.24360847e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 8.41753244e-01,  2.54792356e+00,  5.24220467e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        ...,
#
#        [[-1.35661011e+02, -1.90800919e+02, -2.62355225e+02, ...,
#          -4.33911682e+02, -4.33911682e+02, -4.33911682e+02],
#         [ 1.08014969e+02,  1.14836411e+02,  1.18160446e+02, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 2.49422016e+01,  3.34893570e+01,  5.08303070e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         ...,
#         [ 6.51322556e+00,  5.75917435e+00,  7.08885002e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 7.26659679e+00,  5.83988571e+00,  4.44405174e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 6.63926983e+00,  5.97829819e+00,  6.16070271e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[-3.47007843e+02, -3.59998505e+02, -3.71324890e+02, ...,
#          -4.70521454e+02, -4.70521454e+02, -4.70521454e+02],
#         [ 1.00881065e+02,  9.53231506e+01,  9.43880920e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 2.82434959e+01,  3.23656235e+01,  4.09629860e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         ...,
#         [ 2.80940104e+00,  4.02714252e+00,  2.92221355e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 5.45957279e+00,  8.17462444e+00,  7.39928436e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 6.03617144e+00,  7.78833771e+00,  8.40644455e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[-3.06858551e+02, -3.53230286e+02, -3.96106171e+02, ...,
#          -5.16907593e+02, -5.16907593e+02, -5.16907593e+02],
#         [ 1.16683250e+02,  1.34163956e+02,  1.37302826e+02, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 3.03320808e+01,  4.27699127e+01,  7.28506012e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         ...,
#         [ 7.83198452e+00,  9.13052177e+00,  5.08578062e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 7.67458248e+00,  8.03705025e+00,  2.40043211e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 8.11711502e+00,  7.87737465e+00, -7.02108622e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]]],
#       dtype=float32)

# %%
print(mfcc_val.shape)
print(cstft_val.shape)
print(mSpec_val.shape)
# Out:
# (1725, 20, 259)
# (1725, 12, 259)
# (1725, 128, 259)

# %%
mfcc_train.shape
# Out:
# (5173, 20, 259)

# %%
cstft_train.shape
# Out:
# (5173, 12, 259)

# %%
mSpec_train.shape
# Out:
# (5173, 128, 259)

# %% [markdown]
# The shape of features returned by the above function (20, 259) (12, 259) (128, 259) we need this for defining input shape of our model.

# %%
mfcc_reshaped = mfcc_val.reshape(mfcc_val.shape[0], -1)
cstft_reshaped = cstft_val.reshape(cstft_val.shape[0], -1)
mSpec_reshaped = mSpec_val.reshape(mSpec_val.shape[0], -1)
print(mfcc_reshaped)
np.savetxt('mfcc_variable_val.txt', mfcc_reshaped)
np.savetxt('cstft_variable_val.txt', cstft_reshaped)
np.savetxt('mSpec_variable_val.txt', mSpec_reshaped)
# Out:
# [[-261.58173   -321.93298   -400.95435   ...    9.520231     6.6236386
#      4.1020627]
#  [-238.58762   -302.52997   -375.574     ...    0.           0.
#      0.       ]
#  [-252.65062   -315.80322   -438.5777    ...    0.           0.
#      0.       ]
#  ...
#  [-135.66101   -190.80092   -262.35522   ...    0.           0.
#      0.       ]
#  [-347.00784   -359.9985    -371.3249    ...    0.           0.
#      0.       ]
#  [-306.85855   -353.2303    -396.10617   ...    0.           0.
#      0.       ]]

# %%
# loading variable files
mfcc_val = np.loadtxt('mfcc_variable_val.txt')
cstft_val = np.loadtxt('cstft_variable_val.txt')
mSpec_val = np.loadtxt('mSpec_variable_val.txt')

# %%
mfcc_val = mfcc_val.reshape(
    mfcc_val.shape[0], mfcc_val.shape[1] // 259 , 259)
cstft_val = cstft_val.reshape(
    cstft_val.shape[0], cstft_val.shape[1] // 259 , 259)
mSpec_val = mSpec_val.reshape(
    mSpec_val.shape[0], mSpec_val.shape[1] // 259 , 259)

# %%
mfcc_val.shape
# Out:
# (1725, 20, 259)

# %% [markdown]
# ## Building Model

# %%
# Lets create model using Keras Functional API to check how the features perform.
my_callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=5),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                              patience=3, min_lr=0.00001,mode='min')
]

# %% [markdown]
# ### Here we are creating three different neural networks and then Combining them to a Dense Network

# %%
mfcc_input=keras.layers.Input(shape=(20,259,1),name="mfccInput")
x=keras.layers.Conv2D(32,5,strides=(1,3),padding='same')(mfcc_input)
x=keras.layers.BatchNormalization()(x)
x=keras.layers.Activation(keras.activations.relu)(x)
x=keras.layers.MaxPooling2D(pool_size=2,padding='valid')(x)

x=keras.layers.Conv2D(64,3,strides=(1,2),padding='same')(x)
x=keras.layers.BatchNormalization()(x)
x=keras.layers.Activation(keras.activations.relu)(x)
x=keras.layers.MaxPooling2D(pool_size=2,padding='valid')(x)

x=keras.layers.Conv2D(96,2,padding='same')(x)
x=keras.layers.BatchNormalization()(x)
x=keras.layers.Activation(keras.activations.relu)(x)
x=keras.layers.MaxPooling2D(pool_size=2,padding='valid')(x)

x=keras.layers.Conv2D(128,2,padding='same')(x)
x=keras.layers.BatchNormalization()(x)
x=keras.layers.Activation(keras.activations.relu)(x)
mfcc_output=keras.layers.GlobalMaxPooling2D()(x)

mfcc_model=keras.Model(mfcc_input, mfcc_output, name="mfccModel")

# %%
mfcc_model.summary()
# Out:
# Model: "mfccModel"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mfccInput (InputLayer)      [(None, 20, 259, 1)]      0
#
#  conv2d (Conv2D)             (None, 20, 87, 32)        832
#
#  batch_normalization (Batch  (None, 20, 87, 32)        128
#  Normalization)
#
#  activation (Activation)     (None, 20, 87, 32)        0
#
#  max_pooling2d (MaxPooling2  (None, 10, 43, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 10, 22, 64)        18496
#
#  batch_normalization_1 (Bat  (None, 10, 22, 64)        256
#  chNormalization)
#
#  activation_1 (Activation)   (None, 10, 22, 64)        0
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 11, 64)         0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 5, 11, 96)         24672
#
#  batch_normalization_2 (Bat  (None, 5, 11, 96)         384
#  chNormalization)
#
#  activation_2 (Activation)   (None, 5, 11, 96)         0
#
#  max_pooling2d_2 (MaxPoolin  (None, 2, 5, 96)          0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 2, 5, 128)         49280
#
#  batch_normalization_3 (Bat  (None, 2, 5, 128)         512
#  chNormalization)
#
#  activation_3 (Activation)   (None, 2, 5, 128)         0
#
#  global_max_pooling2d (Glob  (None, 128)               0
#  alMaxPooling2D)
#
# =================================================================
# Total params: 94560 (369.38 KB)
# Trainable params: 93920 (366.88 KB)
# Non-trainable params: 640 (2.50 KB)
# _________________________________________________________________

# %%
croma_input=keras.layers.Input(shape=(12,259,1),name="cromaInput")
x=keras.layers.Conv2D(32,5,strides=(1,3),padding='same')(croma_input)
x=keras.layers.BatchNormalization()(x)
x=keras.layers.Activation(keras.activations.relu)(x)
x=keras.layers.MaxPooling2D(pool_size=2,padding='valid')(x)

x=keras.layers.Conv2D(64,3,strides=(1,2),padding='same')(x)
x=keras.layers.BatchNormalization()(x)
x=keras.layers.Activation(keras.activations.relu)(x)
x=keras.layers.MaxPooling2D(pool_size=2,padding='valid')(x)

x=keras.layers.Conv2D(128,2,padding='same')(x)
x=keras.layers.BatchNormalization()(x)
x=keras.layers.Activation(keras.activations.relu)(x)
croma_output=keras.layers.GlobalMaxPooling2D()(x)

croma_model=keras.Model(croma_input, croma_output, name="cromaModel")

# %%
croma_model.summary()
# Out:
# Model: "cromaModel"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  cromaInput (InputLayer)     [(None, 12, 259, 1)]      0
#
#  conv2d_4 (Conv2D)           (None, 12, 87, 32)        832
#
#  batch_normalization_4 (Bat  (None, 12, 87, 32)        128
#  chNormalization)
#
#  activation_4 (Activation)   (None, 12, 87, 32)        0
#
#  max_pooling2d_3 (MaxPoolin  (None, 6, 43, 32)         0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 6, 22, 64)         18496
#
#  batch_normalization_5 (Bat  (None, 6, 22, 64)         256
#  chNormalization)
#
#  activation_5 (Activation)   (None, 6, 22, 64)         0
#
#  max_pooling2d_4 (MaxPoolin  (None, 3, 11, 64)         0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 3, 11, 128)        32896
#
#  batch_normalization_6 (Bat  (None, 3, 11, 128)        512
#  chNormalization)
#
#  activation_6 (Activation)   (None, 3, 11, 128)        0
#
#  global_max_pooling2d_1 (Gl  (None, 128)               0
#  obalMaxPooling2D)
#
# =================================================================
# Total params: 53120 (207.50 KB)
# Trainable params: 52672 (205.75 KB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________

# %%
mSpec_input=keras.layers.Input(shape=(128,259,1),name="mSpecInput")
x=keras.layers.Conv2D(32,5,strides=(2,3),padding='same')(mSpec_input)
x=keras.layers.BatchNormalization()(x)
x=keras.layers.Activation(keras.activations.relu)(x)
x=keras.layers.MaxPooling2D(pool_size=2,padding='valid')(x)

x=keras.layers.Conv2D(64,3,strides=(2,2),padding='same')(x)
x=keras.layers.BatchNormalization()(x)
x=keras.layers.Activation(keras.activations.relu)(x)
x=keras.layers.MaxPooling2D(pool_size=2,padding='valid')(x)

x=keras.layers.Conv2D(96,2,padding='same')(x)
x=keras.layers.BatchNormalization()(x)
x=keras.layers.Activation(keras.activations.relu)(x)
x=keras.layers.MaxPooling2D(pool_size=2,padding='valid')(x)

x=keras.layers.Conv2D(128,2,padding='same')(x)
x=keras.layers.BatchNormalization()(x)
x=keras.layers.Activation(keras.activations.relu)(x)
mSpec_output=keras.layers.GlobalMaxPooling2D()(x)

mSpec_model=keras.Model(mSpec_input, mSpec_output, name="mSpecModel")

# %%
mSpec_model.summary()
# Out:
# Model: "mSpecModel"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mSpecInput (InputLayer)     [(None, 128, 259, 1)]     0
#
#  conv2d_7 (Conv2D)           (None, 64, 87, 32)        832
#
#  batch_normalization_7 (Bat  (None, 64, 87, 32)        128
#  chNormalization)
#
#  activation_7 (Activation)   (None, 64, 87, 32)        0
#
#  max_pooling2d_5 (MaxPoolin  (None, 32, 43, 32)        0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 16, 22, 64)        18496
#
#  batch_normalization_8 (Bat  (None, 16, 22, 64)        256
#  chNormalization)
#
#  activation_8 (Activation)   (None, 16, 22, 64)        0
#
#  max_pooling2d_6 (MaxPoolin  (None, 8, 11, 64)         0
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 8, 11, 96)         24672
#
#  batch_normalization_9 (Bat  (None, 8, 11, 96)         384
#  chNormalization)
#
#  activation_9 (Activation)   (None, 8, 11, 96)         0
#
#  max_pooling2d_7 (MaxPoolin  (None, 4, 5, 96)          0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 4, 5, 128)         49280
#
#  batch_normalization_10 (Ba  (None, 4, 5, 128)         512
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 4, 5, 128)         0
#
#  global_max_pooling2d_2 (Gl  (None, 128)               0
#  obalMaxPooling2D)
#
# =================================================================
# Total params: 94560 (369.38 KB)
# Trainable params: 93920 (366.88 KB)
# Non-trainable params: 640 (2.50 KB)
# _________________________________________________________________

# %% [markdown]
# Concatenating our 3 models

# %%
input_mfcc=keras.layers.Input(shape=(20,259,1),name="mfcc")
mfcc=mfcc_model(input_mfcc)

input_croma=keras.layers.Input(shape=(12,259,1),name="croma")
croma=croma_model(input_croma)

input_mSpec=keras.layers.Input(shape=(128,259,1),name="mspec")
mSpec=mSpec_model(input_mSpec)


concat=keras.layers.concatenate([mfcc,croma,mSpec])
hidden=keras.layers.Dropout(0.1)(concat)
hidden=keras.layers.Dense(50,activation='relu')(concat)
hidden=keras.layers.Dropout(0.2)(hidden)
hidden=keras.layers.Dense(25,activation='relu')(hidden)
hidden=keras.layers.Dropout(0.2)(hidden)
output=keras.layers.Dense(8,activation='softmax')(hidden)

net=keras.Model([input_mfcc,input_croma,input_mSpec], output, name="Net")

# %%
net.summary()
# Out:
# Model: "Net"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  mfcc (InputLayer)           [(None, 20, 259, 1)]         0         []
#
#  croma (InputLayer)          [(None, 12, 259, 1)]         0         []
#
#  mspec (InputLayer)          [(None, 128, 259, 1)]        0         []
#
#  mfccModel (Functional)      (None, 128)                  94560     ['mfcc[0][0]']
#
#  cromaModel (Functional)     (None, 128)                  53120     ['croma[0][0]']
#
#  mSpecModel (Functional)     (None, 128)                  94560     ['mspec[0][0]']
#
#  concatenate (Concatenate)   (None, 384)                  0         ['mfccModel[0][0]',
#                                                                      'cromaModel[0][0]',
#                                                                      'mSpecModel[0][0]']
#
#  dense (Dense)               (None, 50)                   19250     ['concatenate[0][0]']
#
#  dropout_1 (Dropout)         (None, 50)                   0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 25)                   1275      ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 25)                   0         ['dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 8)                    208       ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 262973 (1.00 MB)
# Trainable params: 261245 (1020.49 KB)
# Non-trainable params: 1728 (6.75 KB)
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(net, "combined_model.png", show_shapes=True)

# %%
from keras import backend as K
net.compile(loss='sparse_categorical_crossentropy', optimizer='nadam', metrics=['accuracy'])
K.set_value(net.optimizer.learning_rate, 0.001)

# %%
history=net.fit(
    {"mfcc":mfcc_train,"croma":cstft_train,"mspec":mSpec_train},
    ytrain,
    validation_data=({"mfcc":mfcc_val,"croma":cstft_val,"mspec":mSpec_val},yval),
    epochs=100,verbose=1,
    callbacks=my_callbacks
)
# Out:
# Epoch 1/100
# 162/162 [==============================] - 96s 512ms/step - loss: 0.6034 - accuracy: 0.8222 - val_loss: 0.8583 - val_accuracy: 0.8122 - lr: 0.0010
# Epoch 2/100
# 162/162 [==============================] - 88s 544ms/step - loss: 0.4762 - accuracy: 0.8361 - val_loss: 0.5052 - val_accuracy: 0.8394 - lr: 0.0010
# Epoch 3/100
# 162/162 [==============================] - 87s 537ms/step - loss: 0.3914 - accuracy: 0.8558 - val_loss: 0.3893 - val_accuracy: 0.8597 - lr: 0.0010
# Epoch 4/100
# 162/162 [==============================] - 87s 535ms/step - loss: 0.3625 - accuracy: 0.8598 - val_loss: 0.3157 - val_accuracy: 0.8777 - lr: 0.0010
# Epoch 5/100
# 162/162 [==============================] - 80s 491ms/step - loss: 0.3359 - accuracy: 0.8691 - val_loss: 0.2998 - val_accuracy: 0.8800 - lr: 0.0010
# Epoch 6/100
# 162/162 [==============================] - 88s 546ms/step - loss: 0.3096 - accuracy: 0.8800 - val_loss: 0.5050 - val_accuracy: 0.8580 - lr: 0.0010
# Epoch 7/100
# 162/162 [==============================] - 93s 574ms/step - loss: 0.2971 - accuracy: 0.8844 - val_loss: 0.2465 - val_accuracy: 0.9009 - lr: 0.0010
# Epoch 8/100
# 162/162 [==============================] - 87s 537ms/step - loss: 0.2871 - accuracy: 0.8877 - val_loss: 0.8147 - val_accuracy: 0.8580 - lr: 0.0010
# Epoch 9/100
# 162/162 [==============================] - 83s 512ms/step - loss: 0.2568 - accuracy: 0.8995 - val_loss: 0.3298 - val_accuracy: 0.8661 - lr: 0.0010
# Epoch 10/100
# 162/162 [==============================] - 84s 516ms/step - loss: 0.2515 - accuracy: 0.9035 - val_loss: 0.4412 - val_accuracy: 0.8725 - lr: 0.0010
# Epoch 11/100
# 162/162 [==============================] - 82s 506ms/step - loss: 0.2096 - accuracy: 0.9173 - val_loss: 0.1842 - val_accuracy: 0.9304 - lr: 1.0000e-04
# Epoch 12/100
# 162/162 [==============================] - 88s 543ms/step - loss: 0.1815 - accuracy: 0.9283 - val_loss: 0.1756 - val_accuracy: 0.9322 - lr: 1.0000e-04
# Epoch 13/100
# 162/162 [==============================] - 87s 536ms/step - loss: 0.1769 - accuracy: 0.9283 - val_loss: 0.1761 - val_accuracy: 0.9322 - lr: 1.0000e-04
# Epoch 14/100
# 162/162 [==============================] - 92s 572ms/step - loss: 0.1730 - accuracy: 0.9271 - val_loss: 0.1697 - val_accuracy: 0.9357 - lr: 1.0000e-04
# Epoch 15/100
# 162/162 [==============================] - 87s 539ms/step - loss: 0.1612 - accuracy: 0.9383 - val_loss: 0.1671 - val_accuracy: 0.9362 - lr: 1.0000e-04
# Epoch 16/100
# 162/162 [==============================] - 82s 507ms/step - loss: 0.1591 - accuracy: 0.9350 - val_loss: 0.1725 - val_accuracy: 0.9351 - lr: 1.0000e-04
# Epoch 17/100
# 162/162 [==============================] - 88s 544ms/step - loss: 0.1504 - accuracy: 0.9397 - val_loss: 0.1655 - val_accuracy: 0.9386 - lr: 1.0000e-04
# Epoch 18/100
# 162/162 [==============================] - 82s 509ms/step - loss: 0.1507 - accuracy: 0.9403 - val_loss: 0.1589 - val_accuracy: 0.9357 - lr: 1.0000e-04
# Epoch 19/100
# 162/162 [==============================] - 83s 510ms/step - loss: 0.1379 - accuracy: 0.9470 - val_loss: 0.1608 - val_accuracy: 0.9414 - lr: 1.0000e-04
# Epoch 20/100
# 162/162 [==============================] - 87s 536ms/step - loss: 0.1371 - accuracy: 0.9476 - val_loss: 0.1600 - val_accuracy: 0.9426 - lr: 1.0000e-04
# Epoch 21/100
# 162/162 [==============================] - 90s 554ms/step - loss: 0.1348 - accuracy: 0.9466 - val_loss: 0.1551 - val_accuracy: 0.9443 - lr: 1.0000e-04
# Epoch 22/100
# 162/162 [==============================] - 88s 543ms/step - loss: 0.1280 - accuracy: 0.9478 - val_loss: 0.1570 - val_accuracy: 0.9432 - lr: 1.0000e-04
# Epoch 23/100
# 162/162 [==============================] - 87s 536ms/step - loss: 0.1210 - accuracy: 0.9544 - val_loss: 0.2251 - val_accuracy: 0.9316 - lr: 1.0000e-04
# Epoch 24/100
# 162/162 [==============================] - 89s 550ms/step - loss: 0.1229 - accuracy: 0.9544 - val_loss: 0.1682 - val_accuracy: 0.9449 - lr: 1.0000e-04
# Epoch 25/100
# 162/162 [==============================] - 85s 523ms/step - loss: 0.1152 - accuracy: 0.9550 - val_loss: 0.1525 - val_accuracy: 0.9490 - lr: 1.0000e-05
# Epoch 26/100
# 162/162 [==============================] - 82s 507ms/step - loss: 0.1120 - accuracy: 0.9552 - val_loss: 0.1513 - val_accuracy: 0.9484 - lr: 1.0000e-05
# Epoch 27/100
# 162/162 [==============================] - 78s 481ms/step - loss: 0.1120 - accuracy: 0.9577 - val_loss: 0.1492 - val_accuracy: 0.9484 - lr: 1.0000e-05
# Epoch 28/100
# 162/162 [==============================] - 87s 541ms/step - loss: 0.1082 - accuracy: 0.9557 - val_loss: 0.1481 - val_accuracy: 0.9496 - lr: 1.0000e-05
# Epoch 29/100
# 162/162 [==============================] - 87s 534ms/step - loss: 0.1082 - accuracy: 0.9590 - val_loss: 0.1513 - val_accuracy: 0.9490 - lr: 1.0000e-05
# Epoch 30/100
# 162/162 [==============================] - 86s 531ms/step - loss: 0.1100 - accuracy: 0.9559 - val_loss: 0.1529 - val_accuracy: 0.9501 - lr: 1.0000e-05
# Epoch 31/100
# 162/162 [==============================] - 82s 506ms/step - loss: 0.1059 - accuracy: 0.9588 - val_loss: 0.1509 - val_accuracy: 0.9513 - lr: 1.0000e-05
# Epoch 32/100
# 162/162 [==============================] - 81s 498ms/step - loss: 0.1070 - accuracy: 0.9561 - val_loss: 0.1516 - val_accuracy: 0.9507 - lr: 1.0000e-05
# Epoch 33/100
# 162/162 [==============================] - 84s 517ms/step - loss: 0.1081 - accuracy: 0.9573 - val_loss: 0.1475 - val_accuracy: 0.9507 - lr: 1.0000e-05
# Epoch 34/100
# 162/162 [==============================] - 86s 531ms/step - loss: 0.1074 - accuracy: 0.9592 - val_loss: 0.1517 - val_accuracy: 0.9513 - lr: 1.0000e-05
# Epoch 35/100
# 162/162 [==============================] - 84s 520ms/step - loss: 0.1064 - accuracy: 0.9581 - val_loss: 0.1531 - val_accuracy: 0.9484 - lr: 1.0000e-05
# Epoch 36/100
# 162/162 [==============================] - 91s 565ms/step - loss: 0.1032 - accuracy: 0.9598 - val_loss: 0.1515 - val_accuracy: 0.9513 - lr: 1.0000e-05
# Epoch 37/100
# 162/162 [==============================] - 87s 537ms/step - loss: 0.0978 - accuracy: 0.9623 - val_loss: 0.1521 - val_accuracy: 0.9519 - lr: 1.0000e-05
# Epoch 38/100
# 162/162 [==============================] - 82s 508ms/step - loss: 0.1059 - accuracy: 0.9615 - val_loss: 0.1539 - val_accuracy: 0.9484 - lr: 1.0000e-05

# %%
history.history['accuracy']
# Out:
# [0.8221535086631775,
#  0.8360719084739685,
#  0.8557896614074707,
#  0.859849214553833,
#  0.8691281676292419,
#  0.8799536228179932,
#  0.8843997716903687,
#  0.8876860737800598,
#  0.8994780778884888,
#  0.9035375714302063,
#  0.9172627329826355,
#  0.9282814860343933,
#  0.9282814860343933,
#  0.9271215796470642,
#  0.9383336305618286,
#  0.9350473880767822,
#  0.9396868348121643,
#  0.9402667880058289,
#  0.9470326900482178,
#  0.9476125836372375,
#  0.9466460347175598,
#  0.9478059411048889,
#  0.9543784856796265,
#  0.9543784856796265,
#  0.954958438873291,
#  0.9551517367362976,
#  0.9576647877693176,
#  0.9557316899299622,
#  0.9590179920196533,
#  0.9559249877929688,
#  0.9588246941566467,
#  0.9561182856559753,
#  0.9572781920433044,
#  0.9592112898826599,
#  0.9580514430999756,
#  0.9597912430763245,
#  0.9623042941093445,
#  0.9615310430526733]

# %%
loss_train = history.history['accuracy']
loss_val = history.history['val_accuracy']
epochs = range(1, len(loss_train) + 1)  # Adjusted range
plt.plot(epochs, loss_train, 'g', label='Training accuracy')
plt.plot(epochs, loss_val, 'b', label='Validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
pd.DataFrame(history.history).plot()
plt.grid(True)
plt.gca().set_ylim(-0.1,1.1)
plt.show()

# %% [markdown]
# ## Evaluating and Saving Our Model

# %%
net.evaluate({"mfcc":mfcc_val,"croma":cstft_val,"mspec":mSpec_val},yval)
# Out:
# 54/54 [==============================] - 7s 129ms/step - loss: 0.1539 - accuracy: 0.9484
# [0.15390072762966156, 0.9484058022499084]

# %%
yval
# Out:
# array([3, 3, 3, ..., 3, 3, 3])

# %%
ypred = net.predict({"mfcc":mfcc_val,"croma":cstft_val,"mspec":mSpec_val})
# Out:
# 54/54 [==============================] - 7s 125ms/step

# %%
yPred = []
for i in ypred:
    yPred.append(np.argmax(i))
yPred
# Out:
# [3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  6,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  7,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  7,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  6,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  6,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  6,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  7,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  6,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  7,
#  3,
#  3,
#  3,
#  3,
#  6,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  6,
#  3,
#  7,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  7,
#  3,
#  6,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  2,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  6,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  2,
#  2,
#  3,
#  3,
#  3,
#  3,
#  6,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  7,
#  3,
#  3,
#  3,
#  3,
#  6,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  7,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  6,
#  3,
#  3,
#  3,
#  7,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  7,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  4,
#  4,
#  3,
#  3,
#  3,
#  3,
#  6,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  4,
#  3,
#  7,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  6,
#  3,
#  3,
#  3,
#  7,
#  3,
#  3,
#  3,
#  3,
#  4,
#  7,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  4,
#  3,
#  6,
#  3,
#  3,
#  7,
#  3,
#  3,
#  3,
#  3,
#  3,
#  7,
#  3,
#  3,
#  3,
#  3,
#  6,
#  3,
#  3,
#  3,
#  3,
#  7,
#  2,
#  4,
#  3,
#  3,
#  3,
#  6,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  2,
#  3,
#  6,
#  3,
#  7,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  6,
#  2,
#  3,
#  7,
#  3,
#  3,
#  3,
#  7,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  4,
#  3,
#  3,
#  6,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  7,
#  3,
#  6,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  6,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  6,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  7,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  1,
#  3,
#  4,
#  4,
#  1,
#  3,
#  3,
#  3,
#  7,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  7,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  6,
#  3,
#  6,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  6,
#  3,
#  6,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  7,
#  3,
#  3,
#  3,
#  7,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  6,
#  7,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  2,
#  7,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  7,
#  6,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  6,
#  3,
#  6,
#  6,
#  3,
#  6,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  2,
#  6,
#  3,
#  3,
#  3,
#  3,
#  7,
#  3,
#  3,
#  3,
#  3,
#  7,
#  3,
#  3,
#  4,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  6,
#  3,
#  4,
#  6,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  6,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  7,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  6,
#  3,
#  3,
#  4,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  6,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  7,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  6,
#  4,
#  3,
#  3,
#  4,
#  6,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  6,
#  3,
#  3,
#  7,
#  3,
#  3,
#  3,
#  3,
#  4,
#  4,
#  3,
#  3,
#  3,
#  6,
#  3,
#  3,
#  7,
#  3,
#  3,
#  6,
#  3,
#  3,
#  ...]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
print('\nClassification Report\n')
from sklearn.metrics import classification_report
print(classification_report(yval, yPred, target_names=['Asthma', 'Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'LRTI', 'Pneumonia', 'URTI']))
# Out:
# Classification Report
#
#                 precision    recall  f1-score   support
#
#         Asthma       0.00      0.00      0.00         1
# Bronchiectasis       0.89      0.96      0.93        26
#  Bronchiolitis       0.64      0.62      0.63        40
#           COPD       0.99      1.00      0.99      1437
#        Healthy       0.71      0.77      0.74        81
#           LRTI       0.00      0.00      0.00         8
#      Pneumonia       0.91      0.86      0.88        71
#           URTI       0.56      0.49      0.52        61
#
#       accuracy                           0.95      1725
#      macro avg       0.59      0.59      0.59      1725
#   weighted avg       0.94      0.95      0.95      1725
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# saving model
from tensorflow.keras.models import save_model
modelExist = os.path.exists('model')
if(not modelExist):
    os.makedirs('model')
    save_model(net, "model/model.h5")
    # net.save(filepath='model/',overwrite=True,include_optimizer=True)

# %% [markdown]
# ## Testing our Model for single input sound file

# %%
# load model
# model = keras.models.load_model('model') if model not saved in h5 format
from tensorflow.keras.models import load_model

# load model
model = load_model('/content/drive/MyDrive/My Projects/respiratory_disorder_classification/model/model.h5')
# summarize model.
model.summary()
# Out:
# Model: "Net"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  mfcc (InputLayer)           [(None, 20, 259, 1)]         0         []
#
#  croma (InputLayer)          [(None, 12, 259, 1)]         0         []
#
#  mspec (InputLayer)          [(None, 128, 259, 1)]        0         []
#
#  mfccModel (Functional)      (None, 128)                  94560     ['mfcc[0][0]']
#
#  cromaModel (Functional)     (None, 128)                  53120     ['croma[0][0]']
#
#  mSpecModel (Functional)     (None, 128)                  94560     ['mspec[0][0]']
#
#  concatenate (Concatenate)   (None, 384)                  0         ['mfccModel[0][0]',
#                                                                      'cromaModel[0][0]',
#                                                                      'mSpecModel[0][0]']
#
#  dense (Dense)               (None, 50)                   19250     ['concatenate[0][0]']
#
#  dropout_1 (Dropout)         (None, 50)                   0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 25)                   1275      ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 25)                   0         ['dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 8)                    208       ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 262973 (1.00 MB)
# Trainable params: 261245 (1020.49 KB)
# Non-trainable params: 1728 (6.75 KB)
# __________________________________________________________________________________________________

# %%
model.summary(expand_nested=True)
# Out:
# Model: "Net"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  mfcc (InputLayer)           [(None, 20, 259, 1)]         0         []
#
#  croma (InputLayer)          [(None, 12, 259, 1)]         0         []
#
#  mspec (InputLayer)          [(None, 128, 259, 1)]        0         []
#
#  mfccModel (Functional)      (None, 128)                  94560     ['mfcc[0][0]']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | mfccInput (InputLayer)     [(None, 20, 259, 1)]         0         []                           |
# |                                                                                                |
# | conv2d (Conv2D)            (None, 20, 87, 32)           832       []                           |
# |                                                                                                |
# | batch_normalization (Batc  (None, 20, 87, 32)           128       []                           |
# | hNormalization)                                                                                |
# |                                                                                                |
# | activation (Activation)    (None, 20, 87, 32)           0         []                           |
# |                                                                                                |
# | max_pooling2d (MaxPooling  (None, 10, 43, 32)           0         []                           |
# | 2D)                                                                                            |
# |                                                                                                |
# | conv2d_1 (Conv2D)          (None, 10, 22, 64)           18496     []                           |
# |                                                                                                |
# | batch_normalization_1 (Ba  (None, 10, 22, 64)           256       []                           |
# | tchNormalization)                                                                              |
# |                                                                                                |
# | activation_1 (Activation)  (None, 10, 22, 64)           0         []                           |
# |                                                                                                |
# | max_pooling2d_1 (MaxPooli  (None, 5, 11, 64)            0         []                           |
# | ng2D)                                                                                          |
# |                                                                                                |
# | conv2d_2 (Conv2D)          (None, 5, 11, 96)            24672     []                           |
# |                                                                                                |
# | batch_normalization_2 (Ba  (None, 5, 11, 96)            384       []                           |
# | tchNormalization)                                                                              |
# |                                                                                                |
# | activation_2 (Activation)  (None, 5, 11, 96)            0         []                           |
# |                                                                                                |
# | max_pooling2d_2 (MaxPooli  (None, 2, 5, 96)             0         []                           |
# | ng2D)                                                                                          |
# |                                                                                                |
# | conv2d_3 (Conv2D)          (None, 2, 5, 128)            49280     []                           |
# |                                                                                                |
# | batch_normalization_3 (Ba  (None, 2, 5, 128)            512       []                           |
# | tchNormalization)                                                                              |
# |                                                                                                |
# | activation_3 (Activation)  (None, 2, 5, 128)            0         []                           |
# |                                                                                                |
# | global_max_pooling2d (Glo  (None, 128)                  0         []                           |
# | balMaxPooling2D)                                                                               |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  cromaModel (Functional)     (None, 128)                  53120     ['croma[0][0]']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | cromaInput (InputLayer)    [(None, 12, 259, 1)]         0         []                           |
# |                                                                                                |
# | conv2d_4 (Conv2D)          (None, 12, 87, 32)           832       []                           |
# |                                                                                                |
# | batch_normalization_4 (Ba  (None, 12, 87, 32)           128       []                           |
# | tchNormalization)                                                                              |
# |                                                                                                |
# | activation_4 (Activation)  (None, 12, 87, 32)           0         []                           |
# |                                                                                                |
# | max_pooling2d_3 (MaxPooli  (None, 6, 43, 32)            0         []                           |
# | ng2D)                                                                                          |
# |                                                                                                |
# | conv2d_5 (Conv2D)          (None, 6, 22, 64)            18496     []                           |
# |                                                                                                |
# | batch_normalization_5 (Ba  (None, 6, 22, 64)            256       []                           |
# | tchNormalization)                                                                              |
# |                                                                                                |
# | activation_5 (Activation)  (None, 6, 22, 64)            0         []                           |
# |                                                                                                |
# | max_pooling2d_4 (MaxPooli  (None, 3, 11, 64)            0         []                           |
# | ng2D)                                                                                          |
# |                                                                                                |
# | conv2d_6 (Conv2D)          (None, 3, 11, 128)           32896     []                           |
# |                                                                                                |
# | batch_normalization_6 (Ba  (None, 3, 11, 128)           512       []                           |
# | tchNormalization)                                                                              |
# |                                                                                                |
# | activation_6 (Activation)  (None, 3, 11, 128)           0         []                           |
# |                                                                                                |
# | global_max_pooling2d_1 (G  (None, 128)                  0         []                           |
# | lobalMaxPooling2D)                                                                             |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  mSpecModel (Functional)     (None, 128)                  94560     ['mspec[0][0]']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | mSpecInput (InputLayer)    [(None, 128, 259, 1)]        0         []                           |
# |                                                                                                |
# | conv2d_7 (Conv2D)          (None, 64, 87, 32)           832       []                           |
# |                                                                                                |
# | batch_normalization_7 (Ba  (None, 64, 87, 32)           128       []                           |
# | tchNormalization)                                                                              |
# |                                                                                                |
# | activation_7 (Activation)  (None, 64, 87, 32)           0         []                           |
# |                                                                                                |
# | max_pooling2d_5 (MaxPooli  (None, 32, 43, 32)           0         []                           |
# | ng2D)                                                                                          |
# |                                                                                                |
# | conv2d_8 (Conv2D)          (None, 16, 22, 64)           18496     []                           |
# |                                                                                                |
# | batch_normalization_8 (Ba  (None, 16, 22, 64)           256       []                           |
# | tchNormalization)                                                                              |
# |                                                                                                |
# | activation_8 (Activation)  (None, 16, 22, 64)           0         []                           |
# |                                                                                                |
# | max_pooling2d_6 (MaxPooli  (None, 8, 11, 64)            0         []                           |
# | ng2D)                                                                                          |
# |                                                                                                |
# | conv2d_9 (Conv2D)          (None, 8, 11, 96)            24672     []                           |
# |                                                                                                |
# | batch_normalization_9 (Ba  (None, 8, 11, 96)            384       []                           |
# | tchNormalization)                                                                              |
# |                                                                                                |
# | activation_9 (Activation)  (None, 8, 11, 96)            0         []                           |
# |                                                                                                |
# | max_pooling2d_7 (MaxPooli  (None, 4, 5, 96)             0         []                           |
# | ng2D)                                                                                          |
# |                                                                                                |
# | conv2d_10 (Conv2D)         (None, 4, 5, 128)            49280     []                           |
# |                                                                                                |
# | batch_normalization_10 (B  (None, 4, 5, 128)            512       []                           |
# | atchNormalization)                                                                             |
# |                                                                                                |
# | activation_10 (Activation  (None, 4, 5, 128)            0         []                           |
# | )                                                                                              |
# |                                                                                                |
# | global_max_pooling2d_2 (G  (None, 128)                  0         []                           |
# | lobalMaxPooling2D)                                                                             |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  concatenate (Concatenate)   (None, 384)                  0         ['mfccModel[0][0]',
#                                                                      'cromaModel[0][0]',
#                                                                      'mSpecModel[0][0]']
#
#  dense (Dense)               (None, 50)                   19250     ['concatenate[0][0]']
#
#  dropout_1 (Dropout)         (None, 50)                   0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 25)                   1275      ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 25)                   0         ['dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 8)                    208       ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 262973 (1.00 MB)
# Trainable params: 261245 (1020.49 KB)
# Non-trainable params: 1728 (6.75 KB)
# __________________________________________________________________________________________________

# %%
import librosa as lb
def getFeaturesForNeuralNetwork(path):
    soundArr,sample_rate=lb.load(path)
    mfcc=lb.feature.mfcc(y=soundArr,sr=sample_rate)
    cstft=lb.feature.chroma_stft(y=soundArr,sr=sample_rate)
    mSpec=lb.feature.melspectrogram(y=soundArr,sr=sample_rate)

    return mfcc,cstft,mSpec

# %%
# testing soundfile path

COPD = "113_1b1_Ll_sc_Litt3200_2.wav"
Pneumonia = "135_2b3_Al_mc_LittC2SE_3.wav"
URTI = "119_1b1_Ar_sc_Meditron_0.wav"
Healthy = "159_1b1_Ar_sc_Meditron_3.wav"
Bronchiectasis = "111_1b2_Tc_sc_Meditron_2.wav"
Bronchiolitis = "149_1b1_Pl_sc_Meditron_10.wav"
Asthma = "103_2b2_Ar_mc_LittC2SE_3.wav"

# soundFilePath = os.getcwd() + "\processed_audio_files\\" + COPD
soundFilePath = "/content/drive/MyDrive/My Projects/respiratory_disorder_classification/processed_audio_files/" + COPD
print(os.getcwd())
print(soundFilePath)
# Out:
# /content
# /content/drive/MyDrive/My Projects/respiratory_disorder_classification/processed_audio_files/113_1b1_Ll_sc_Litt3200_2.wav

# %%
isExist = os.path.exists(soundFilePath)
print(isExist)
# Out:
# True

# %%
mfcc_test, croma_test, mspec_test = getFeaturesForNeuralNetwork(soundFilePath)

# %%
# cannot directly input mfcc_test, croma_test, mspec_test, be careful of dimensions
import numpy as np
mfcc,cstft,mSpec = [],[],[]
mfcc.append(mfcc_test)
cstft.append(croma_test)
mSpec.append(mspec_test)

mfcc_test = np.array(mfcc)
cstft_test = np.array(cstft)
mspec_test = np.array(mSpec)
print(mfcc_test.shape)
print(cstft_test.shape)
print(mspec_test.shape)
# Out:
# (1, 20, 259)
# (1, 12, 259)
# (1, 128, 259)

# %%
result = model.predict({"mfcc":mfcc_test,"croma":cstft_test,"mspec":mspec_test})
# Out:
# 1/1 [==============================] - 1s 529ms/step

# %%
# print(le.classes_)
# After label encoding we get
# array(['Asthma', 'Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy',
#        'LRTI', 'Pneumonia', 'URTI'], dtype=object)
diseaseArray = ['Asthma', 'Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'LRTI', 'Pneumonia', 'URTI']
result = result.flatten()
indexMax = np.argmax(result)
indexSecMax = 0
secMax = result[0]
for smx in range(len(result)):
    if(result[smx] > secMax and result[smx] < result[indexMax]):
        indexSecMax = smx
        secMax = result[smx]

print(index)
print(result)
print(indexSecMax)
# Out:
# range(0, 6898)
# [9.8715792e-18 5.5069024e-13 7.6909677e-15 1.0000000e+00 2.0409954e-12
#  1.6610651e-20 1.4947417e-10 1.5143598e-16]
# 6

# %%
# 2 most prominent disorders
print("Disorders Detected:")
print("respiratory disorder detected: " + str(diseaseArray[indexMax]) + " with probability " + str(result[indexMax] * 100) + "%")
print("respiratory disorder detected: " + str(diseaseArray[indexSecMax]) + " with probability " + str(result[indexSecMax] * 100) + "%")
# Out:
# Disorders Detected:
# respiratory disorder detected: COPD with probability 100.0%
# respiratory disorder detected: Pneumonia with probability 1.4947416915322975e-08%

# %% [markdown]
# ## Training and Testing individual models for comparison

# %% [markdown]
# MFCC Model

# %%
# modelExist = os.path.exists('trainedModel')
# if(not modelExist):
mfcc_input=keras.layers.Input(shape=(20,259,1),name="mfccInput")
x=keras.layers.Conv2D(32,5,strides=(1,3),padding='same')(mfcc_input)
x=keras.layers.BatchNormalization()(x)
x=keras.layers.Activation(keras.activations.relu)(x)
x=keras.layers.MaxPooling2D(pool_size=2,padding='valid')(x)

x=keras.layers.Conv2D(64,3,strides=(1,2),padding='same')(x)
x=keras.layers.BatchNormalization()(x)
x=keras.layers.Activation(keras.activations.relu)(x)
x=keras.layers.MaxPooling2D(pool_size=2,padding='valid')(x)

x=keras.layers.Conv2D(96,2,padding='same')(x)
x=keras.layers.BatchNormalization()(x)
x=keras.layers.Activation(keras.activations.relu)(x)
x=keras.layers.MaxPooling2D(pool_size=2,padding='valid')(x)

x=keras.layers.Conv2D(128,2,padding='same')(x)
x=keras.layers.BatchNormalization()(x)
x=keras.layers.Activation(keras.activations.relu)(x)
mfcc_output=keras.layers.GlobalMaxPooling2D()(x)

mfccModel=keras.Model(mfcc_input, mfcc_output, name="mfccModel")


input_mfcc=keras.layers.Input(shape=(20,259,1),name="mfcc")
mfcc=mfccModel(input_mfcc)

concat=keras.layers.concatenate([mfcc])
hidden=keras.layers.Dropout(0.3)(concat)
hidden=keras.layers.Dense(100,activation='relu')(concat)
hidden=keras.layers.Dropout(0.3)(hidden)
hidden=keras.layers.Dense(50,activation='relu')(concat)
hidden=keras.layers.Dropout(0.3)(hidden)
hidden=keras.layers.Dense(25,activation='relu')(hidden)
hidden=keras.layers.Dropout(0.3)(hidden)
hidden=keras.layers.Dense(12,activation='relu')(hidden)
hidden=keras.layers.Dropout(0.3)(hidden)
output=keras.layers.Dense(8,activation='softmax')(hidden)

mfcc_model=keras.Model([input_mfcc], output, name="mfcc_model")

# %%
# modelExist = os.path.exists('trainedModel')
# if(not modelExist):
from keras import backend as K
mfcc_model.compile(loss='sparse_categorical_crossentropy', optimizer='nadam', metrics=['accuracy'])
K.set_value(mfcc_model.optimizer.learning_rate, 0.001)

# %%
modelExist = os.path.exists('trainedModel')
if(not modelExist):
    history=mfcc_model.fit(
        {"mfcc":mfcc_train},
        ytrain,
        validation_data=({"mfcc":mfcc_val},yval),
        epochs=100,verbose=1,
        callbacks=my_callbacks
    )

# %%
from tensorflow.keras.models import save_model
save_model(mfcc_model, "mfccTrained1.h5")
# Out:
# <ipython-input-107-96cdcdc6c9e3>:2: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   save_model(mfcc_model, "mfccTrained1.h5")

# %%
loss_train = history.history['accuracy']
loss_val = history.history['val_accuracy']
epochs = range(0, len(loss_train))
plt.plot(epochs, loss_train, 'g', label='Training accuracy')
plt.plot(epochs, loss_val, 'b', label='Validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
pd.DataFrame(history.history).plot()
plt.grid(True)
plt.gca().set_ylim(-0.1,1.1)
plt.show()

# %%
modelExist = os.path.exists('trainedModel')
if(not modelExist):
    mfcc_model.evaluate({"mfcc":mfcc_val},yval)

# %%
modelExist = os.path.exists('trainedModel')
if(modelExist):
    mfcc_model.summary()
# Out:
# Model: "mfcc_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mfcc (InputLayer)           [(None, 20, 259, 1)]      0
#
#  mfccModel (Functional)      (None, 128)               94560
#
#  concatenate_1 (Concatenate  (None, 128)               0
#  )
#
#  dense_4 (Dense)             (None, 50)                6450
#
#  dropout_5 (Dropout)         (None, 50)                0
#
#  dense_5 (Dense)             (None, 25)                1275
#
#  dropout_6 (Dropout)         (None, 25)                0
#
#  dense_6 (Dense)             (None, 12)                312
#
#  dropout_7 (Dropout)         (None, 12)                0
#
#  dense_7 (Dense)             (None, 8)                 104
#
# =================================================================
# Total params: 102701 (401.18 KB)
# Trainable params: 102061 (398.68 KB)
# Non-trainable params: 640 (2.50 KB)
# _________________________________________________________________

# %% [markdown]
# CHROMA Model

# %%
# modelExist = os.path.exists('trainedModel')
# if(not modelExist):
croma_input=keras.layers.Input(shape=(12,259,1),name="cromaInput")
x=keras.layers.Conv2D(32,5,strides=(1,3),padding='same')(croma_input)
x=keras.layers.BatchNormalization()(x)
x=keras.layers.Activation(keras.activations.relu)(x)
x=keras.layers.MaxPooling2D(pool_size=2,padding='valid')(x)

x=keras.layers.Conv2D(64,3,strides=(1,2),padding='same')(x)
x=keras.layers.BatchNormalization()(x)
x=keras.layers.Activation(keras.activations.relu)(x)
x=keras.layers.MaxPooling2D(pool_size=2,padding='valid')(x)

x=keras.layers.Conv2D(128,2,padding='same')(x)
x=keras.layers.BatchNormalization()(x)
x=keras.layers.Activation(keras.activations.relu)(x)
croma_output=keras.layers.GlobalMaxPooling2D()(x)

croma_model=keras.Model(croma_input, croma_output, name="cromaModel")

input_croma=keras.layers.Input(shape=(12,259,1),name="croma")
croma=croma_model(input_croma)

concat=keras.layers.concatenate([croma])
hidden=keras.layers.Dropout(0.2)(concat)
hidden=keras.layers.Dense(50,activation='relu')(concat)
hidden=keras.layers.Dropout(0.3)(hidden)
hidden=keras.layers.Dense(25,activation='relu')(hidden)
hidden=keras.layers.Dropout(0.3)(hidden)
output=keras.layers.Dense(8,activation='softmax')(hidden)

chroma_model=keras.Model([input_croma], output, name="chroma_model")

# %%
# modelExist = os.path.exists('trainedModel')
# if(not modelExist):
from keras import backend as K
chroma_model.compile(loss='sparse_categorical_crossentropy', optimizer='nadam', metrics=['accuracy'])
K.set_value(chroma_model.optimizer.learning_rate, 0.001)

# %%
modelExist = os.path.exists('trainedModel')
if(not modelExist):
    history=chroma_model.fit(
    {"croma":cstft_train},
    ytrain,
    validation_data=({"croma":cstft_val},yval),
    epochs=100,verbose=1,
    callbacks=my_callbacks
)

# %%
save_model(chroma_model, "chromaTrained1.h5")
# Out:
# <ipython-input-115-003d7992f691>:1: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   save_model(chroma_model, "chromaTrained1.h5")

# %%
loss_train = history.history['accuracy']
loss_val = history.history['val_accuracy']
epochs = range(0, len(loss_train))
plt.plot(epochs, loss_train, 'g', label='Training accuracy')
plt.plot(epochs, loss_val, 'b', label='Validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
modelExist = os.path.exists('trainedModel')
if(not modelExist):
    chroma_model.evaluate({"croma":cstft_val},yval)

# %%
modelExist = os.path.exists('trainedModel')
if(not modelExist):
    chroma_model.summary()

# %% [markdown]
# MSPEC Model

# %%
# modelExist = os.path.exists('trainedModel')
# if(not modelExist):
mSpec_input=keras.layers.Input(shape=(128,259,1),name="mSpecInput")
x=keras.layers.Conv2D(32,5,strides=(2,3),padding='same')(mSpec_input)
x=keras.layers.BatchNormalization()(x)
x=keras.layers.Activation(keras.activations.relu)(x)
x=keras.layers.MaxPooling2D(pool_size=2,padding='valid')(x)

x=keras.layers.Conv2D(64,3,strides=(2,2),padding='same')(x)
x=keras.layers.BatchNormalization()(x)
x=keras.layers.Activation(keras.activations.relu)(x)
x=keras.layers.MaxPooling2D(pool_size=2,padding='valid')(x)

x=keras.layers.Conv2D(96,2,padding='same')(x)
x=keras.layers.BatchNormalization()(x)
x=keras.layers.Activation(keras.activations.relu)(x)
x=keras.layers.MaxPooling2D(pool_size=2,padding='valid')(x)

x=keras.layers.Conv2D(128,2,padding='same')(x)
x=keras.layers.BatchNormalization()(x)
x=keras.layers.Activation(keras.activations.relu)(x)
mSpec_output=keras.layers.GlobalMaxPooling2D()(x)

mSpec_model=keras.Model(mSpec_input, mSpec_output, name="mSpecModel")

input_mSpec=keras.layers.Input(shape=(128,259,1),name="mspec")
mSpec=mSpec_model(input_mSpec)

concat=keras.layers.concatenate([mSpec])
hidden=keras.layers.Dropout(0.2)(concat)
hidden=keras.layers.Dense(50,activation='relu')(concat)
hidden=keras.layers.Dropout(0.3)(hidden)
hidden=keras.layers.Dense(25,activation='relu')(hidden)
hidden=keras.layers.Dropout(0.3)(hidden)
output=keras.layers.Dense(8,activation='softmax')(hidden)

mSpec_model = keras.Model([input_mSpec], output, name="mSpec_model")

# %%
# modelExist = os.path.exists('trainedModel')
# if(not modelExist):
from keras import backend as K
mSpec_model.compile(loss='sparse_categorical_crossentropy', optimizer='nadam', metrics=['accuracy'])
K.set_value(mSpec_model.optimizer.learning_rate, 0.001)

# %%
modelExist = os.path.exists('trainedModel')
if(not modelExist):
    history=mSpec_model.fit(
        {"mspec":mSpec_train},
        ytrain,
        validation_data=({"mspec":mSpec_val},yval),
        epochs=100,verbose=1,
        callbacks=my_callbacks
    )

# %%
loss_train = history.history['accuracy']
loss_val = history.history['val_accuracy']
epochs = range(0, len(loss_train))
plt.plot(epochs, loss_train, 'g', label='Training accuracy')
plt.plot(epochs, loss_val, 'b', label='validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
save_model(mSpec_model, "mSpecTrained1.h5")
# Out:
# <ipython-input-123-182e6d79fd94>:1: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   save_model(mSpec_model, "mSpecTrained1.h5")

# %%
modelExist = os.path.exists('trainedModel')
if(not modelExist):
    mSpec_model.evaluate({"mspec":mSpec_val},yval)

# %%
modelExist = os.path.exists('trainedModel')
if(not modelExist):
    mSpec_model.summary()

# %%
modelExist = os.path.exists('trainedModel')
if(not modelExist):
    os.makedirs('trainedModel')
    save_model(mfcc_model, "./trainedModel/mfcc_model.h5")
    save_model(chroma_model, "./trainedModel/chroma_model.h5")
    save_model(mSpec_model, "./trainedModel/mSpec_model.h5")

# %% [markdown]
# ## Testing time limit taken for execution by each model

# %%
import librosa as lb
def getFeaturesForNeuralNetwork(path):
    soundArr,sample_rate=lb.load(path)
    mfcc=lb.feature.mfcc(y=soundArr,sr=sample_rate)
    cstft=lb.feature.chroma_stft(y=soundArr,sr=sample_rate)
    mSpec=lb.feature.melspectrogram(y=soundArr,sr=sample_rate)

    return mfcc,cstft,mSpec

# %%
# testing soundfile path

COPD = "113_1b1_Ll_sc_Litt3200_2.wav"
Pneumonia = "135_2b3_Al_mc_LittC2SE_3.wav"
URTI = "119_1b1_Ar_sc_Meditron_0.wav"
Healthy = "159_1b1_Ar_sc_Meditron_3.wav"
Bronchiectasis = "111_1b2_Tc_sc_Meditron_2.wav"
Bronchiolitis = "149_1b1_Pl_sc_Meditron_10.wav"
Asthma = "103_2b2_Ar_mc_LittC2SE_3.wav"

soundFilePath = "/content/drive/MyDrive/My Projects/respiratory_disorder_classification/processed_audio_files/" + Pneumonia
print(os.getcwd())
print(soundFilePath)
# Out:
# /content
# /content/drive/MyDrive/My Projects/respiratory_disorder_classification/processed_audio_files/135_2b3_Al_mc_LittC2SE_3.wav

# %%
mfcc_test, croma_test, mspec_test = getFeaturesForNeuralNetwork(soundFilePath)

# %%
# cannot directly input mfcc_test, croma_test, mspec_test, be careful of dimensions
import numpy as np
mfcc,cstft,mSpec = [],[],[]
mfcc.append(mfcc_test)
cstft.append(croma_test)
mSpec.append(mspec_test)

mfcc_test = np.array(mfcc)
cstft_test = np.array(cstft)
mspec_test = np.array(mSpec)
print(mfcc_test.shape)
print(cstft_test.shape)
print(mspec_test.shape)
# Out:
# (1, 20, 259)
# (1, 12, 259)
# (1, 128, 259)

# %%
# load model
# model = keras.models.load_model('model') if model not saved in h5 format
import tensorflow
import time
from tensorflow.keras.models import load_model

# load model

netModel = load_model('model/model.h5')

# %%
# Mfcc Model

counter = 0
itr = 30
for i in range(itr):
    temp = 0
    start = time.time()
    result = mfcc_model.predict({"mfcc":mfcc_test})
    end = time.time()
    temp = (end-start) * 10**3
    counter += temp
    print("The time of execution of mfcc model for iteration " + str(i) + ":",temp, "ms")
print("--------------------------------------------------------------------------")
print("Average time taken by model:",counter/itr,"ms")
# Out:
# 1/1 [==============================] - 0s 232ms/step
# The time of execution of mfcc model for iteration 0: 315.54555892944336 ms
# 1/1 [==============================] - 0s 29ms/step
# The time of execution of mfcc model for iteration 1: 106.52518272399902 ms
# 1/1 [==============================] - 0s 34ms/step
# The time of execution of mfcc model for iteration 2: 116.86062812805176 ms
# 1/1 [==============================] - 0s 33ms/step
# The time of execution of mfcc model for iteration 3: 109.3440055847168 ms
# 1/1 [==============================] - 0s 34ms/step
# The time of execution of mfcc model for iteration 4: 126.42121315002441 ms
# 1/1 [==============================] - 0s 32ms/step
# The time of execution of mfcc model for iteration 5: 114.67432975769043 ms
# 1/1 [==============================] - 0s 31ms/step
# The time of execution of mfcc model for iteration 6: 99.47943687438965 ms
# 1/1 [==============================] - 0s 30ms/step
# The time of execution of mfcc model for iteration 7: 113.97862434387207 ms
# 1/1 [==============================] - 0s 32ms/step
# The time of execution of mfcc model for iteration 8: 132.7202320098877 ms
# 1/1 [==============================] - 0s 39ms/step
# The time of execution of mfcc model for iteration 9: 118.27325820922852 ms
# 1/1 [==============================] - 0s 36ms/step
# The time of execution of mfcc model for iteration 10: 119.4450855255127 ms
# 1/1 [==============================] - 0s 37ms/step
# The time of execution of mfcc model for iteration 11: 109.07435417175293 ms
# 1/1 [==============================] - 0s 32ms/step
# The time of execution of mfcc model for iteration 12: 112.24222183227539 ms
# 1/1 [==============================] - 0s 40ms/step
# The time of execution of mfcc model for iteration 13: 126.13725662231445 ms
# 1/1 [==============================] - 0s 32ms/step
# The time of execution of mfcc model for iteration 14: 115.25940895080566 ms
# 1/1 [==============================] - 0s 42ms/step
# The time of execution of mfcc model for iteration 15: 126.26886367797852 ms
# 1/1 [==============================] - 0s 33ms/step
# The time of execution of mfcc model for iteration 16: 105.92174530029297 ms
# 1/1 [==============================] - 0s 35ms/step
# The time of execution of mfcc model for iteration 17: 133.80813598632812 ms
# 1/1 [==============================] - 0s 33ms/step
# The time of execution of mfcc model for iteration 18: 130.2495002746582 ms
# 1/1 [==============================] - 0s 32ms/step
# The time of execution of mfcc model for iteration 19: 113.43240737915039 ms
# 1/1 [==============================] - 0s 31ms/step
# The time of execution of mfcc model for iteration 20: 116.41168594360352 ms
# 1/1 [==============================] - 0s 42ms/step
# The time of execution of mfcc model for iteration 21: 117.3243522644043 ms
# 1/1 [==============================] - 0s 32ms/step
# The time of execution of mfcc model for iteration 22: 135.26272773742676 ms
# 1/1 [==============================] - 0s 31ms/step
# The time of execution of mfcc model for iteration 23: 120.69201469421387 ms
# 1/1 [==============================] - 0s 31ms/step
# The time of execution of mfcc model for iteration 24: 106.75382614135742 ms
# 1/1 [==============================] - 0s 38ms/step
# The time of execution of mfcc model for iteration 25: 108.89935493469238 ms
# 1/1 [==============================] - 0s 34ms/step
# The time of execution of mfcc model for iteration 26: 132.71760940551758 ms
# 1/1 [==============================] - 0s 31ms/step
# The time of execution of mfcc model for iteration 27: 111.75346374511719 ms
# 1/1 [==============================] - 0s 33ms/step
# The time of execution of mfcc model for iteration 28: 123.12865257263184 ms
# 1/1 [==============================] - 0s 33ms/step
# The time of execution of mfcc model for iteration 29: 108.00051689147949 ms
# --------------------------------------------------------------------------
# Average time taken by model: 124.22018845876057 ms

# %%
# MSpec Model

counter = 0
itr = 30
for i in range(itr):
    temp = 0
    start = time.time()
    result = mSpec_model.predict({"mspec":mspec_test})
    end = time.time()
    temp = (end-start) * 10**3
    counter += temp
    print("The time of execution of mSpec model for iteration " + str(i) + ":",temp, "ms")
print("--------------------------------------------------------------------------")
print("Average time taken by model:",counter/itr,"ms")
# Out:
# 1/1 [==============================] - 0s 233ms/step
# The time of execution of mSpec model for iteration 0: 318.1335926055908 ms
# 1/1 [==============================] - 0s 34ms/step
# The time of execution of mSpec model for iteration 1: 112.01739311218262 ms
# 1/1 [==============================] - 0s 36ms/step
# The time of execution of mSpec model for iteration 2: 116.72806739807129 ms
# 1/1 [==============================] - 0s 31ms/step
# The time of execution of mSpec model for iteration 3: 128.4310817718506 ms
# 1/1 [==============================] - 0s 33ms/step
# The time of execution of mSpec model for iteration 4: 112.48087882995605 ms
# 1/1 [==============================] - 0s 39ms/step
# The time of execution of mSpec model for iteration 5: 108.51263999938965 ms
# 1/1 [==============================] - 0s 33ms/step
# The time of execution of mSpec model for iteration 6: 109.07125473022461 ms
# 1/1 [==============================] - 0s 37ms/step
# The time of execution of mSpec model for iteration 7: 114.24922943115234 ms
# 1/1 [==============================] - 0s 36ms/step
# The time of execution of mSpec model for iteration 8: 109.4810962677002 ms
# 1/1 [==============================] - 0s 41ms/step
# The time of execution of mSpec model for iteration 9: 134.79042053222656 ms
# 1/1 [==============================] - 0s 37ms/step
# The time of execution of mSpec model for iteration 10: 111.6170883178711 ms
# 1/1 [==============================] - 0s 43ms/step
# The time of execution of mSpec model for iteration 11: 133.5620880126953 ms
# 1/1 [==============================] - 0s 33ms/step
# The time of execution of mSpec model for iteration 12: 131.81185722351074 ms
# 1/1 [==============================] - 0s 31ms/step
# The time of execution of mSpec model for iteration 13: 109.71641540527344 ms
# 1/1 [==============================] - 0s 36ms/step
# The time of execution of mSpec model for iteration 14: 124.18174743652344 ms
# 1/1 [==============================] - 0s 32ms/step
# The time of execution of mSpec model for iteration 15: 115.15974998474121 ms
# 1/1 [==============================] - 0s 42ms/step
# The time of execution of mSpec model for iteration 16: 123.7783432006836 ms
# 1/1 [==============================] - 0s 36ms/step
# The time of execution of mSpec model for iteration 17: 123.92687797546387 ms
# 1/1 [==============================] - 0s 37ms/step
# The time of execution of mSpec model for iteration 18: 130.22160530090332 ms
# 1/1 [==============================] - 0s 32ms/step
# The time of execution of mSpec model for iteration 19: 120.27740478515625 ms
# 1/1 [==============================] - 0s 34ms/step
# The time of execution of mSpec model for iteration 20: 133.73208045959473 ms
# 1/1 [==============================] - 0s 41ms/step
# The time of execution of mSpec model for iteration 21: 130.86867332458496 ms
# 1/1 [==============================] - 0s 36ms/step
# The time of execution of mSpec model for iteration 22: 122.41888046264648 ms
# 1/1 [==============================] - 0s 35ms/step
# The time of execution of mSpec model for iteration 23: 128.01790237426758 ms
# 1/1 [==============================] - 0s 33ms/step
# The time of execution of mSpec model for iteration 24: 114.52054977416992 ms
# 1/1 [==============================] - 0s 38ms/step
# The time of execution of mSpec model for iteration 25: 120.20349502563477 ms
# 1/1 [==============================] - 0s 37ms/step
# The time of execution of mSpec model for iteration 26: 139.55163955688477 ms
# 1/1 [==============================] - 0s 35ms/step
# The time of execution of mSpec model for iteration 27: 132.69543647766113 ms
# 1/1 [==============================] - 0s 36ms/step
# The time of execution of mSpec model for iteration 28: 151.02171897888184 ms
# 1/1 [==============================] - 0s 33ms/step
# The time of execution of mSpec model for iteration 29: 114.00079727172852 ms
# --------------------------------------------------------------------------
# Average time taken by model: 129.17266686757407 ms

# %%
# Chroma Stft Model

counter = 0
itr = 30
for i in range(itr):
    temp = 0
    start = time.time()
    result = chroma_model.predict({"croma":cstft_test})
    end = time.time()
    temp = (end-start) * 10**3
    counter += temp
    print("The time of execution of Chroma Stft model for iteration " + str(i) + ":",temp, "ms")
print("--------------------------------------------------------------------------")
print("Average time taken by model:",counter/itr,"ms")
# Out:
# 1/1 [==============================] - 0s 183ms/step
# The time of execution of Chroma Stft model for iteration 0: 275.78210830688477 ms
# 1/1 [==============================] - 0s 27ms/step
# The time of execution of Chroma Stft model for iteration 1: 99.72476959228516 ms
# 1/1 [==============================] - 0s 28ms/step
# The time of execution of Chroma Stft model for iteration 2: 116.5306568145752 ms
# 1/1 [==============================] - 0s 34ms/step
# The time of execution of Chroma Stft model for iteration 3: 116.14727973937988 ms
# 1/1 [==============================] - 0s 35ms/step
# The time of execution of Chroma Stft model for iteration 4: 132.06028938293457 ms
# 1/1 [==============================] - 0s 33ms/step
# The time of execution of Chroma Stft model for iteration 5: 141.54291152954102 ms
# 1/1 [==============================] - 0s 31ms/step
# The time of execution of Chroma Stft model for iteration 6: 116.71566963195801 ms
# 1/1 [==============================] - 0s 35ms/step
# The time of execution of Chroma Stft model for iteration 7: 119.94075775146484 ms
# 1/1 [==============================] - 0s 37ms/step
# The time of execution of Chroma Stft model for iteration 8: 125.98443031311035 ms
# 1/1 [==============================] - 0s 30ms/step
# The time of execution of Chroma Stft model for iteration 9: 117.28596687316895 ms
# 1/1 [==============================] - 0s 31ms/step
# The time of execution of Chroma Stft model for iteration 10: 125.74529647827148 ms
# 1/1 [==============================] - 0s 33ms/step
# The time of execution of Chroma Stft model for iteration 11: 124.90391731262207 ms
# 1/1 [==============================] - 0s 31ms/step
# The time of execution of Chroma Stft model for iteration 12: 119.60244178771973 ms
# 1/1 [==============================] - 0s 40ms/step
# The time of execution of Chroma Stft model for iteration 13: 130.33413887023926 ms
# 1/1 [==============================] - 0s 37ms/step
# The time of execution of Chroma Stft model for iteration 14: 126.40595436096191 ms
# 1/1 [==============================] - 0s 31ms/step
# The time of execution of Chroma Stft model for iteration 15: 110.11362075805664 ms
# 1/1 [==============================] - 0s 37ms/step
# The time of execution of Chroma Stft model for iteration 16: 116.23716354370117 ms
# 1/1 [==============================] - 0s 38ms/step
# The time of execution of Chroma Stft model for iteration 17: 114.39681053161621 ms
# 1/1 [==============================] - 0s 34ms/step
# The time of execution of Chroma Stft model for iteration 18: 107.61237144470215 ms
# 1/1 [==============================] - 0s 32ms/step
# The time of execution of Chroma Stft model for iteration 19: 112.43176460266113 ms
# 1/1 [==============================] - 0s 34ms/step
# The time of execution of Chroma Stft model for iteration 20: 108.04271697998047 ms
# 1/1 [==============================] - 0s 33ms/step
# The time of execution of Chroma Stft model for iteration 21: 106.68706893920898 ms
# 1/1 [==============================] - 0s 39ms/step
# The time of execution of Chroma Stft model for iteration 22: 131.57033920288086 ms
# 1/1 [==============================] - 0s 30ms/step
# The time of execution of Chroma Stft model for iteration 23: 120.57209014892578 ms
# 1/1 [==============================] - 0s 34ms/step
# The time of execution of Chroma Stft model for iteration 24: 117.36202239990234 ms
# 1/1 [==============================] - 0s 33ms/step
# The time of execution of Chroma Stft model for iteration 25: 118.96252632141113 ms
# 1/1 [==============================] - 0s 31ms/step
# The time of execution of Chroma Stft model for iteration 26: 101.01604461669922 ms
# 1/1 [==============================] - 0s 36ms/step
# The time of execution of Chroma Stft model for iteration 27: 118.14665794372559 ms
# 1/1 [==============================] - 0s 33ms/step
# The time of execution of Chroma Stft model for iteration 28: 107.82051086425781 ms
# 1/1 [==============================] - 0s 40ms/step
# The time of execution of Chroma Stft model for iteration 29: 113.89660835266113 ms
# --------------------------------------------------------------------------
# Average time taken by model: 123.1191635131836 ms

# %%
# The net concatenated model

counter = 0
itr = 30
for i in range(itr):
    temp = 0
    start = time.time()
    result = netModel.predict({"mfcc":mfcc_test,"croma":cstft_test,"mspec":mspec_test})
    end = time.time()
    temp = (end-start) * 10**3
    counter += temp
    print("The time of execution of net concatenated model for iteration " + str(i) + ":",temp, "ms")
print("--------------------------------------------------------------------------")
print("Average time taken by model:",counter/itr,"ms")
# Out:
# 1/1 [==============================] - 0s 463ms/step
# The time of execution of net concatenated model for iteration 0: 565.8044815063477 ms
# 1/1 [==============================] - 0s 43ms/step
# The time of execution of net concatenated model for iteration 1: 148.93651008605957 ms
# 1/1 [==============================] - 0s 42ms/step
# The time of execution of net concatenated model for iteration 2: 141.03007316589355 ms
# 1/1 [==============================] - 0s 36ms/step
# The time of execution of net concatenated model for iteration 3: 128.85665893554688 ms
# 1/1 [==============================] - 0s 37ms/step
# The time of execution of net concatenated model for iteration 4: 132.2481632232666 ms
# 1/1 [==============================] - 0s 34ms/step
# The time of execution of net concatenated model for iteration 5: 124.48549270629883 ms
# 1/1 [==============================] - 0s 39ms/step
# The time of execution of net concatenated model for iteration 6: 156.6452980041504 ms
# 1/1 [==============================] - 0s 36ms/step
# The time of execution of net concatenated model for iteration 7: 129.52804565429688 ms
# 1/1 [==============================] - 0s 34ms/step
# The time of execution of net concatenated model for iteration 8: 132.42077827453613 ms
# 1/1 [==============================] - 0s 37ms/step
# The time of execution of net concatenated model for iteration 9: 117.9347038269043 ms
# 1/1 [==============================] - 0s 35ms/step
# The time of execution of net concatenated model for iteration 10: 133.11767578125 ms
# 1/1 [==============================] - 0s 40ms/step
# The time of execution of net concatenated model for iteration 11: 135.21075248718262 ms
# 1/1 [==============================] - 0s 31ms/step
# The time of execution of net concatenated model for iteration 12: 126.69038772583008 ms
# 1/1 [==============================] - 0s 37ms/step
# The time of execution of net concatenated model for iteration 13: 118.60108375549316 ms
# 1/1 [==============================] - 0s 37ms/step
# The time of execution of net concatenated model for iteration 14: 171.6618537902832 ms
# 1/1 [==============================] - 0s 38ms/step
# The time of execution of net concatenated model for iteration 15: 129.36902046203613 ms
# 1/1 [==============================] - 0s 38ms/step
# The time of execution of net concatenated model for iteration 16: 130.86557388305664 ms
# 1/1 [==============================] - 0s 40ms/step
# The time of execution of net concatenated model for iteration 17: 131.62803649902344 ms
# 1/1 [==============================] - 0s 43ms/step
# The time of execution of net concatenated model for iteration 18: 141.53504371643066 ms
# 1/1 [==============================] - 0s 37ms/step
# The time of execution of net concatenated model for iteration 19: 124.51505661010742 ms
# 1/1 [==============================] - 0s 37ms/step
# The time of execution of net concatenated model for iteration 20: 125.3657341003418 ms
# 1/1 [==============================] - 0s 55ms/step
# The time of execution of net concatenated model for iteration 21: 148.6835479736328 ms
# 1/1 [==============================] - 0s 34ms/step
# The time of execution of net concatenated model for iteration 22: 135.38765907287598 ms
# 1/1 [==============================] - 0s 36ms/step
# The time of execution of net concatenated model for iteration 23: 139.2965316772461 ms
# 1/1 [==============================] - 0s 36ms/step
# The time of execution of net concatenated model for iteration 24: 136.74020767211914 ms
# 1/1 [==============================] - 0s 39ms/step
# The time of execution of net concatenated model for iteration 25: 139.86968994140625 ms
# 1/1 [==============================] - 0s 39ms/step
# The time of execution of net concatenated model for iteration 26: 134.32908058166504 ms
# 1/1 [==============================] - 0s 51ms/step
# The time of execution of net concatenated model for iteration 27: 143.7392234802246 ms
# 1/1 [==============================] - 0s 39ms/step
# The time of execution of net concatenated model for iteration 28: 136.57259941101074 ms
# 1/1 [==============================] - 0s 36ms/step
# The time of execution of net concatenated model for iteration 29: 141.9992446899414 ms
# --------------------------------------------------------------------------
# Average time taken by model: 150.1022736231486 ms

# %% [markdown]
# ## Conclusion

# %% [markdown]
# #### When we used only MFCC:
# Model accuracy - 86.55 % <br />
# loss - 34.69 % <br />
# Time taken: 123 ms
#
# #### When we used only Chroma STFT:
# Model accuracy - 82.96 % <br />
# loss - 58.54 % <br />
# Time taken - 123 ms
#
# #### When we used only mSpec:
# Model accuracy - 85.68 % <br />
# loss - 46.57 % <br />
# Time taken - 129 ms
#
# #### When taking all of them combined in a neural network:
# Model Accuracy - 95 % <br />
# loss - 17.27 % <br />
# Time taken - 150 ms
#
# #### Hence, we can see that mfcc, chroma stft and mSpec using them together for feature extraction not only reduces the loss but also increases our overall model accuracy.
